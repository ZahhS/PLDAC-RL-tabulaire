# %% [markdown]
#  Copyright © Sorbonne University.
#
#  This source code is licensed under the MIT license found in the
#  LICENSE file in the root directory of this source tree.

# %% [markdown]
# # PLDAC - RL TABULAIRE

# %% [markdown]
# In this notebook, we will code a naive actor-critic algorithm in the tabular case using q-tables instead of the value function v.
#
#
# ## Install libraries
#
# Installs the necessary Python and system libraries

# %%
try:
    from easypip import easyimport
except ModuleNotFoundError:
    from subprocess import run
    assert run(["pip", "install", "easypip"]).returncode == 0, "Could not install easypip"
    from easypip import easyimport

easyimport("swig")
easyimport("bbrl_utils").setup(maze_mdp=True)

import os
from pathlib import Path
from typing import List, Tuple

import gymnasium as gym
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from bbrl_gymnasium.envs.maze_mdp import MazeMDPEnv
from bbrl_utils.notebook import tqdm
from mazemdp.mdp import Mdp
from mazemdp.toolbox import egreedy, egreedy_loc, sample_categorical, softmax
from mazemdp import random_policy
import bbrl_gymnasium  # noqa: F401

# %%
# matplotlib.use("TkAgg")

from functools import partial
# !pip install optuna
import optuna
import yaml
import hydra
from omegaconf import OmegaConf, DictConfig

import seaborn as sns
sns.set_theme()
import logging
optuna.logging.set_verbosity(optuna.logging.WARNING)
# Out:
# Requirement already satisfied: optuna in /usr/local/lib/python3.11/dist-packages (4.2.1)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.11/dist-packages (from optuna) (1.15.2)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.11/dist-packages (from optuna) (6.9.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from optuna) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from optuna) (24.2)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.11/dist-packages (from optuna) (2.0.40)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from optuna) (4.67.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.11/dist-packages (from optuna) (6.0.2)
# Requirement already satisfied: Mako in /usr/lib/python3/dist-packages (from alembic>=1.5.0->optuna) (1.1.3)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.11/dist-packages (from alembic>=1.5.0->optuna) (4.13.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.1.1)

# %% [markdown]
# # Step 1: Updating the naive Actor-critic algorithm with Q-values
#
# We consider the naive actor-critic algorithm with a categorical policy.
# The algorithm learns a critic with the standard temporal difference mechanism
# using a learning rate \(\alpha_{critic}\).
#
# We consider a **Q-value-based critic** \(Q(s, a)\) instead of a value-based critic \(V(s)\), which allows the algorithm to estimate the value of taking action \(a\) from state \(s\).
#
#
# ---
#
# ## Critic Update Rules
#
# We implement four different update rules for the Q-values:
#
# 1. **SARSA Update Rule**
#    $Q(s_t, a_t) ← Q(s_t, a_t) + alpha-critic [r_{t+1} + \gamma Q(s_{t+1}, a_{t+1}) - Q(s_t, a_t)]$
#
#    This rule follows the **on-policy** approach, where the next action is drawn according to the policy.
#
# 2. **Q-learning Update Rule**
#    $Q(s_t, a_t) ← Q(s_t, a_t) + alpha-critic [r_{t+1} + \gamma max_a Q(s_{t+1}, a) - max_a Q(s_t, a)]$
#
#    This rule follows the **off-policy** approach, where the best possible action is chosen greedily.
#
# 3. **"Mean" SARSA Update Rule**
#    $Q(s_t, a_t) ← Q(s_t, a_t) + alpha-critic [r_{t+1} + \gamma max_a Q(s_{t+1}, a) - \Sigma_a \pi(a|s_t)  Q(s_t, a)]$
#
#    This rule leverages the **expected value** of the Q-function over all actions, weighted by the current policy.
#
# 4. **Fourth Update Rule**
#    $Q(s_t, a_t) ← Q(s_t, a_t) + alpha-critic [r_{t+1} + \gamma max_a Q(s_{t+1}, a) - Q(s_t, a_t)]$
#    This rule uses a one-step update towards the maximum Q-value of the next state.
#
#
#
# ---
#
# ## Actor Update
#
# To update the actor, the general idea is the same, using the temporal difference error with another learning rate $\alpha_{actor}$.
#
# However, naively applying the same learning rule would not ensure that the probabilities of all actions in a state sum to 1.
# Besides, when the temporal difference error $\delta_t$ is negative, it may happen that the probability of an action gets negative or null, which raises an issue when applying renormalization.
#
# So, instead of applying the naive rule, we apply the following one:
# $$
# \pi_{temp}(a_t|s_t) =  \begin{cases}
# \pi^{(i)}(a_t|s_t) + \alpha_{actor} \delta_t & \mathrm{if } \pi^{(i)}(a_t|s_t) + \alpha_{actor} \delta_t > 10^{-8}\\
# 10^{-8} & \mathrm{otherwise.} \\
# \end{cases}
# $$
#
# Then we can apply renormalization so that the probabilities of actions still sum to 1, with
# $$
# \forall a, \pi^{(i+1)}(a|s_t) = \frac{\pi_{temp}^{(i+1)}(a|s_t)} {\sum_{a'} \pi_{temp}^{(i+1)}(a'|s_t)}
# $$ with
# $$
# \pi_{temp}^{(i+1)}(a|s_t) =  \begin{cases}
# \pi_{temp}(a|s_t) & \mathrm{if } a = a_t\\
# \pi^{(i)}(a|s_t) & \mathrm{otherwise.} \\
# \end{cases}
# $$
#
# ---
#
# ## Implementation:
#
# We provide a Python implementation of the naive actor-critic algorithm with Q-values using the four update rules.
#
#
# ---

# %%
def renormalize(
    mdp: MazeMDPEnv,
    policy: np.array,
    state: np.array,
) -> None:
    """
    Renormalize the probability of actions so that the sum of probabilities over actions is always 1.
    We made sure in the calling function that the probabilities of action never get negative when they are decreased.
    :param mdp: the mdp the agent is working in (to get the number of actions)
    :param policy: the current policy, before normalization
    :param state: the state where the actions need to be renormalized
    :return: nothing
    """

    policy[state] = policy[state] / np.sum(policy[state])

# %%
import numpy as np

def perform_episode(
    mdp: MazeMDPEnv,
    policy: np.array,
    q: np.array,
    alpha_critic: float,
    alpha_actor: float,
    update_type: int,
    render: bool = True,
    stagnation_threshold: float = 0.1,
    max_no_improve: int = 5
) -> int:
    """
    Perform an episode on the given mdp with the given policy using Q-values.
    :param update_type: int indicating the chosen update rule (1, 2, 3, 4).
    :return: the number of steps before it stops
    """
    state, _ = mdp.reset(uniform=True)  # reinit env, get initial state
    terminated = False
    truncated = False
    steps = 0
    episode_rewards = []
    last_avg_reward = None
    no_improvement_count = 0

    while not (terminated or truncated):
        if steps % 10000 == 0:
            print(f"Step: {steps}, State: {state}, Terminated: {terminated}, Truncated: {truncated}")

        action = sample_categorical(policy[state])  # draw action from the policy
        next_state, reward, terminated, truncated, _ = mdp.step(action)

        # max Q-value for the next state
        max_q_next = np.max(q[next_state])

        # next action according to the current policy (for SARSA)
        next_action = sample_categorical(policy[next_state])

        # TD error (delta) based on the selected update type
        if update_type == 1:
            # 1: SARSA update rule
            delta = reward + mdp.gamma * q[next_state, next_action] * (1 - terminated) - q[state, action]
            print(f"delta ({update_type}) - State: {state}, Action: {action}, Delta: {delta}")

        elif update_type == 2:
            # 2: Q-learning update rule
            delta = reward + mdp.gamma * max_q_next * (1 - terminated) - np.max(q[state])
            print(f"delta ({update_type}) - State: {state}, Action: {action}, Delta: {delta}")

        elif update_type == 3:
            # 3: MEAN SARSA update rule
            sum = np.sum(policy[state] * q[state])
            delta = reward + mdp.gamma * max_q_next * (1 - terminated) - sum
            print(f"delta ({update_type}) - State: {state}, Action: {action}, Delta: {delta}")
            print(f"Perform Episode - Update Type 3 - State: {state}, Sum Q: {sum}, Delta: {delta}")

        elif update_type == 4:
            # 4: Fourth update rule
            delta = reward + mdp.gamma * max_q_next * (1 - terminated) - q[state, action]
            print(f"delta ({update_type}) - State: {state}, Action: {action}, Delta: {delta}")

        else:
            raise ValueError("Invalid update type")

        # Update the Q-value with the delta
        q[state, action] += alpha_critic * delta

        # Update the policy with the new Q-values using the softmax function
        policy_temp = policy[state, action] + alpha_actor * delta
        policy[state, action] = max(policy_temp, 1e-8)

        renormalize(mdp, policy, state)
        print(f"Policy sum for state {state}: {np.sum(policy[state])}")
        assert np.isclose(np.sum(policy[state]), 1.0), "Policy is not properly normalized!"

        # Move to the next state
        state = next_state
        steps += 1

        # Track the reward for averaging
        episode_rewards.append(reward)

        # Calculate the average reward over the last N steps
        avg_reward = np.mean(episode_rewards[-1000:])

        # Detect stagnation based on the reward change
        if last_avg_reward is not None and abs(avg_reward - last_avg_reward) < stagnation_threshold:
            no_improvement_count += 1
        else:
            no_improvement_count = 0

        last_avg_reward = avg_reward

        # Stop if stagnation persists for a number of episodes
        if no_improvement_count >= max_no_improve:
            print(f"Stagnation detected after {steps} steps. Avg reward: {avg_reward}")
            return np.linalg.norm(q), steps

        value_norm = np.linalg.norm(q)
        print(f"Norm of Q-values: {value_norm}")

    return np.linalg.norm(q), steps

# %% [markdown]
# Here comes the main actor-critic function. It should take the shown parameters as input and output a list of value norms and a list of number of steps,
# corresponding to the evolution of these quantities through learning

# %%
def actor_critic_q(
    mdp: MazeMDPEnv,
    nb_episodes: int,
    alpha_critic: float,
    alpha_actor: float,
    update_type: int,
    render: bool = True,
) -> np.array:
    """
    Perform actor-critic training over a number of episodes with Q-values.
    :param update_type: int indicating the chosen update rule (1, 2, 3, 4).
    :return: a list of norm of Q values and a list of number of steps of episodes
    """
    # Initialize Q-values to zero
    q = np.zeros((mdp.nb_states, mdp.action_space.n)) # MAIN CHANGES FROM PREVIOUSLY

    # Initialize uniform policy
    policy = np.ones((mdp.nb_states, mdp.action_space.n)) / mdp.action_space.n

    # Store the number of steps and norms
    nb_steps = []
    value_norms = []

    for ep in range(nb_episodes):
        print(f" Actor_critic_q function - looping Episode {ep + 1}/{nb_episodes}")
        value_norm, steps = perform_episode(mdp, policy, q, alpha_critic, alpha_actor, update_type, render)
        value_norms.append(value_norm)
        nb_steps.append(steps)

    return value_norms, nb_steps

# %% [markdown]
# ## Provide a plot function
#
# Your plot function should show the evolution through time of number of steps the agent takes to find the reward in the maze.
# If your algorithm works, this number of steps should decrease through time.
#
# Your plot function should also show a mean and a standard deviation (or some more advanced statistics) over a collection of learning runs.
# Make sure that your figure complies with [The figure checklist](https://master-dac.isir.upmc.fr/The_figure_checklist.pdf).

# %%
def plot_steps(
    nb_runs: int = 5,
    nb_episodes: int = 20,
    alpha_critic: float = 0.01,
    alpha_actor: float = 0.01,
    render: bool = True
) -> None:
    """
    Plot the performance of the Actor-Critic algorithm over multiple runs with different update rules.
    Shows the mean and standard deviation of the number of steps per episode for each update rule.
    Also provides a summary table with mean and standard deviation values.
    :param nb_episodes: the number of episodes
    :param alpha_critic: the learning rate of the critic
    :param alpha_actor: the learning rate of the actor
    :param render: whether training should be rendered
    :param nb_runs: number of runs to perform
    :return: nothing
    """
    update_names = ["SARSA", "Q-learning", "Mean SARSA", "Fourth Rule"]
    all_results = []
    summary = []

    print("\nEntered plot_steps funtion\n")
    for update_type in range(1, 5):
        print(f"\nPlot_steps funtion - Update type {update_type}")
        all_steps = []
        all_vals = []

        for run in range(nb_runs):
            print(f"Plot_steps funtion - Run {run + 1} of {nb_runs}")
            vals, nb_steps = actor_critic_q(mdp, nb_episodes, alpha_critic, alpha_actor, update_type, render)
            all_steps.append(nb_steps)
            all_vals.append(vals)

        # Convert to numpy arrays
        all_steps = np.array(all_steps)
        mean_steps = np.mean(all_steps, axis=0)
        std_steps = np.std(all_steps, axis=0)
        all_results.append((update_names[update_type - 1], mean_steps, std_steps))
        summary.append([update_names[update_type - 1], np.mean(mean_steps), np.std(mean_steps)])

    # Create summary table
    summary_df = pd.DataFrame(summary, columns=["Update Rule", "Mean Steps", "Standard Deviation"])
    print("\nSummary Table:\n", summary_df)
    print("nb_episodes:", nb_episodes)

    # Plotting results
    plt.figure(figsize=(12, 8))
    plt.title("Actor-Critic Performance - Comparison of Update Rules")
    plt.xlabel("Episode")
    plt.ylabel("Number of Steps")
    plt.grid(True, linestyle="--", alpha=0.6)

    for name, mean_steps, std_steps in all_results:
        plt.plot(mean_steps, label=f"{name} - Mean Steps")
        plt.fill_between(range(nb_episodes), mean_steps - std_steps, mean_steps + std_steps, alpha=0.2)

    plt.legend(loc="upper right")
    plt.savefig("actor_critic_comparison.pdf")
    plt.show()

# %% [markdown]
# ## Separating plot_steps into 2 functions

# %%
def run_actor_critic_experiments(
    mdp, nb_runs: int,
    nb_episodes: int,
    alpha_critic: float,
    alpha_actor: float,
    render: bool
):
    """
    Run the Actor-Critic algorithm multiple times with different update rules and collect results.

    :return: results (list of tuples with update rule name, mean steps, std steps), summary DataFrame
    """
    update_names = ["SARSA", "Q-learning", "Mean SARSA", "Fourth Rule"]
    all_results = []
    summary = []

    for update_type in range(1, 5):  # Loop over update rules
        all_steps = []

        for run in range(nb_runs):
            _, nb_steps = actor_critic_q(mdp, nb_episodes, alpha_critic, alpha_actor, update_type, render)
            all_steps.append(nb_steps)

        all_steps = np.array(all_steps)
        mean_steps = np.mean(all_steps, axis=0)
        std_steps = np.std(all_steps, axis=0)

        all_results.append((update_names[update_type - 1], mean_steps, std_steps))
        summary.append([update_names[update_type - 1], np.mean(mean_steps), np.std(mean_steps)])

    df = pd.DataFrame(summary, columns=["Update Rule", "Mean Steps", "Standard Deviation"])

    return all_results, df

# %%
def plot_results(all_results, summary_df, nb_episodes):
    """
    Plot the results of the Actor-Critic algorithm and display the summary table.

    :param all_results: List of tuples (update rule name, mean steps, std steps)
    :param summary_df: DataFrame with mean and std deviation of steps per update rule
    """
    print("\nSummary Table:\n", summary_df)
    print("nb_episodes:", nb_episodes)

    plt.figure(figsize=(12, 8))
    plt.title("Actor-Critic Performance - Comparison of Update Rules")
    plt.xlabel("Episode")
    plt.ylabel("Number of Steps")
    plt.grid(True, linestyle="--", alpha=0.6)

    for name, mean_steps, std_steps in all_results:
        plt.plot(mean_steps, label=f"{name} - Mean Steps")
        plt.fill_between(range(nb_episodes), mean_steps - std_steps, mean_steps + std_steps, alpha=0.2)

    plt.legend(loc="upper right")
    plt.savefig("actor_critic_comparison.pdf")
    plt.show()

# %%
nb_runs = 5
nb_episodes = 30
alpha_critic = 0.01
alpha_actor = 0.01
render = True

all_results, summary_df = run_actor_critic_experiments(mdp, nb_runs, nb_episodes, alpha_critic, alpha_actor, render)
plot_results(all_results, summary_df, nb_episodes)
# Out:
# Streaming output truncated to the last 5000 lines.
# Perform Episode - Update Type 3 - State: 16, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 16: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 11, Action: 2, Delta: 0.0
# Perform Episode - Update Type 3 - State: 11, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 11: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 3/30
# Step: 0, State: 20, Terminated: False, Truncated: False
# delta (3) - State: 20, Action: 1, Delta: 0.0
# Perform Episode - Update Type 3 - State: 20, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 20: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 21, Action: 2, Delta: 0.0
# Perform Episode - Update Type 3 - State: 21, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 21: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 21, Action: 0, Delta: 0.0
# Perform Episode - Update Type 3 - State: 21, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 21: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 20, Action: 3, Delta: 0.0
# Perform Episode - Update Type 3 - State: 20, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 20: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 15, Action: 0, Delta: 0.0
# Perform Episode - Update Type 3 - State: 15, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 15: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 15, Action: 1, Delta: 0.0
# Perform Episode - Update Type 3 - State: 15, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 15: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 4/30
# Step: 0, State: 4, Terminated: False, Truncated: False
# delta (3) - State: 4, Action: 2, Delta: 0.0
# Perform Episode - Update Type 3 - State: 4, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 4: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 9, Action: 2, Delta: 0.0
# Perform Episode - Update Type 3 - State: 9, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 9: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 14, Action: 3, Delta: 0.0
# Perform Episode - Update Type 3 - State: 14, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 14: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 9, Action: 0, Delta: 0.0
# Perform Episode - Update Type 3 - State: 9, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 9: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 8, Action: 0, Delta: 0.0
# Perform Episode - Update Type 3 - State: 8, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 8: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 7, Action: 0, Delta: 0.0
# Perform Episode - Update Type 3 - State: 7, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 7: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 5/30
# Step: 0, State: 15, Terminated: False, Truncated: False
# delta (3) - State: 15, Action: 0, Delta: 0.0
# Perform Episode - Update Type 3 - State: 15, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 15: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 15, Action: 1, Delta: 0.0
# Perform Episode - Update Type 3 - State: 15, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 15: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 16, Action: 2, Delta: 0.0
# Perform Episode - Update Type 3 - State: 16, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 16: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 21, Action: 2, Delta: 0.0
# Perform Episode - Update Type 3 - State: 21, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 21: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 21, Action: 3, Delta: 0.0
# Perform Episode - Update Type 3 - State: 21, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 21: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 16, Action: 1, Delta: 0.0
# Perform Episode - Update Type 3 - State: 16, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 16: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 6/30
# Step: 0, State: 2, Terminated: False, Truncated: False
# delta (3) - State: 2, Action: 3, Delta: 0.0
# Perform Episode - Update Type 3 - State: 2, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 2: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 2, Action: 3, Delta: 0.0
# Perform Episode - Update Type 3 - State: 2, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 2: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 2, Action: 2, Delta: 0.0
# Perform Episode - Update Type 3 - State: 2, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 2: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 7, Action: 3, Delta: 0.0
# Perform Episode - Update Type 3 - State: 7, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 7: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 2, Action: 1, Delta: 0.0
# Perform Episode - Update Type 3 - State: 2, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 2: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 3, Action: 1, Delta: 0.0
# Perform Episode - Update Type 3 - State: 3, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 3: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 7/30
# Step: 0, State: 11, Terminated: False, Truncated: False
# delta (3) - State: 11, Action: 1, Delta: 0.0
# Perform Episode - Update Type 3 - State: 11, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 11: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 12, Action: 3, Delta: 0.0
# Perform Episode - Update Type 3 - State: 12, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 12: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 7, Action: 1, Delta: 0.0
# Perform Episode - Update Type 3 - State: 7, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 7: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 8, Action: 0, Delta: 0.0
# Perform Episode - Update Type 3 - State: 8, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 8: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 7, Action: 1, Delta: 0.0
# Perform Episode - Update Type 3 - State: 7, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 7: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 8, Action: 1, Delta: 0.0
# Perform Episode - Update Type 3 - State: 8, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 8: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 8/30
# Step: 0, State: 2, Terminated: False, Truncated: False
# delta (3) - State: 2, Action: 2, Delta: 0.0
# Perform Episode - Update Type 3 - State: 2, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 2: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 7, Action: 2, Delta: 0.0
# Perform Episode - Update Type 3 - State: 7, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 7: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 12, Action: 1, Delta: 0.0
# Perform Episode - Update Type 3 - State: 12, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 12: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 13, Action: 0, Delta: 0.0
# Perform Episode - Update Type 3 - State: 13, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 13: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 12, Action: 3, Delta: 0.0
# Perform Episode - Update Type 3 - State: 12, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 12: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 7, Action: 0, Delta: 0.0
# Perform Episode - Update Type 3 - State: 7, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 7: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 9/30
# Step: 0, State: 5, Terminated: False, Truncated: False
# delta (3) - State: 5, Action: 1, Delta: 0.0
# Perform Episode - Update Type 3 - State: 5, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 5: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 6, Action: 2, Delta: 0.0
# Perform Episode - Update Type 3 - State: 6, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 6: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 11, Action: 0, Delta: 0.0
# Perform Episode - Update Type 3 - State: 11, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 11: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 10, Action: 2, Delta: 0.0
# Perform Episode - Update Type 3 - State: 10, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 10: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 15, Action: 1, Delta: 0.0
# Perform Episode - Update Type 3 - State: 15, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 15: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 16, Action: 1, Delta: 0.0
# Perform Episode - Update Type 3 - State: 16, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 16: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 10/30
# Step: 0, State: 21, Terminated: False, Truncated: False
# delta (3) - State: 21, Action: 3, Delta: 0.0
# Perform Episode - Update Type 3 - State: 21, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 21: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 16, Action: 0, Delta: 0.0
# Perform Episode - Update Type 3 - State: 16, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 16: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 15, Action: 0, Delta: 0.0
# Perform Episode - Update Type 3 - State: 15, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 15: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 15, Action: 1, Delta: 0.0
# Perform Episode - Update Type 3 - State: 15, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 15: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 16, Action: 0, Delta: 0.0
# Perform Episode - Update Type 3 - State: 16, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 16: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 15, Action: 0, Delta: 0.0
# Perform Episode - Update Type 3 - State: 15, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 15: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 11/30
# Step: 0, State: 18, Terminated: False, Truncated: False
# delta (3) - State: 18, Action: 0, Delta: 0.0
# Perform Episode - Update Type 3 - State: 18, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 18: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 17, Action: 0, Delta: 0.0
# Perform Episode - Update Type 3 - State: 17, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 17: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 16, Action: 2, Delta: 0.0
# Perform Episode - Update Type 3 - State: 16, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 16: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 21, Action: 2, Delta: 0.0
# Perform Episode - Update Type 3 - State: 21, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 21: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 21, Action: 3, Delta: 0.0
# Perform Episode - Update Type 3 - State: 21, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 21: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 16, Action: 1, Delta: 0.0
# Perform Episode - Update Type 3 - State: 16, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 16: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 12/30
# Step: 0, State: 24, Terminated: False, Truncated: False
# delta (3) - State: 24, Action: 1, Delta: 1.0
# Perform Episode - Update Type 3 - State: 24, Sum Q: 0.0, Delta: 1.0
# Policy sum for state 24: 1.0
# Norm of Q-values: 0.01
#  Actor_critic_q function - looping Episode 13/30
# Step: 0, State: 18, Terminated: False, Truncated: False
# delta (3) - State: 18, Action: 2, Delta: 0.0
# Perform Episode - Update Type 3 - State: 18, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 18: 1.0
# Norm of Q-values: 0.01
# delta (3) - State: 23, Action: 0, Delta: 0.0
# Perform Episode - Update Type 3 - State: 23, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 23: 1.0
# Norm of Q-values: 0.01
# delta (3) - State: 22, Action: 0, Delta: 0.0
# Perform Episode - Update Type 3 - State: 22, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 22: 1.0
# Norm of Q-values: 0.01
# delta (3) - State: 21, Action: 0, Delta: 0.0
# Perform Episode - Update Type 3 - State: 21, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 21: 1.0
# Norm of Q-values: 0.01
# delta (3) - State: 20, Action: 0, Delta: 0.0
# Perform Episode - Update Type 3 - State: 20, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 20: 1.0
# Norm of Q-values: 0.01
# delta (3) - State: 20, Action: 1, Delta: 0.0
# Perform Episode - Update Type 3 - State: 20, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 20: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 14/30
# Step: 0, State: 3, Terminated: False, Truncated: False
# delta (3) - State: 3, Action: 1, Delta: 0.0
# Perform Episode - Update Type 3 - State: 3, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 3: 1.0
# Norm of Q-values: 0.01
# delta (3) - State: 4, Action: 3, Delta: 0.0
# Perform Episode - Update Type 3 - State: 4, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 4: 1.0
# Norm of Q-values: 0.01
# delta (3) - State: 4, Action: 1, Delta: 0.0
# Perform Episode - Update Type 3 - State: 4, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 4: 1.0
# Norm of Q-values: 0.01
# delta (3) - State: 4, Action: 2, Delta: 0.0
# Perform Episode - Update Type 3 - State: 4, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 4: 1.0
# Norm of Q-values: 0.01
# delta (3) - State: 9, Action: 0, Delta: 0.0
# Perform Episode - Update Type 3 - State: 9, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 9: 1.0
# Norm of Q-values: 0.01
# delta (3) - State: 8, Action: 3, Delta: 0.0
# Perform Episode - Update Type 3 - State: 8, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 8: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 15/30
# Step: 0, State: 23, Terminated: False, Truncated: False
# delta (3) - State: 23, Action: 2, Delta: 0.0
# Perform Episode - Update Type 3 - State: 23, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 23: 1.0
# Norm of Q-values: 0.01
# delta (3) - State: 23, Action: 0, Delta: 0.0
# Perform Episode - Update Type 3 - State: 23, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 23: 1.0
# Norm of Q-values: 0.01
# delta (3) - State: 22, Action: 1, Delta: 0.0
# Perform Episode - Update Type 3 - State: 22, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 22: 1.0
# Norm of Q-values: 0.01
# delta (3) - State: 23, Action: 3, Delta: 0.0
# Perform Episode - Update Type 3 - State: 23, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 23: 1.0
# Norm of Q-values: 0.01
# delta (3) - State: 18, Action: 2, Delta: 0.0
# Perform Episode - Update Type 3 - State: 18, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 18: 1.0
# Norm of Q-values: 0.01
# delta (3) - State: 23, Action: 1, Delta: 0.009000000000000001
# Perform Episode - Update Type 3 - State: 23, Sum Q: 0.0, Delta: 0.009000000000000001
# Policy sum for state 23: 1.0000000000000002
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 16/30
# Step: 0, State: 14, Terminated: False, Truncated: False
# delta (3) - State: 14, Action: 1, Delta: 0.0
# Perform Episode - Update Type 3 - State: 14, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 14: 1.0
# Norm of Q-values: 0.010000404991799083
# delta (3) - State: 14, Action: 0, Delta: 0.0
# Perform Episode - Update Type 3 - State: 14, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 14: 1.0
# Norm of Q-values: 0.010000404991799083
# delta (3) - State: 13, Action: 2, Delta: 0.0
# Perform Episode - Update Type 3 - State: 13, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 13: 1.0
# Norm of Q-values: 0.010000404991799083
# delta (3) - State: 18, Action: 3, Delta: 0.0
# Perform Episode - Update Type 3 - State: 18, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 18: 1.0
# Norm of Q-values: 0.010000404991799083
# delta (3) - State: 13, Action: 3, Delta: 0.0
# Perform Episode - Update Type 3 - State: 13, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 13: 1.0
# Norm of Q-values: 0.010000404991799083
# delta (3) - State: 8, Action: 2, Delta: 0.0
# Perform Episode - Update Type 3 - State: 8, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 8: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 17/30
# Step: 0, State: 11, Terminated: False, Truncated: False
# delta (3) - State: 11, Action: 1, Delta: 0.0
# Perform Episode - Update Type 3 - State: 11, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 11: 1.0
# Norm of Q-values: 0.010000404991799083
# delta (3) - State: 12, Action: 2, Delta: 0.0
# Perform Episode - Update Type 3 - State: 12, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 12: 1.0
# Norm of Q-values: 0.010000404991799083
# delta (3) - State: 17, Action: 1, Delta: 0.0
# Perform Episode - Update Type 3 - State: 17, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 17: 1.0
# Norm of Q-values: 0.010000404991799083
# delta (3) - State: 18, Action: 2, Delta: 8.1e-05
# Perform Episode - Update Type 3 - State: 18, Sum Q: 0.0, Delta: 8.1e-05
# Policy sum for state 18: 1.0
# Norm of Q-values: 0.010000405024602754
# delta (3) - State: 23, Action: 2, Delta: 5.84939255467008e-05
# Perform Episode - Update Type 3 - State: 23, Sum Q: 2.2506074453299206e-05, Delta: 5.84939255467008e-05
# Policy sum for state 23: 0.9999999999999998
# Norm of Q-values: 0.010000405041709758
# delta (3) - State: 23, Action: 2, Delta: 5.834771680083864e-05
# Perform Episode - Update Type 3 - State: 23, Sum Q: 2.2652283199161366e-05, Delta: 5.834771680083864e-05
# Policy sum for state 23: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 18/30
# Step: 0, State: 11, Terminated: False, Truncated: False
# delta (3) - State: 11, Action: 2, Delta: 0.0
# Perform Episode - Update Type 3 - State: 11, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 11: 1.0
# Norm of Q-values: 0.010000405092859835
# delta (3) - State: 16, Action: 1, Delta: 0.0
# Perform Episode - Update Type 3 - State: 16, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 16: 1.0
# Norm of Q-values: 0.010000405092859835
# delta (3) - State: 17, Action: 3, Delta: 0.0
# Perform Episode - Update Type 3 - State: 17, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 17: 1.0
# Norm of Q-values: 0.010000405092859835
# delta (3) - State: 12, Action: 0, Delta: 0.0
# Perform Episode - Update Type 3 - State: 12, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 12: 1.0
# Norm of Q-values: 0.010000405092859835
# delta (3) - State: 11, Action: 3, Delta: 0.0
# Perform Episode - Update Type 3 - State: 11, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 11: 1.0
# Norm of Q-values: 0.010000405092859835
# delta (3) - State: 6, Action: 1, Delta: 0.0
# Perform Episode - Update Type 3 - State: 6, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 6: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 19/30
# Step: 0, State: 11, Terminated: False, Truncated: False
# delta (3) - State: 11, Action: 0, Delta: 0.0
# Perform Episode - Update Type 3 - State: 11, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 11: 1.0
# Norm of Q-values: 0.010000405092859835
# delta (3) - State: 10, Action: 1, Delta: 0.0
# Perform Episode - Update Type 3 - State: 10, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 10: 1.0
# Norm of Q-values: 0.010000405092859835
# delta (3) - State: 11, Action: 0, Delta: 0.0
# Perform Episode - Update Type 3 - State: 11, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 11: 1.0
# Norm of Q-values: 0.010000405092859835
# delta (3) - State: 10, Action: 3, Delta: 0.0
# Perform Episode - Update Type 3 - State: 10, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 10: 1.0
# Norm of Q-values: 0.010000405092859835
# delta (3) - State: 5, Action: 3, Delta: 0.0
# Perform Episode - Update Type 3 - State: 5, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 5: 1.0
# Norm of Q-values: 0.010000405092859835
# delta (3) - State: 0, Action: 2, Delta: 0.0
# Perform Episode - Update Type 3 - State: 0, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 0: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 20/30
# Step: 0, State: 16, Terminated: False, Truncated: False
# delta (3) - State: 16, Action: 3, Delta: 0.0
# Perform Episode - Update Type 3 - State: 16, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 16: 1.0
# Norm of Q-values: 0.010000405092859835
# delta (3) - State: 11, Action: 0, Delta: 0.0
# Perform Episode - Update Type 3 - State: 11, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 11: 1.0
# Norm of Q-values: 0.010000405092859835
# delta (3) - State: 10, Action: 1, Delta: 0.0
# Perform Episode - Update Type 3 - State: 10, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 10: 1.0
# Norm of Q-values: 0.010000405092859835
# delta (3) - State: 11, Action: 1, Delta: 0.0
# Perform Episode - Update Type 3 - State: 11, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 11: 1.0
# Norm of Q-values: 0.010000405092859835
# delta (3) - State: 12, Action: 1, Delta: 0.0
# Perform Episode - Update Type 3 - State: 12, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 12: 1.0
# Norm of Q-values: 0.010000405092859835
# delta (3) - State: 13, Action: 3, Delta: 0.0
# Perform Episode - Update Type 3 - State: 13, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 13: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 21/30
# Step: 0, State: 14, Terminated: False, Truncated: False
# delta (3) - State: 14, Action: 1, Delta: 0.0
# Perform Episode - Update Type 3 - State: 14, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 14: 1.0
# Norm of Q-values: 0.010000405092859835
# delta (3) - State: 14, Action: 2, Delta: 0.0
# Perform Episode - Update Type 3 - State: 14, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 14: 1.0
# Norm of Q-values: 0.010000405092859835
# delta (3) - State: 19, Action: 3, Delta: 0.0
# Perform Episode - Update Type 3 - State: 19, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 19: 1.0
# Norm of Q-values: 0.010000405092859835
# delta (3) - State: 14, Action: 0, Delta: 0.0
# Perform Episode - Update Type 3 - State: 14, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 14: 1.0
# Norm of Q-values: 0.010000405092859835
# delta (3) - State: 13, Action: 1, Delta: 0.0
# Perform Episode - Update Type 3 - State: 13, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 13: 1.0
# Norm of Q-values: 0.010000405092859835
# delta (3) - State: 14, Action: 2, Delta: 0.0
# Perform Episode - Update Type 3 - State: 14, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 14: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 22/30
# Step: 0, State: 19, Terminated: False, Truncated: False
# delta (3) - State: 19, Action: 3, Delta: 0.0
# Perform Episode - Update Type 3 - State: 19, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 19: 1.0
# Norm of Q-values: 0.010000405092859835
# delta (3) - State: 14, Action: 3, Delta: 0.0
# Perform Episode - Update Type 3 - State: 14, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 14: 1.0
# Norm of Q-values: 0.010000405092859835
# delta (3) - State: 9, Action: 1, Delta: 0.0
# Perform Episode - Update Type 3 - State: 9, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 9: 1.0
# Norm of Q-values: 0.010000405092859835
# delta (3) - State: 9, Action: 1, Delta: 0.0
# Perform Episode - Update Type 3 - State: 9, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 9: 1.0
# Norm of Q-values: 0.010000405092859835
# delta (3) - State: 9, Action: 2, Delta: 0.0
# Perform Episode - Update Type 3 - State: 9, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 9: 1.0
# Norm of Q-values: 0.010000405092859835
# delta (3) - State: 14, Action: 1, Delta: 0.0
# Perform Episode - Update Type 3 - State: 14, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 14: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 23/30
# Step: 0, State: 17, Terminated: False, Truncated: False
# delta (3) - State: 17, Action: 0, Delta: 0.0
# Perform Episode - Update Type 3 - State: 17, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 17: 1.0
# Norm of Q-values: 0.010000405092859835
# delta (3) - State: 16, Action: 2, Delta: 0.0
# Perform Episode - Update Type 3 - State: 16, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 16: 1.0
# Norm of Q-values: 0.010000405092859835
# delta (3) - State: 21, Action: 1, Delta: 0.0
# Perform Episode - Update Type 3 - State: 21, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 21: 1.0
# Norm of Q-values: 0.010000405092859835
# delta (3) - State: 22, Action: 0, Delta: 0.0
# Perform Episode - Update Type 3 - State: 22, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 22: 1.0
# Norm of Q-values: 0.010000405092859835
# delta (3) - State: 21, Action: 3, Delta: 0.0
# Perform Episode - Update Type 3 - State: 21, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 21: 1.0
# Norm of Q-values: 0.010000405092859835
# delta (3) - State: 16, Action: 1, Delta: 0.0
# Perform Episode - Update Type 3 - State: 16, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 16: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 24/30
# Step: 0, State: 23, Terminated: False, Truncated: False
# delta (3) - State: 23, Action: 0, Delta: -2.2798126999647904e-05
# Perform Episode - Update Type 3 - State: 23, Sum Q: 2.2798126999647904e-05, Delta: -2.2798126999647904e-05
# Policy sum for state 23: 1.0
# Norm of Q-values: 0.010000405095458503
# delta (3) - State: 22, Action: 2, Delta: 0.0
# Perform Episode - Update Type 3 - State: 22, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 22: 1.0
# Norm of Q-values: 0.010000405095458503
# delta (3) - State: 22, Action: 2, Delta: 0.0
# Perform Episode - Update Type 3 - State: 22, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 22: 1.0
# Norm of Q-values: 0.010000405095458503
# delta (3) - State: 22, Action: 3, Delta: 0.0
# Perform Episode - Update Type 3 - State: 22, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 22: 1.0
# Norm of Q-values: 0.010000405095458503
# delta (3) - State: 17, Action: 0, Delta: 0.0
# Perform Episode - Update Type 3 - State: 17, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 17: 1.0
# Norm of Q-values: 0.010000405095458503
# delta (3) - State: 16, Action: 2, Delta: 0.0
# Perform Episode - Update Type 3 - State: 16, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 16: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 25/30
# Step: 0, State: 14, Terminated: False, Truncated: False
# delta (3) - State: 14, Action: 0, Delta: 0.0
# Perform Episode - Update Type 3 - State: 14, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 14: 1.0
# Norm of Q-values: 0.010000405095458503
# delta (3) - State: 13, Action: 3, Delta: 0.0
# Perform Episode - Update Type 3 - State: 13, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 13: 1.0
# Norm of Q-values: 0.010000405095458503
# delta (3) - State: 8, Action: 3, Delta: 0.0
# Perform Episode - Update Type 3 - State: 8, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 8: 1.0
# Norm of Q-values: 0.010000405095458503
# delta (3) - State: 3, Action: 0, Delta: 0.0
# Perform Episode - Update Type 3 - State: 3, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 3: 1.0
# Norm of Q-values: 0.010000405095458503
# delta (3) - State: 2, Action: 0, Delta: 0.0
# Perform Episode - Update Type 3 - State: 2, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 2: 1.0
# Norm of Q-values: 0.010000405095458503
# delta (3) - State: 1, Action: 1, Delta: 0.0
# Perform Episode - Update Type 3 - State: 1, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 1: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 26/30
# Step: 0, State: 11, Terminated: False, Truncated: False
# delta (3) - State: 11, Action: 1, Delta: 0.0
# Perform Episode - Update Type 3 - State: 11, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 11: 1.0
# Norm of Q-values: 0.010000405095458503
# delta (3) - State: 12, Action: 2, Delta: 0.0
# Perform Episode - Update Type 3 - State: 12, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 12: 1.0
# Norm of Q-values: 0.010000405095458503
# delta (3) - State: 17, Action: 3, Delta: 0.0
# Perform Episode - Update Type 3 - State: 17, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 17: 1.0
# Norm of Q-values: 0.010000405095458503
# delta (3) - State: 12, Action: 1, Delta: 0.0
# Perform Episode - Update Type 3 - State: 12, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 12: 1.0
# Norm of Q-values: 0.010000405095458503
# delta (3) - State: 13, Action: 0, Delta: 0.0
# Perform Episode - Update Type 3 - State: 13, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 13: 1.0
# Norm of Q-values: 0.010000405095458503
# delta (3) - State: 12, Action: 0, Delta: 0.0
# Perform Episode - Update Type 3 - State: 12, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 12: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 27/30
# Step: 0, State: 20, Terminated: False, Truncated: False
# delta (3) - State: 20, Action: 0, Delta: 0.0
# Perform Episode - Update Type 3 - State: 20, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 20: 1.0
# Norm of Q-values: 0.010000405095458503
# delta (3) - State: 20, Action: 2, Delta: 0.0
# Perform Episode - Update Type 3 - State: 20, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 20: 1.0
# Norm of Q-values: 0.010000405095458503
# delta (3) - State: 20, Action: 3, Delta: 0.0
# Perform Episode - Update Type 3 - State: 20, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 20: 1.0
# Norm of Q-values: 0.010000405095458503
# delta (3) - State: 15, Action: 2, Delta: 0.0
# Perform Episode - Update Type 3 - State: 15, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 15: 1.0
# Norm of Q-values: 0.010000405095458503
# delta (3) - State: 20, Action: 1, Delta: 0.0
# Perform Episode - Update Type 3 - State: 20, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 20: 1.0
# Norm of Q-values: 0.010000405095458503
# delta (3) - State: 21, Action: 0, Delta: 0.0
# Perform Episode - Update Type 3 - State: 21, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 21: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 28/30
# Step: 0, State: 6, Terminated: False, Truncated: False
# delta (3) - State: 6, Action: 1, Delta: 0.0
# Perform Episode - Update Type 3 - State: 6, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 6: 1.0
# Norm of Q-values: 0.010000405095458503
# delta (3) - State: 7, Action: 2, Delta: 0.0
# Perform Episode - Update Type 3 - State: 7, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 7: 1.0
# Norm of Q-values: 0.010000405095458503
# delta (3) - State: 12, Action: 3, Delta: 0.0
# Perform Episode - Update Type 3 - State: 12, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 12: 1.0
# Norm of Q-values: 0.010000405095458503
# delta (3) - State: 7, Action: 1, Delta: 0.0
# Perform Episode - Update Type 3 - State: 7, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 7: 1.0
# Norm of Q-values: 0.010000405095458503
# delta (3) - State: 8, Action: 0, Delta: 0.0
# Perform Episode - Update Type 3 - State: 8, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 8: 1.0
# Norm of Q-values: 0.010000405095458503
# delta (3) - State: 7, Action: 2, Delta: 0.0
# Perform Episode - Update Type 3 - State: 7, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 7: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 29/30
# Step: 0, State: 19, Terminated: False, Truncated: False
# delta (3) - State: 19, Action: 3, Delta: 0.0
# Perform Episode - Update Type 3 - State: 19, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 19: 1.0
# Norm of Q-values: 0.010000405095458503
# delta (3) - State: 14, Action: 2, Delta: 0.0
# Perform Episode - Update Type 3 - State: 14, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 14: 1.0
# Norm of Q-values: 0.010000405095458503
# delta (3) - State: 19, Action: 2, Delta: 0.009000000000000001
# Perform Episode - Update Type 3 - State: 19, Sum Q: 0.0, Delta: 0.009000000000000001
# Policy sum for state 19: 1.0
# Norm of Q-values: 0.010000810070852881
# delta (3) - State: 24, Action: 1, Delta: 0.9974257425742574
# Perform Episode - Update Type 3 - State: 24, Sum Q: 0.0025742574257425744, Delta: 0.9974257425742574
# Policy sum for state 24: 1.0
# Norm of Q-values: 0.019974662995482673
#  Actor_critic_q function - looping Episode 30/30
# Step: 0, State: 2, Terminated: False, Truncated: False
# delta (3) - State: 2, Action: 3, Delta: 0.0
# Perform Episode - Update Type 3 - State: 2, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 2: 1.0
# Norm of Q-values: 0.019974662995482673
# delta (3) - State: 2, Action: 2, Delta: 0.0
# Perform Episode - Update Type 3 - State: 2, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 2: 1.0
# Norm of Q-values: 0.019974662995482673
# delta (3) - State: 7, Action: 1, Delta: 0.0
# Perform Episode - Update Type 3 - State: 7, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 7: 1.0
# Norm of Q-values: 0.019974662995482673
# delta (3) - State: 8, Action: 2, Delta: 0.0
# Perform Episode - Update Type 3 - State: 8, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 8: 1.0
# Norm of Q-values: 0.019974662995482673
# delta (3) - State: 13, Action: 1, Delta: 0.0
# Perform Episode - Update Type 3 - State: 13, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 13: 1.0
# Norm of Q-values: 0.019974662995482673
# delta (3) - State: 14, Action: 0, Delta: 0.0
# Perform Episode - Update Type 3 - State: 14, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 14: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 1/30
# Step: 0, State: 2, Terminated: False, Truncated: False
# delta (3) - State: 2, Action: 1, Delta: 0.0
# Perform Episode - Update Type 3 - State: 2, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 2: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 3, Action: 0, Delta: 0.0
# Perform Episode - Update Type 3 - State: 3, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 3: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 2, Action: 1, Delta: 0.0
# Perform Episode - Update Type 3 - State: 2, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 2: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 3, Action: 0, Delta: 0.0
# Perform Episode - Update Type 3 - State: 3, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 3: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 2, Action: 3, Delta: 0.0
# Perform Episode - Update Type 3 - State: 2, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 2: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 2, Action: 2, Delta: 0.0
# Perform Episode - Update Type 3 - State: 2, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 2: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 2/30
# Step: 0, State: 20, Terminated: False, Truncated: False
# delta (3) - State: 20, Action: 3, Delta: 0.0
# Perform Episode - Update Type 3 - State: 20, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 20: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 15, Action: 3, Delta: 0.0
# Perform Episode - Update Type 3 - State: 15, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 15: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 10, Action: 3, Delta: 0.0
# Perform Episode - Update Type 3 - State: 10, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 10: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 5, Action: 3, Delta: 0.0
# Perform Episode - Update Type 3 - State: 5, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 5: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 0, Action: 3, Delta: 0.0
# Perform Episode - Update Type 3 - State: 0, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 0: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 0, Action: 3, Delta: 0.0
# Perform Episode - Update Type 3 - State: 0, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 0: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 3/30
# Step: 0, State: 18, Terminated: False, Truncated: False
# delta (3) - State: 18, Action: 1, Delta: 0.0
# Perform Episode - Update Type 3 - State: 18, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 18: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 19, Action: 3, Delta: 0.0
# Perform Episode - Update Type 3 - State: 19, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 19: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 14, Action: 2, Delta: 0.0
# Perform Episode - Update Type 3 - State: 14, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 14: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 19, Action: 3, Delta: 0.0
# Perform Episode - Update Type 3 - State: 19, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 19: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 14, Action: 0, Delta: 0.0
# Perform Episode - Update Type 3 - State: 14, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 14: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 13, Action: 1, Delta: 0.0
# Perform Episode - Update Type 3 - State: 13, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 13: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 4/30
# Step: 0, State: 21, Terminated: False, Truncated: False
# delta (3) - State: 21, Action: 2, Delta: 0.0
# Perform Episode - Update Type 3 - State: 21, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 21: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 21, Action: 0, Delta: 0.0
# Perform Episode - Update Type 3 - State: 21, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 21: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 20, Action: 1, Delta: 0.0
# Perform Episode - Update Type 3 - State: 20, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 20: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 21, Action: 0, Delta: 0.0
# Perform Episode - Update Type 3 - State: 21, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 21: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 20, Action: 0, Delta: 0.0
# Perform Episode - Update Type 3 - State: 20, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 20: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 20, Action: 3, Delta: 0.0
# Perform Episode - Update Type 3 - State: 20, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 20: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 5/30
# Step: 0, State: 21, Terminated: False, Truncated: False
# delta (3) - State: 21, Action: 2, Delta: 0.0
# Perform Episode - Update Type 3 - State: 21, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 21: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 21, Action: 3, Delta: 0.0
# Perform Episode - Update Type 3 - State: 21, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 21: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 16, Action: 2, Delta: 0.0
# Perform Episode - Update Type 3 - State: 16, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 16: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 21, Action: 0, Delta: 0.0
# Perform Episode - Update Type 3 - State: 21, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 21: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 20, Action: 0, Delta: 0.0
# Perform Episode - Update Type 3 - State: 20, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 20: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 20, Action: 1, Delta: 0.0
# Perform Episode - Update Type 3 - State: 20, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 20: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 6/30
# Step: 0, State: 23, Terminated: False, Truncated: False
# delta (3) - State: 23, Action: 2, Delta: 0.0
# Perform Episode - Update Type 3 - State: 23, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 23: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 23, Action: 3, Delta: 0.0
# Perform Episode - Update Type 3 - State: 23, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 23: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 18, Action: 0, Delta: 0.0
# Perform Episode - Update Type 3 - State: 18, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 18: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 17, Action: 0, Delta: 0.0
# Perform Episode - Update Type 3 - State: 17, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 17: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 16, Action: 0, Delta: 0.0
# Perform Episode - Update Type 3 - State: 16, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 16: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 15, Action: 3, Delta: 0.0
# Perform Episode - Update Type 3 - State: 15, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 15: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 7/30
# Step: 0, State: 12, Terminated: False, Truncated: False
# delta (3) - State: 12, Action: 3, Delta: 0.0
# Perform Episode - Update Type 3 - State: 12, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 12: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 7, Action: 1, Delta: 0.0
# Perform Episode - Update Type 3 - State: 7, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 7: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 8, Action: 3, Delta: 0.0
# Perform Episode - Update Type 3 - State: 8, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 8: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 3, Action: 0, Delta: 0.0
# Perform Episode - Update Type 3 - State: 3, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 3: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 2, Action: 3, Delta: 0.0
# Perform Episode - Update Type 3 - State: 2, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 2: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 2, Action: 0, Delta: 0.0
# Perform Episode - Update Type 3 - State: 2, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 2: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 8/30
# Step: 0, State: 24, Terminated: False, Truncated: False
# delta (3) - State: 24, Action: 1, Delta: 1.0
# Perform Episode - Update Type 3 - State: 24, Sum Q: 0.0, Delta: 1.0
# Policy sum for state 24: 1.0
# Norm of Q-values: 0.01
#  Actor_critic_q function - looping Episode 9/30
# Step: 0, State: 24, Terminated: False, Truncated: False
# delta (3) - State: 24, Action: 3, Delta: 0.9974257425742574
# Perform Episode - Update Type 3 - State: 24, Sum Q: 0.0025742574257425744, Delta: 0.9974257425742574
# Policy sum for state 24: 1.0
# Norm of Q-values: 0.01412394460464147
#  Actor_critic_q function - looping Episode 10/30
# Step: 0, State: 6, Terminated: False, Truncated: False
# delta (3) - State: 6, Action: 3, Delta: 0.0
# Perform Episode - Update Type 3 - State: 6, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 6: 1.0
# Norm of Q-values: 0.01412394460464147
# delta (3) - State: 1, Action: 2, Delta: 0.0
# Perform Episode - Update Type 3 - State: 1, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 1: 1.0
# Norm of Q-values: 0.01412394460464147
# delta (3) - State: 6, Action: 0, Delta: 0.0
# Perform Episode - Update Type 3 - State: 6, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 6: 1.0
# Norm of Q-values: 0.01412394460464147
# delta (3) - State: 5, Action: 0, Delta: 0.0
# Perform Episode - Update Type 3 - State: 5, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 5: 1.0
# Norm of Q-values: 0.01412394460464147
# delta (3) - State: 5, Action: 3, Delta: 0.0
# Perform Episode - Update Type 3 - State: 5, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 5: 1.0
# Norm of Q-values: 0.01412394460464147
# delta (3) - State: 0, Action: 2, Delta: 0.0
# Perform Episode - Update Type 3 - State: 0, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 0: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 11/30
# Step: 0, State: 21, Terminated: False, Truncated: False
# delta (3) - State: 21, Action: 2, Delta: 0.0
# Perform Episode - Update Type 3 - State: 21, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 21: 1.0
# Norm of Q-values: 0.01412394460464147
# delta (3) - State: 21, Action: 3, Delta: 0.0
# Perform Episode - Update Type 3 - State: 21, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 21: 1.0
# Norm of Q-values: 0.01412394460464147
# delta (3) - State: 16, Action: 3, Delta: 0.0
# Perform Episode - Update Type 3 - State: 16, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 16: 1.0
# Norm of Q-values: 0.01412394460464147
# delta (3) - State: 11, Action: 3, Delta: 0.0
# Perform Episode - Update Type 3 - State: 11, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 11: 1.0
# Norm of Q-values: 0.01412394460464147
# delta (3) - State: 6, Action: 2, Delta: 0.0
# Perform Episode - Update Type 3 - State: 6, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 6: 1.0
# Norm of Q-values: 0.01412394460464147
# delta (3) - State: 11, Action: 1, Delta: 0.0
# Perform Episode - Update Type 3 - State: 11, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 11: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 12/30
# Step: 0, State: 15, Terminated: False, Truncated: False
# delta (3) - State: 15, Action: 3, Delta: 0.0
# Perform Episode - Update Type 3 - State: 15, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 15: 1.0
# Norm of Q-values: 0.01412394460464147
# delta (3) - State: 10, Action: 2, Delta: 0.0
# Perform Episode - Update Type 3 - State: 10, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 10: 1.0
# Norm of Q-values: 0.01412394460464147
# delta (3) - State: 15, Action: 3, Delta: 0.0
# Perform Episode - Update Type 3 - State: 15, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 15: 1.0
# Norm of Q-values: 0.01412394460464147
# delta (3) - State: 10, Action: 2, Delta: 0.0
# Perform Episode - Update Type 3 - State: 10, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 10: 1.0
# Norm of Q-values: 0.01412394460464147
# delta (3) - State: 15, Action: 0, Delta: 0.0
# Perform Episode - Update Type 3 - State: 15, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 15: 1.0
# Norm of Q-values: 0.01412394460464147
# delta (3) - State: 15, Action: 3, Delta: 0.0
# Perform Episode - Update Type 3 - State: 15, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 15: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 13/30
# Step: 0, State: 0, Terminated: False, Truncated: False
# delta (3) - State: 0, Action: 2, Delta: 0.0
# Perform Episode - Update Type 3 - State: 0, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 0: 1.0
# Norm of Q-values: 0.01412394460464147
# delta (3) - State: 5, Action: 2, Delta: 0.0
# Perform Episode - Update Type 3 - State: 5, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 5: 1.0
# Norm of Q-values: 0.01412394460464147
# delta (3) - State: 10, Action: 0, Delta: 0.0
# Perform Episode - Update Type 3 - State: 10, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 10: 1.0
# Norm of Q-values: 0.01412394460464147
# delta (3) - State: 10, Action: 3, Delta: 0.0
# Perform Episode - Update Type 3 - State: 10, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 10: 1.0
# Norm of Q-values: 0.01412394460464147
# delta (3) - State: 5, Action: 3, Delta: 0.0
# Perform Episode - Update Type 3 - State: 5, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 5: 1.0
# Norm of Q-values: 0.01412394460464147
# delta (3) - State: 0, Action: 3, Delta: 0.0
# Perform Episode - Update Type 3 - State: 0, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 0: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 14/30
# Step: 0, State: 15, Terminated: False, Truncated: False
# delta (3) - State: 15, Action: 1, Delta: 0.0
# Perform Episode - Update Type 3 - State: 15, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 15: 1.0
# Norm of Q-values: 0.01412394460464147
# delta (3) - State: 16, Action: 2, Delta: 0.0
# Perform Episode - Update Type 3 - State: 16, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 16: 1.0
# Norm of Q-values: 0.01412394460464147
# delta (3) - State: 21, Action: 2, Delta: 0.0
# Perform Episode - Update Type 3 - State: 21, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 21: 1.0
# Norm of Q-values: 0.01412394460464147
# delta (3) - State: 21, Action: 0, Delta: 0.0
# Perform Episode - Update Type 3 - State: 21, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 21: 1.0
# Norm of Q-values: 0.01412394460464147
# delta (3) - State: 20, Action: 3, Delta: 0.0
# Perform Episode - Update Type 3 - State: 20, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 20: 1.0
# Norm of Q-values: 0.01412394460464147
# delta (3) - State: 15, Action: 2, Delta: 0.0
# Perform Episode - Update Type 3 - State: 15, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 15: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 15/30
# Step: 0, State: 9, Terminated: False, Truncated: False
# delta (3) - State: 9, Action: 3, Delta: 0.0
# Perform Episode - Update Type 3 - State: 9, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 9: 1.0
# Norm of Q-values: 0.01412394460464147
# delta (3) - State: 4, Action: 1, Delta: 0.0
# Perform Episode - Update Type 3 - State: 4, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 4: 1.0
# Norm of Q-values: 0.01412394460464147
# delta (3) - State: 4, Action: 3, Delta: 0.0
# Perform Episode - Update Type 3 - State: 4, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 4: 1.0
# Norm of Q-values: 0.01412394460464147
# delta (3) - State: 4, Action: 2, Delta: 0.0
# Perform Episode - Update Type 3 - State: 4, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 4: 1.0
# Norm of Q-values: 0.01412394460464147
# delta (3) - State: 9, Action: 1, Delta: 0.0
# Perform Episode - Update Type 3 - State: 9, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 9: 1.0
# Norm of Q-values: 0.01412394460464147
# delta (3) - State: 9, Action: 3, Delta: 0.0
# Perform Episode - Update Type 3 - State: 9, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 9: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 16/30
# Step: 0, State: 1, Terminated: False, Truncated: False
# delta (3) - State: 1, Action: 1, Delta: 0.0
# Perform Episode - Update Type 3 - State: 1, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 1: 1.0
# Norm of Q-values: 0.01412394460464147
# delta (3) - State: 2, Action: 3, Delta: 0.0
# Perform Episode - Update Type 3 - State: 2, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 2: 1.0
# Norm of Q-values: 0.01412394460464147
# delta (3) - State: 2, Action: 0, Delta: 0.0
# Perform Episode - Update Type 3 - State: 2, Sum Q: 0.0, Delta: 0.0
# ...
# Policy sum for state 12: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 7, Action: 2, Delta: 0.0
# Policy sum for state 7: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 12, Action: 1, Delta: 0.0
# Policy sum for state 12: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 13, Action: 3, Delta: 0.0
# Policy sum for state 13: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 9/30
# Step: 0, State: 17, Terminated: False, Truncated: False
# delta (4) - State: 17, Action: 2, Delta: 0.0
# Policy sum for state 17: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 22, Action: 2, Delta: 0.0
# Policy sum for state 22: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 22, Action: 0, Delta: 0.0
# Policy sum for state 22: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 21, Action: 0, Delta: 0.0
# Policy sum for state 21: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 20, Action: 0, Delta: 0.0
# Policy sum for state 20: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 20, Action: 3, Delta: 0.0
# Policy sum for state 20: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 10/30
# Step: 0, State: 21, Terminated: False, Truncated: False
# delta (4) - State: 21, Action: 3, Delta: 0.0
# Policy sum for state 21: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 16, Action: 3, Delta: 0.0
# Policy sum for state 16: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 11, Action: 2, Delta: 0.0
# Policy sum for state 11: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 16, Action: 2, Delta: 0.0
# Policy sum for state 16: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 21, Action: 0, Delta: 0.0
# Policy sum for state 21: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 20, Action: 0, Delta: 0.0
# Policy sum for state 20: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 11/30
# Step: 0, State: 20, Terminated: False, Truncated: False
# delta (4) - State: 20, Action: 3, Delta: 0.0
# Policy sum for state 20: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 15, Action: 1, Delta: 0.0
# Policy sum for state 15: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 16, Action: 2, Delta: 0.0
# Policy sum for state 16: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 21, Action: 2, Delta: 0.0
# Policy sum for state 21: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 21, Action: 0, Delta: 0.0
# Policy sum for state 21: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 20, Action: 1, Delta: 0.0
# Policy sum for state 20: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 12/30
# Step: 0, State: 15, Terminated: False, Truncated: False
# delta (4) - State: 15, Action: 0, Delta: 0.0
# Policy sum for state 15: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 15, Action: 0, Delta: 0.0
# Policy sum for state 15: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 15, Action: 3, Delta: 0.0
# Policy sum for state 15: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 10, Action: 1, Delta: 0.0
# Policy sum for state 10: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 11, Action: 0, Delta: 0.0
# Policy sum for state 11: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 10, Action: 0, Delta: 0.0
# Policy sum for state 10: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 13/30
# Step: 0, State: 4, Terminated: False, Truncated: False
# delta (4) - State: 4, Action: 2, Delta: 0.0
# Policy sum for state 4: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 9, Action: 1, Delta: 0.0
# Policy sum for state 9: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 9, Action: 1, Delta: 0.0
# Policy sum for state 9: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 9, Action: 3, Delta: 0.0
# Policy sum for state 9: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 4, Action: 1, Delta: 0.0
# Policy sum for state 4: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 4, Action: 1, Delta: 0.0
# Policy sum for state 4: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 14/30
# Step: 0, State: 22, Terminated: False, Truncated: False
# delta (4) - State: 22, Action: 1, Delta: 0.0
# Policy sum for state 22: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 23, Action: 0, Delta: 0.0
# Policy sum for state 23: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 22, Action: 3, Delta: 0.0
# Policy sum for state 22: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 17, Action: 1, Delta: 0.0
# Policy sum for state 17: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 18, Action: 0, Delta: 0.0
# Policy sum for state 18: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 17, Action: 0, Delta: 0.0
# Policy sum for state 17: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 15/30
# Step: 0, State: 17, Terminated: False, Truncated: False
# delta (4) - State: 17, Action: 0, Delta: 0.0
# Policy sum for state 17: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 16, Action: 0, Delta: 0.0
# Policy sum for state 16: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 15, Action: 1, Delta: 0.0
# Policy sum for state 15: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 16, Action: 1, Delta: 0.0
# Policy sum for state 16: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 17, Action: 2, Delta: 0.0
# Policy sum for state 17: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 22, Action: 1, Delta: 0.0
# Policy sum for state 22: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 16/30
# Step: 0, State: 14, Terminated: False, Truncated: False
# delta (4) - State: 14, Action: 1, Delta: 0.0
# Policy sum for state 14: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 14, Action: 2, Delta: 0.0
# Policy sum for state 14: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 19, Action: 2, Delta: 0.0
# Policy sum for state 19: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 24, Action: 2, Delta: 1.0
# Policy sum for state 24: 1.0
# Norm of Q-values: 0.01
#  Actor_critic_q function - looping Episode 17/30
# Step: 0, State: 24, Terminated: False, Truncated: False
# delta (4) - State: 24, Action: 1, Delta: 1.0
# Policy sum for state 24: 0.9999999999999999
# Norm of Q-values: 0.01414213562373095
#  Actor_critic_q function - looping Episode 18/30
# Step: 0, State: 20, Terminated: False, Truncated: False
# delta (4) - State: 20, Action: 1, Delta: 0.0
# Policy sum for state 20: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 21, Action: 1, Delta: 0.0
# Policy sum for state 21: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 22, Action: 2, Delta: 0.0
# Policy sum for state 22: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 22, Action: 2, Delta: 0.0
# Policy sum for state 22: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 22, Action: 2, Delta: 0.0
# Policy sum for state 22: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 22, Action: 3, Delta: 0.0
# Policy sum for state 22: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 19/30
# Step: 0, State: 17, Terminated: False, Truncated: False
# delta (4) - State: 17, Action: 0, Delta: 0.0
# Policy sum for state 17: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 16, Action: 1, Delta: 0.0
# Policy sum for state 16: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 17, Action: 0, Delta: 0.0
# Policy sum for state 17: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 16, Action: 2, Delta: 0.0
# Policy sum for state 16: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 21, Action: 0, Delta: 0.0
# Policy sum for state 21: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 20, Action: 1, Delta: 0.0
# Policy sum for state 20: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 20/30
# Step: 0, State: 5, Terminated: False, Truncated: False
# delta (4) - State: 5, Action: 3, Delta: 0.0
# Policy sum for state 5: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 0, Action: 3, Delta: 0.0
# Policy sum for state 0: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 0, Action: 1, Delta: 0.0
# Policy sum for state 0: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 1, Action: 1, Delta: 0.0
# Policy sum for state 1: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 2, Action: 3, Delta: 0.0
# Policy sum for state 2: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 2, Action: 3, Delta: 0.0
# Policy sum for state 2: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 21/30
# Step: 0, State: 13, Terminated: False, Truncated: False
# delta (4) - State: 13, Action: 0, Delta: 0.0
# Policy sum for state 13: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 12, Action: 0, Delta: 0.0
# Policy sum for state 12: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 11, Action: 3, Delta: 0.0
# Policy sum for state 11: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 6, Action: 1, Delta: 0.0
# Policy sum for state 6: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 7, Action: 1, Delta: 0.0
# Policy sum for state 7: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 8, Action: 2, Delta: 0.0
# Policy sum for state 8: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 22/30
# Step: 0, State: 17, Terminated: False, Truncated: False
# delta (4) - State: 17, Action: 1, Delta: 0.0
# Policy sum for state 17: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 18, Action: 3, Delta: 0.0
# Policy sum for state 18: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 13, Action: 0, Delta: 0.0
# Policy sum for state 13: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 12, Action: 3, Delta: 0.0
# Policy sum for state 12: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 7, Action: 1, Delta: 0.0
# Policy sum for state 7: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 8, Action: 0, Delta: 0.0
# Policy sum for state 8: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 23/30
# Step: 0, State: 12, Terminated: False, Truncated: False
# delta (4) - State: 12, Action: 0, Delta: 0.0
# Policy sum for state 12: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 11, Action: 1, Delta: 0.0
# Policy sum for state 11: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 12, Action: 0, Delta: 0.0
# Policy sum for state 12: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 11, Action: 1, Delta: 0.0
# Policy sum for state 11: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 12, Action: 3, Delta: 0.0
# Policy sum for state 12: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 7, Action: 3, Delta: 0.0
# Policy sum for state 7: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 24/30
# Step: 0, State: 15, Terminated: False, Truncated: False
# delta (4) - State: 15, Action: 3, Delta: 0.0
# Policy sum for state 15: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 10, Action: 3, Delta: 0.0
# Policy sum for state 10: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 5, Action: 2, Delta: 0.0
# Policy sum for state 5: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 10, Action: 0, Delta: 0.0
# Policy sum for state 10: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 10, Action: 0, Delta: 0.0
# Policy sum for state 10: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 10, Action: 0, Delta: 0.0
# Policy sum for state 10: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 25/30
# Step: 0, State: 7, Terminated: False, Truncated: False
# delta (4) - State: 7, Action: 0, Delta: 0.0
# Policy sum for state 7: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 6, Action: 0, Delta: 0.0
# Policy sum for state 6: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 5, Action: 0, Delta: 0.0
# Policy sum for state 5: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 5, Action: 2, Delta: 0.0
# Policy sum for state 5: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 10, Action: 3, Delta: 0.0
# Policy sum for state 10: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 5, Action: 1, Delta: 0.0
# Policy sum for state 5: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 26/30
# Step: 0, State: 23, Terminated: False, Truncated: False
# delta (4) - State: 23, Action: 0, Delta: 0.0
# Policy sum for state 23: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 22, Action: 1, Delta: 0.0
# Policy sum for state 22: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 23, Action: 0, Delta: 0.0
# Policy sum for state 23: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 22, Action: 3, Delta: 0.0
# Policy sum for state 22: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 17, Action: 0, Delta: 0.0
# Policy sum for state 17: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 16, Action: 1, Delta: 0.0
# Policy sum for state 16: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 27/30
# Step: 0, State: 18, Terminated: False, Truncated: False
# delta (4) - State: 18, Action: 0, Delta: 0.0
# Policy sum for state 18: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 17, Action: 1, Delta: 0.0
# Policy sum for state 17: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 18, Action: 3, Delta: 0.0
# Policy sum for state 18: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 13, Action: 1, Delta: 0.0
# Policy sum for state 13: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 14, Action: 0, Delta: 0.0
# Policy sum for state 14: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 13, Action: 1, Delta: 0.0
# Policy sum for state 13: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 28/30
# Step: 0, State: 24, Terminated: False, Truncated: False
# delta (4) - State: 24, Action: 0, Delta: 1.0
# Policy sum for state 24: 1.0000000000000002
# Norm of Q-values: 0.017320508075688773
#  Actor_critic_q function - looping Episode 29/30
# Step: 0, State: 19, Terminated: False, Truncated: False
# delta (4) - State: 19, Action: 1, Delta: 0.0
# Policy sum for state 19: 1.0
# Norm of Q-values: 0.017320508075688773
# delta (4) - State: 19, Action: 3, Delta: 0.0
# Policy sum for state 19: 1.0
# Norm of Q-values: 0.017320508075688773
# delta (4) - State: 14, Action: 1, Delta: 0.0
# Policy sum for state 14: 1.0
# Norm of Q-values: 0.017320508075688773
# delta (4) - State: 14, Action: 0, Delta: 0.0
# Policy sum for state 14: 1.0
# Norm of Q-values: 0.017320508075688773
# delta (4) - State: 13, Action: 1, Delta: 0.0
# Policy sum for state 13: 1.0
# Norm of Q-values: 0.017320508075688773
# delta (4) - State: 14, Action: 2, Delta: 0.0
# Policy sum for state 14: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 30/30
# Step: 0, State: 14, Terminated: False, Truncated: False
# delta (4) - State: 14, Action: 1, Delta: 0.0
# Policy sum for state 14: 1.0
# Norm of Q-values: 0.017320508075688773
# delta (4) - State: 14, Action: 3, Delta: 0.0
# Policy sum for state 14: 1.0
# Norm of Q-values: 0.017320508075688773
# delta (4) - State: 9, Action: 3, Delta: 0.0
# Policy sum for state 9: 1.0
# Norm of Q-values: 0.017320508075688773
# delta (4) - State: 4, Action: 1, Delta: 0.0
# Policy sum for state 4: 1.0
# Norm of Q-values: 0.017320508075688773
# delta (4) - State: 4, Action: 3, Delta: 0.0
# Policy sum for state 4: 1.0
# Norm of Q-values: 0.017320508075688773
# delta (4) - State: 4, Action: 2, Delta: 0.0
# Policy sum for state 4: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#
# Summary Table:
#     Update Rule  Mean Steps  Standard Deviation
# 0        SARSA    5.580000            0.477074
# 1   Q-learning    5.686667            0.446268
# 2   Mean SARSA    5.506667            0.543405
# 3  Fourth Rule    5.726667            0.501952
# nb_episodes: 30

# %%
import time
from datetime import timedelta


def make_mdp(cfg):
    mdp = gym.make(cfg.mdp.name, kwargs={"width": cfg.mdp.width, "height": cfg.mdp.height, "ratio": cfg.mdp.ratio}, render_mode=cfg.mdp.render_mode)
    mdp = mdp.unwrapped
    return mdp

# ========== Fonctions Algorithmiques ==========
def run_experiment(cfg, nb_runs):
    """ Exécute l'algorithme Actor-Critic et retourne les résultats. """
    mdp = make_mdp(cfg)  # Créer un nouvel environnement avec les paramètres actuels
    update_names = ["SARSA", "Q-learning", "Mean SARSA", "Fourth Rule"]
    all_results = []
    summary = []

    for update_type in range(1, 5):
        all_steps = []

        for run in range(nb_runs):
            _, nb_steps = actor_critic_q(mdp, cfg.nb_episodes, cfg.alpha_critic, cfg.alpha_actor, update_type, cfg.render)
            all_steps.append(nb_steps)

        # Convertir en numpy arrays pour le calcul des statistiques
        all_steps = np.array(all_steps)
        mean_steps = np.mean(all_steps, axis=0)
        std_steps = np.std(all_steps, axis=0)

        all_results.append((update_names[update_type - 1], mean_steps, std_steps))
        summary.append([update_names[update_type - 1], np.mean(mean_steps), np.std(mean_steps)])

    return all_results, summary


# ========== Fonction pour le tracé des résultats ==========
def plot_results(all_results, cfg):
    """ Affiche les courbes de performance en fonction des mises à jour et enregistre les plots. """

    # Créer le dossier "plots" si nécessaire
    if not os.path.exists('plots'):
        os.makedirs('plots')

    # Création du plot
    plt.figure(figsize=(12, 8))
    plt.title(f"Actor-Critic Performance - Comparison of Update Rules (gamma={cfg.mdp.gamma})")
    plt.xlabel("Episode")
    plt.ylabel("Number of Steps")
    plt.grid(True, linestyle="--", alpha=0.6)

    for name, mean_steps, std_steps in all_results:
        plt.plot(mean_steps, label=f"{name} - Mean Steps")
        plt.fill_between(range(cfg.nb_episodes), mean_steps - std_steps, mean_steps + std_steps, alpha=0.2)

    plt.legend(loc="upper right")

    # Générer un nom de fichier basé sur les paramètres
    plot_filename = f"actor_critic_comparison_gamma_{cfg.mdp.gamma}_alpha_critic_{cfg.alpha_critic}_alpha_actor_{cfg.alpha_actor}.pdf"
    plot_filepath = os.path.join('plots', plot_filename)

    # Sauvegarder le plot dans le dossier "plots"
    plt.savefig(plot_filepath)
    print(f"Plot saved to {plot_filepath}")

    # Afficher le plot
    plt.show()


# ========== Exécution des tests sur plusieurs configurations ==========
# les taux d'apprentissages
hyperparameter_tests = [
    {"alpha_critic": 0.8, "alpha_actor": 0.5},  # Critic fort
    {"alpha_critic": 0.5, "alpha_actor": 0.8},  # Actor fort
]

gammas = [0.9, 0.95, 0.99]  # Test sur différentes valeurs de gamma

N = 100  # Nombre de runs

for params in hyperparameter_tests:
    for gamma in gammas:
        print(f"\n\nTest avec alpha_critic={params['alpha_critic']}, alpha_actor={params['alpha_actor']} et gamma={gamma}")

        ac_params = {
            "save_curves": False,
            "save_heatmap": True,
            "mdp": {
                "name": "MazeMDP-v0",
                "width": 5,
                "height": 5,
                "ratio": 0.2,
                "render_mode": "rgb_array",
                "gamma": gamma,
            },
            "log_dir": "./tmp",
            "video_dir": "./tmp/videos",
            "nb_episodes": 100,
            "render": False,
            "nb_repeats": 5,
            "alpha_critic": params["alpha_critic"],
            "alpha_actor": params["alpha_actor"],
        }

        cfg = OmegaConf.create(ac_params)

        # Lancer le test et mesurer le temps d'exécution
        start_time = time.time()
        all_results, summary = run_experiment(cfg, N)
        end_time = time.time()

        elapsed_time = timedelta(seconds=(end_time - start_time))
        print(f"Temps d'exécution pour {N} runs avec gamma = {gamma} : {elapsed_time}\n")

        # Affichage des résultats
        summary_df = pd.DataFrame(summary, columns=["Update Rule", "Mean Steps", "Standard Deviation"])
        print("\nRésumé des résultats :\n", summary_df)

        plot_results(all_results, cfg)  # Tracer les résultats
# Out:
# Streaming output truncated to the last 5000 lines.
# Policy sum for state 9: 1.0
# Norm of Q-values: 1.7352617785221918
# delta (4) - State: 10, Action: 3, Delta: 0.0
# Policy sum for state 10: 1.0
# Norm of Q-values: 1.7352617785221918
# delta (4) - State: 5, Action: 3, Delta: 0.0
# Policy sum for state 5: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 30/100
# Step: 0, State: 11, Terminated: False, Truncated: False
# delta (4) - State: 11, Action: 1, Delta: 0.0
# Policy sum for state 11: 1.0
# Norm of Q-values: 1.7352617785221918
# delta (4) - State: 11, Action: 2, Delta: 0.6220800000000001
# Policy sum for state 11: 1.0
# Norm of Q-values: 1.8052154710438308
# delta (4) - State: 16, Action: 0, Delta: 0.0
# Policy sum for state 16: 1.0
# Norm of Q-values: 1.8052154710438308
# delta (4) - State: 15, Action: 2, Delta: 0.5184000000000001
# Policy sum for state 15: 1.0
# Norm of Q-values: 1.8522406904330766
# delta (4) - State: 18, Action: 3, Delta: 0.3732480000000001
# Policy sum for state 18: 0.9999999999999999
# Norm of Q-values: 1.876154732365793
# delta (4) - State: 15, Action: 2, Delta: 0.10368
# Policy sum for state 15: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 31/100
# Step: 0, State: 17, Terminated: False, Truncated: False
# delta (4) - State: 17, Action: 0, Delta: 0.0
# Policy sum for state 17: 1.0
# Norm of Q-values: 1.896215535817213
# delta (4) - State: 17, Action: 1, Delta: 0.0
# Policy sum for state 17: 1.0
# Norm of Q-values: 1.896215535817213
# delta (4) - State: 17, Action: 2, Delta: 0.0
# Policy sum for state 17: 1.0
# Norm of Q-values: 1.896215535817213
# delta (4) - State: 17, Action: 1, Delta: 0.0
# Policy sum for state 17: 1.0
# Norm of Q-values: 1.896215535817213
# delta (4) - State: 17, Action: 0, Delta: 0.0
# Policy sum for state 17: 1.0
# Norm of Q-values: 1.896215535817213
# delta (4) - State: 17, Action: 1, Delta: 0.0
# Policy sum for state 17: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 32/100
# Step: 0, State: 6, Terminated: False, Truncated: False
# delta (4) - State: 6, Action: 2, Delta: 0.0
# Policy sum for state 6: 1.0
# Norm of Q-values: 1.896215535817213
# delta (4) - State: 6, Action: 3, Delta: 0.0
# Policy sum for state 6: 1.0
# Norm of Q-values: 1.896215535817213
# delta (4) - State: 2, Action: 0, Delta: 0.0
# Policy sum for state 2: 1.0
# Norm of Q-values: 1.896215535817213
# delta (4) - State: 1, Action: 3, Delta: 0.0
# Policy sum for state 1: 1.0
# Norm of Q-values: 1.896215535817213
# delta (4) - State: 1, Action: 2, Delta: 0.0
# Policy sum for state 1: 1.0
# Norm of Q-values: 1.896215535817213
# delta (4) - State: 5, Action: 2, Delta: 0.0
# Policy sum for state 5: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 33/100
# Step: 0, State: 14, Terminated: False, Truncated: False
# delta (4) - State: 14, Action: 2, Delta: 0.0
# Policy sum for state 14: 1.0
# Norm of Q-values: 1.896215535817213
# delta (4) - State: 14, Action: 2, Delta: 0.0
# Policy sum for state 14: 1.0
# Norm of Q-values: 1.896215535817213
# delta (4) - State: 14, Action: 2, Delta: 0.0
# Policy sum for state 14: 1.0
# Norm of Q-values: 1.896215535817213
# delta (4) - State: 14, Action: 3, Delta: 0.0
# Policy sum for state 14: 1.0
# Norm of Q-values: 1.896215535817213
# delta (4) - State: 14, Action: 2, Delta: 0.0
# Policy sum for state 14: 1.0
# Norm of Q-values: 1.896215535817213
# delta (4) - State: 14, Action: 3, Delta: 0.0
# Policy sum for state 14: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 34/100
# Step: 0, State: 17, Terminated: False, Truncated: False
# delta (4) - State: 17, Action: 1, Delta: 0.0
# Policy sum for state 17: 1.0
# Norm of Q-values: 1.896215535817213
# delta (4) - State: 17, Action: 3, Delta: 0.0
# Policy sum for state 17: 1.0
# Norm of Q-values: 1.896215535817213
# delta (4) - State: 12, Action: 0, Delta: 0.0
# Policy sum for state 12: 1.0
# Norm of Q-values: 1.896215535817213
# delta (4) - State: 12, Action: 1, Delta: 0.0
# Policy sum for state 12: 1.0
# Norm of Q-values: 1.896215535817213
# delta (4) - State: 13, Action: 0, Delta: 0.0
# Policy sum for state 13: 1.0
# Norm of Q-values: 1.896215535817213
# delta (4) - State: 12, Action: 1, Delta: 0.0
# Policy sum for state 12: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 35/100
# Step: 0, State: 5, Terminated: False, Truncated: False
# delta (4) - State: 5, Action: 2, Delta: 0.0
# Policy sum for state 5: 1.0
# Norm of Q-values: 1.896215535817213
# delta (4) - State: 10, Action: 3, Delta: 0.0
# Policy sum for state 10: 1.0
# Norm of Q-values: 1.896215535817213
# delta (4) - State: 5, Action: 0, Delta: 0.0
# Policy sum for state 5: 1.0
# Norm of Q-values: 1.896215535817213
# delta (4) - State: 4, Action: 0, Delta: 0.0
# Policy sum for state 4: 1.0
# Norm of Q-values: 1.896215535817213
# delta (4) - State: 4, Action: 2, Delta: 0.0
# Policy sum for state 4: 1.0
# Norm of Q-values: 1.896215535817213
# delta (4) - State: 9, Action: 2, Delta: 0.0
# Policy sum for state 9: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 36/100
# Step: 0, State: 13, Terminated: False, Truncated: False
# delta (4) - State: 13, Action: 2, Delta: 0.0
# Policy sum for state 13: 1.0
# Norm of Q-values: 1.896215535817213
# delta (4) - State: 13, Action: 0, Delta: 0.0
# Policy sum for state 13: 1.0
# Norm of Q-values: 1.896215535817213
# delta (4) - State: 12, Action: 0, Delta: 0.0
# Policy sum for state 12: 1.0
# Norm of Q-values: 1.896215535817213
# delta (4) - State: 12, Action: 0, Delta: 0.0
# Policy sum for state 12: 1.0
# Norm of Q-values: 1.896215535817213
# delta (4) - State: 12, Action: 3, Delta: 0.0
# Policy sum for state 12: 1.0
# Norm of Q-values: 1.896215535817213
# delta (4) - State: 9, Action: 2, Delta: 0.0
# Policy sum for state 9: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 37/100
# Step: 0, State: 12, Terminated: False, Truncated: False
# delta (4) - State: 12, Action: 0, Delta: 0.0
# Policy sum for state 12: 1.0
# Norm of Q-values: 1.896215535817213
# delta (4) - State: 12, Action: 1, Delta: 0.0
# Policy sum for state 12: 1.0
# Norm of Q-values: 1.896215535817213
# delta (4) - State: 13, Action: 3, Delta: 0.0
# Policy sum for state 13: 1.0
# Norm of Q-values: 1.896215535817213
# delta (4) - State: 10, Action: 0, Delta: 0.0
# Policy sum for state 10: 1.0
# Norm of Q-values: 1.896215535817213
# delta (4) - State: 9, Action: 1, Delta: 0.0
# Policy sum for state 9: 1.0
# Norm of Q-values: 1.896215535817213
# delta (4) - State: 10, Action: 1, Delta: 0.0
# Policy sum for state 10: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 38/100
# Step: 0, State: 15, Terminated: False, Truncated: False
# delta (4) - State: 15, Action: 3, Delta: 0.4478976000000001
# Policy sum for state 15: 1.0000000000000002
# Norm of Q-values: 1.9297733557932255
# delta (4) - State: 15, Action: 1, Delta: 0.6220800000000001
# Policy sum for state 15: 0.9999999999999999
# Norm of Q-values: 1.9929111022886712
# delta (4) - State: 16, Action: 2, Delta: 0.17279999999999995
# Policy sum for state 16: 1.0
# Norm of Q-values: 2.044971377605429
# delta (4) - State: 19, Action: 3, Delta: 0.19999999999999996
# Policy sum for state 19: 0.9999999999999999
# Norm of Q-values: 2.1127015726849465
#  Actor_critic_q function - looping Episode 39/100
# Step: 0, State: 16, Terminated: False, Truncated: False
# delta (4) - State: 16, Action: 3, Delta: 0.4478976000000001
# Policy sum for state 16: 1.0
# Norm of Q-values: 2.142871853770153
# delta (4) - State: 11, Action: 2, Delta: 0.24883199999999983
# Policy sum for state 11: 1.0
# Norm of Q-values: 2.1976493033012554
# delta (4) - State: 16, Action: 3, Delta: 0.26873855999999985
# Policy sum for state 16: 1.0
# Norm of Q-values: 2.242755836191295
# delta (4) - State: 11, Action: 0, Delta: 0.6270566399999999
# Policy sum for state 11: 1.0
# Norm of Q-values: 2.2981735704297215
# delta (4) - State: 11, Action: 3, Delta: 0.0
# Policy sum for state 11: 1.0
# Norm of Q-values: 2.2981735704297215
# delta (4) - State: 8, Action: 0, Delta: 0.0
# Policy sum for state 8: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 40/100
# Step: 0, State: 3, Terminated: False, Truncated: False
# delta (4) - State: 3, Action: 0, Delta: 0.0
# Policy sum for state 3: 1.0
# Norm of Q-values: 2.2981735704297215
# delta (4) - State: 2, Action: 2, Delta: 0.0
# Policy sum for state 2: 1.0
# Norm of Q-values: 2.2981735704297215
# delta (4) - State: 6, Action: 3, Delta: 0.0
# Policy sum for state 6: 1.0
# Norm of Q-values: 2.2981735704297215
# delta (4) - State: 2, Action: 1, Delta: 0.0
# Policy sum for state 2: 1.0
# Norm of Q-values: 2.2981735704297215
# delta (4) - State: 3, Action: 2, Delta: 0.0
# Policy sum for state 3: 1.0
# Norm of Q-values: 2.2981735704297215
# delta (4) - State: 7, Action: 1, Delta: 0.0
# Policy sum for state 7: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 41/100
# Step: 0, State: 18, Terminated: False, Truncated: False
# delta (4) - State: 18, Action: 3, Delta: 0.14929920000000002
# Policy sum for state 18: 1.0
# Norm of Q-values: 2.316721028549823
# delta (4) - State: 15, Action: 2, Delta: 0.020735999999999977
# Policy sum for state 15: 1.0
# Norm of Q-values: 2.32034109767008
# delta (4) - State: 18, Action: 3, Delta: 0.0447897599999999
# Policy sum for state 18: 1.0
# Norm of Q-values: 2.327063562842124
# delta (4) - State: 15, Action: 2, Delta: 0.0041472000000000175
# Policy sum for state 15: 1.0
# Norm of Q-values: 2.327798996429536
# delta (4) - State: 18, Action: 3, Delta: 0.011943936000000044
# Policy sum for state 18: 1.0000000000000002
# Norm of Q-values: 2.3296808904146094
# delta (4) - State: 15, Action: 2, Delta: 0.0008294399999999591
# Policy sum for state 15: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 42/100
# Step: 0, State: 0, Terminated: False, Truncated: False
# delta (4) - State: 0, Action: 0, Delta: 0.0
# Policy sum for state 0: 1.0
# Norm of Q-values: 2.3298283974200165
# delta (4) - State: 0, Action: 2, Delta: 0.0
# Policy sum for state 0: 1.0
# Norm of Q-values: 2.3298283974200165
# delta (4) - State: 4, Action: 3, Delta: 0.0
# Policy sum for state 4: 1.0
# Norm of Q-values: 2.3298283974200165
# delta (4) - State: 0, Action: 1, Delta: 0.0
# Policy sum for state 0: 1.0
# Norm of Q-values: 2.3298283974200165
# delta (4) - State: 1, Action: 1, Delta: 0.0
# Policy sum for state 1: 1.0
# Norm of Q-values: 2.3298283974200165
# delta (4) - State: 2, Action: 0, Delta: 0.0
# Policy sum for state 2: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 43/100
# Step: 0, State: 7, Terminated: False, Truncated: False
# delta (4) - State: 7, Action: 2, Delta: 0.0
# Policy sum for state 7: 1.0
# Norm of Q-values: 2.3298283974200165
# delta (4) - State: 7, Action: 2, Delta: 0.0
# Policy sum for state 7: 1.0
# Norm of Q-values: 2.3298283974200165
# delta (4) - State: 7, Action: 2, Delta: 0.0
# Policy sum for state 7: 1.0
# Norm of Q-values: 2.3298283974200165
# delta (4) - State: 7, Action: 3, Delta: 0.0
# Policy sum for state 7: 1.0
# Norm of Q-values: 2.3298283974200165
# delta (4) - State: 3, Action: 0, Delta: 0.0
# Policy sum for state 3: 1.0
# Norm of Q-values: 2.3298283974200165
# delta (4) - State: 2, Action: 3, Delta: 0.0
# Policy sum for state 2: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 44/100
# Step: 0, State: 16, Terminated: False, Truncated: False
# delta (4) - State: 16, Action: 3, Delta: 0.05374771199999995
# Policy sum for state 16: 1.0
# Norm of Q-values: 2.340780141972404
# delta (4) - State: 11, Action: 3, Delta: 0.0
# Policy sum for state 11: 1.0
# Norm of Q-values: 2.340780141972404
# delta (4) - State: 8, Action: 0, Delta: 0.0
# Policy sum for state 8: 1.0
# Norm of Q-values: 2.340780141972404
# delta (4) - State: 7, Action: 2, Delta: 0.0
# Policy sum for state 7: 1.0
# Norm of Q-values: 2.340780141972404
# delta (4) - State: 7, Action: 1, Delta: 0.0
# Policy sum for state 7: 1.0
# Norm of Q-values: 2.340780141972404
# delta (4) - State: 8, Action: 1, Delta: 0.0
# Policy sum for state 8: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 45/100
# Step: 0, State: 18, Terminated: False, Truncated: False
# delta (4) - State: 18, Action: 1, Delta: 0.2879999999999999
# Policy sum for state 18: 1.0
# Norm of Q-values: 2.4078531170011903
# delta (4) - State: 19, Action: 2, Delta: 0.19999999999999996
# Policy sum for state 19: 1.0
# Norm of Q-values: 2
# Policy sum for state 2: 0.9999999999999999
# Norm of Q-values: 3.4792911653652063
# delta (4) - State: 6, Action: 3, Delta: 0.2396570455080986
# Policy sum for state 6: 0.9999999999999998
# Norm of Q-values: 3.481354030869856
# delta (4) - State: 2, Action: 0, Delta: 0.041307052389144304
# Policy sum for state 2: 1.0000000000000002
# Norm of Q-values: 3.481660340839575
# delta (4) - State: 1, Action: 0, Delta: 0.0
# Policy sum for state 1: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 93/100
# Step: 0, State: 18, Terminated: False, Truncated: False
# delta (4) - State: 18, Action: 2, Delta: 0.026567001342773344
# Policy sum for state 18: 1.0
# Norm of Q-values: 3.484591976578735
# delta (4) - State: 18, Action: 0, Delta: 0.013879890918731763
# Policy sum for state 18: 1.0
# Norm of Q-values: 3.48598331842593
# delta (4) - State: 17, Action: 0, Delta: 0.10701976761817933
# Policy sum for state 17: 1.0
# Norm of Q-values: 3.494471673714402
# delta (4) - State: 16, Action: 0, Delta: 0.08585822890752443
# Policy sum for state 16: 1.0000000000000002
# Norm of Q-values: 3.498741320578217
# delta (4) - State: 15, Action: 2, Delta: 0.1651970149622719
# Policy sum for state 15: 1.0
# Norm of Q-values: 3.5055400142325346
# delta (4) - State: 15, Action: 3, Delta: 0.03299489403548472
# Policy sum for state 15: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 94/100
# Step: 0, State: 17, Terminated: False, Truncated: False
# delta (4) - State: 17, Action: 0, Delta: 0.05350988380908961
# Policy sum for state 17: 1.0
# Norm of Q-values: 3.5122595152021927
# delta (4) - State: 16, Action: 0, Delta: 0.057776816769730344
# Policy sum for state 16: 0.9999999999999999
# Norm of Q-values: 3.515413829566071
# delta (4) - State: 15, Action: 1, Delta: 0.6339249893188478
# Policy sum for state 15: 0.9999999999999999
# Norm of Q-values: 3.5296741515506946
# delta (4) - State: 16, Action: 1, Delta: 0.004790124893188419
# Policy sum for state 16: 1.0
# Norm of Q-values: 3.5301528763050074
# delta (4) - State: 17, Action: 2, Delta: 0.03660847735404971
# Policy sum for state 17: 1.0
# Norm of Q-values: 3.5336857728373747
# delta (4) - State: 17, Action: 1, Delta: 0.0006967735290527299
# Policy sum for state 17: 0.9999999999999998
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 95/100
# Step: 0, State: 11, Terminated: False, Truncated: False
# delta (4) - State: 11, Action: 3, Delta: 0.06579329372004794
# Policy sum for state 11: 1.0
# Norm of Q-values: 3.5378720889554134
# delta (4) - State: 11, Action: 1, Delta: 0.022009195732623388
# Policy sum for state 11: 1.0
# Norm of Q-values: 3.539585573210621
# delta (4) - State: 12, Action: 2, Delta: 0.021539762949943753
# Policy sum for state 12: 1.0
# Norm of Q-values: 3.541471316163297
# delta (4) - State: 16, Action: 0, Delta: 0.028888408384865172
# Policy sum for state 16: 0.9999999999999999
# Norm of Q-values: 3.543124148798582
# delta (4) - State: 15, Action: 3, Delta: 0.026401585097422853
# Policy sum for state 15: 1.0
# Norm of Q-values: 3.544915977648622
# delta (4) - State: 11, Action: 3, Delta: 0.04280078493970446
# Policy sum for state 11: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 96/100
# Step: 0, State: 14, Terminated: False, Truncated: False
# delta (4) - State: 14, Action: 3, Delta: 0.08191665361583222
# Policy sum for state 14: 0.9999999999999999
# Norm of Q-values: 3.553358037699865
# delta (4) - State: 14, Action: 0, Delta: 0.028373173320293432
# Policy sum for state 14: 0.9999999999999998
# Norm of Q-values: 3.555816650160142
# delta (4) - State: 13, Action: 1, Delta: 0.12120338043808931
# Policy sum for state 13: 1.0
# Norm of Q-values: 3.563816277648033
# delta (4) - State: 14, Action: 0, Delta: 0.014186586660146716
# Policy sum for state 14: 1.0
# Norm of Q-values: 3.5650633596045407
# delta (4) - State: 13, Action: 3, Delta: 0.04509045120254157
# Policy sum for state 13: 1.0
# Norm of Q-values: 3.5682597372777667
# delta (4) - State: 9, Action: 0, Delta: 0.06175083092629913
# Policy sum for state 9: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 97/100
# Step: 0, State: 9, Terminated: False, Truncated: False
# delta (4) - State: 9, Action: 2, Delta: 0.037880537080764776
# Policy sum for state 9: 1.0
# Norm of Q-values: 3.574403167293229
# delta (4) - State: 13, Action: 0, Delta: 0.00902533235647729
# Policy sum for state 13: 1.0000000000000002
# Norm of Q-values: 3.5751110286076924
# delta (4) - State: 12, Action: 3, Delta: 0.3597803864057064
# Policy sum for state 12: 1.0
# Norm of Q-values: 3.5808204566303874
# delta (4) - State: 8, Action: 0, Delta: 0.05361776916235689
# Policy sum for state 8: 0.9999999999999999
# Norm of Q-values: 3.5833888620307555
# delta (4) - State: 8, Action: 3, Delta: 0.08648033721703292
# Policy sum for state 8: 1.0
# Norm of Q-values: 3.5848212308231235
# delta (4) - State: 5, Action: 1, Delta: 0.19711915112686157
# Policy sum for state 5: 1.0000000000000002
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 98/100
# Step: 0, State: 5, Terminated: False, Truncated: False
# delta (4) - State: 5, Action: 2, Delta: 0.17940877600479127
# Policy sum for state 5: 1.0
# Norm of Q-values: 3.5969935940587816
# delta (4) - State: 8, Action: 0, Delta: 0.026808884581178416
# Policy sum for state 8: 1.0
# Norm of Q-values: 3.5983471552743467
# delta (4) - State: 8, Action: 1, Delta: 0.13053842267096039
# Policy sum for state 8: 0.9999999999999999
# Norm of Q-values: 3.606656464028168
# delta (4) - State: 9, Action: 0, Delta: 0.08961770566508176
# Policy sum for state 9: 0.9999999999999999
# Norm of Q-values: 3.611311480510359
# delta (4) - State: 8, Action: 1, Delta: 0.06526921133548019
# Policy sum for state 8: 1.0
# Norm of Q-values: 3.6158954577738807
# delta (4) - State: 9, Action: 0, Delta: 0.07417999793350694
# Policy sum for state 9: 1.0000000000000002
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 99/100
# Step: 0, State: 17, Terminated: False, Truncated: False
# delta (4) - State: 17, Action: 3, Delta: 0.01533147169947624
# Policy sum for state 17: 1.0000000000000002
# Norm of Q-values: 3.62148367263568
# delta (4) - State: 13, Action: 1, Delta: 0.06698565421611069
# Policy sum for state 13: 1.0
# Norm of Q-values: 3.6262615132592333
# delta (4) - State: 14, Action: 3, Delta: 0.06011021879911427
# Policy sum for state 14: 1.0
# Norm of Q-values: 3.6305862895537975
# delta (4) - State: 14, Action: 3, Delta: 0.030055109399557134
# Policy sum for state 14: 1.0
# Norm of Q-values: 3.6328399923162324
# delta (4) - State: 14, Action: 0, Delta: 0.007093293330073358
# Policy sum for state 14: 1.0
# Norm of Q-values: 3.6334569344444927
# delta (4) - State: 13, Action: 3, Delta: 0.03959146728761498
# Policy sum for state 13: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 100/100
# Step: 0, State: 12, Terminated: False, Truncated: False
# delta (4) - State: 12, Action: 3, Delta: 0.26800362850575143
# Policy sum for state 12: 1.0
# Norm of Q-values: 3.646280831687426
# delta (4) - State: 8, Action: 0, Delta: 0.1015178775934874
# Policy sum for state 8: 1.0
# Norm of Q-values: 3.6517805178232297
# delta (4) - State: 8, Action: 0, Delta: 0.0507589387967437
# Policy sum for state 8: 1.0000000000000002
# Norm of Q-values: 3.654791625546551
# delta (4) - State: 8, Action: 0, Delta: 0.02537946939837188
# Policy sum for state 8: 0.9999999999999998
# Norm of Q-values: 3.65636231139248
# delta (4) - State: 8, Action: 0, Delta: 0.01268973469918594
# Policy sum for state 8: 1.0
# Norm of Q-values: 3.657163913088869
# delta (4) - State: 8, Action: 1, Delta: 0.032634605667740124
# Policy sum for state 8: 0.9999999999999998
# Stagnation detected after 6 steps. Avg reward: 0.0
# Temps d'exécution pour 100 runs avec gamma = 0.99 : 0:00:31.369101
#
#
# Résumé des résultats :
#     Update Rule  Mean Steps  Standard Deviation
# 0        SARSA      5.5894            0.132890
# 1   Q-learning      5.3625            0.204350
# 2   Mean SARSA      5.4146            0.195240
# 3  Fourth Rule      5.5701            0.129348
# Plot saved to plots/actor_critic_comparison_gamma_0.99_alpha_critic_0.5_alpha_actor_0.8.pdf

# %% [markdown]
# ## Actor-critic hyper-parameters
#
# To represent the hyper-parameters of the experiments performed in this notebook, we suggest using the dictionary below.
# This dictionary can be read using omegaconf.
# Using it is not mandatory.
# You can also change the value of hyper-parameters or environment parameters at will.

# %% [markdown]
# ## Test your code
#
# The code for testing what you did so far is provided below.

# %%
# default given initially
ac_params = {
    "save_curves": False,
    "save_heatmap": True,
    "mdp": {
        "name": "MazeMDP-v0",
        "width": 5,
        "height": 5,
        "ratio": 0.0,
        "render_mode": "rgb_array",
        },

    "log_dir": "./tmp",
    "video_dir": "./tmp/videos",

    "nb_episodes": 30,
    "render": False, # True, #
    "nb_repeats": 5,

    "alpha_critic": 0.5,
    "alpha_actor": 0.5,
    }

def make_mdp(cfg):
    mdp = gym.make(cfg.mdp.name, kwargs={"width": cfg.mdp.width, "height": cfg.mdp.height, "ratio": cfg.mdp.ratio}, render_mode=cfg.mdp.render_mode)
    mdp = mdp.unwrapped
    return mdp

cfg=OmegaConf.create(ac_params)
mdp = make_mdp(cfg) # the mdp is made once and for all, this is an ugly global variable

# %%
plot_steps(nb_runs=cfg.nb_repeats, nb_episodes=cfg.nb_episodes, alpha_actor=cfg.alpha_actor, alpha_critic=cfg.alpha_critic)

# print("average v value:", v_vals.mean())
# Out:
# Streaming output truncated to the last 5000 lines.
# delta (3) - State: 11, Action: 2, Delta: 0.0
# Perform Episode - Update Type 3 - State: 11, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 11: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 7/30
# Step: 0, State: 11, Terminated: False, Truncated: False
# delta (3) - State: 11, Action: 1, Delta: 0.0
# Perform Episode - Update Type 3 - State: 11, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 11: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 12, Action: 0, Delta: 0.0
# Perform Episode - Update Type 3 - State: 12, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 12: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 11, Action: 1, Delta: 0.0
# Perform Episode - Update Type 3 - State: 11, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 11: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 12, Action: 0, Delta: 0.0
# Perform Episode - Update Type 3 - State: 12, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 12: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 11, Action: 3, Delta: 0.0
# Perform Episode - Update Type 3 - State: 11, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 11: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 6, Action: 2, Delta: 0.0
# Perform Episode - Update Type 3 - State: 6, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 6: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 8/30
# Step: 0, State: 2, Terminated: False, Truncated: False
# delta (3) - State: 2, Action: 1, Delta: 0.0
# Perform Episode - Update Type 3 - State: 2, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 2: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 3, Action: 1, Delta: 0.0
# Perform Episode - Update Type 3 - State: 3, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 3: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 4, Action: 0, Delta: 0.0
# Perform Episode - Update Type 3 - State: 4, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 4: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 3, Action: 1, Delta: 0.0
# Perform Episode - Update Type 3 - State: 3, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 3: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 4, Action: 1, Delta: 0.0
# Perform Episode - Update Type 3 - State: 4, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 4: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 4, Action: 3, Delta: 0.0
# Perform Episode - Update Type 3 - State: 4, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 4: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 9/30
# Step: 0, State: 13, Terminated: False, Truncated: False
# delta (3) - State: 13, Action: 3, Delta: 0.0
# Perform Episode - Update Type 3 - State: 13, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 13: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 8, Action: 0, Delta: 0.0
# Perform Episode - Update Type 3 - State: 8, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 8: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 7, Action: 2, Delta: 0.0
# Perform Episode - Update Type 3 - State: 7, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 7: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 12, Action: 0, Delta: 0.0
# Perform Episode - Update Type 3 - State: 12, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 12: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 11, Action: 1, Delta: 0.0
# Perform Episode - Update Type 3 - State: 11, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 11: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 12, Action: 1, Delta: 0.0
# Perform Episode - Update Type 3 - State: 12, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 12: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 10/30
# Step: 0, State: 24, Terminated: False, Truncated: False
# delta (3) - State: 24, Action: 2, Delta: 1.0
# Perform Episode - Update Type 3 - State: 24, Sum Q: 0.0, Delta: 1.0
# Policy sum for state 24: 0.9999999999999999
# Norm of Q-values: 0.5
#  Actor_critic_q function - looping Episode 11/30
# Step: 0, State: 3, Terminated: False, Truncated: False
# delta (3) - State: 3, Action: 1, Delta: 0.0
# Perform Episode - Update Type 3 - State: 3, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 3: 1.0
# Norm of Q-values: 0.5
# delta (3) - State: 4, Action: 0, Delta: 0.0
# Perform Episode - Update Type 3 - State: 4, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 4: 1.0
# Norm of Q-values: 0.5
# delta (3) - State: 3, Action: 2, Delta: 0.0
# Perform Episode - Update Type 3 - State: 3, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 3: 1.0
# Norm of Q-values: 0.5
# delta (3) - State: 8, Action: 3, Delta: 0.0
# Perform Episode - Update Type 3 - State: 8, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 8: 1.0
# Norm of Q-values: 0.5
# delta (3) - State: 3, Action: 2, Delta: 0.0
# Perform Episode - Update Type 3 - State: 3, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 3: 1.0
# Norm of Q-values: 0.5
# delta (3) - State: 8, Action: 2, Delta: 0.0
# Perform Episode - Update Type 3 - State: 8, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 8: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 12/30
# Step: 0, State: 0, Terminated: False, Truncated: False
# delta (3) - State: 0, Action: 0, Delta: 0.0
# Perform Episode - Update Type 3 - State: 0, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 0: 1.0
# Norm of Q-values: 0.5
# delta (3) - State: 0, Action: 2, Delta: 0.0
# Perform Episode - Update Type 3 - State: 0, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 0: 1.0
# Norm of Q-values: 0.5
# delta (3) - State: 5, Action: 3, Delta: 0.0
# Perform Episode - Update Type 3 - State: 5, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 5: 1.0
# Norm of Q-values: 0.5
# delta (3) - State: 0, Action: 0, Delta: 0.0
# Perform Episode - Update Type 3 - State: 0, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 0: 1.0
# Norm of Q-values: 0.5
# delta (3) - State: 0, Action: 1, Delta: 0.0
# Perform Episode - Update Type 3 - State: 0, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 0: 1.0
# Norm of Q-values: 0.5
# delta (3) - State: 1, Action: 3, Delta: 0.0
# Perform Episode - Update Type 3 - State: 1, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 1: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 13/30
# Step: 0, State: 23, Terminated: False, Truncated: False
# delta (3) - State: 23, Action: 3, Delta: 0.0
# Perform Episode - Update Type 3 - State: 23, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 23: 1.0
# Norm of Q-values: 0.5
# delta (3) - State: 18, Action: 2, Delta: 0.0
# Perform Episode - Update Type 3 - State: 18, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 18: 1.0
# Norm of Q-values: 0.5
# delta (3) - State: 23, Action: 0, Delta: 0.0
# Perform Episode - Update Type 3 - State: 23, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 23: 1.0
# Norm of Q-values: 0.5
# delta (3) - State: 22, Action: 0, Delta: 0.0
# Perform Episode - Update Type 3 - State: 22, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 22: 1.0
# Norm of Q-values: 0.5
# delta (3) - State: 21, Action: 3, Delta: 0.0
# Perform Episode - Update Type 3 - State: 21, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 21: 1.0
# Norm of Q-values: 0.5
# delta (3) - State: 16, Action: 3, Delta: 0.0
# Perform Episode - Update Type 3 - State: 16, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 16: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 14/30
# Step: 0, State: 11, Terminated: False, Truncated: False
# delta (3) - State: 11, Action: 1, Delta: 0.0
# Perform Episode - Update Type 3 - State: 11, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 11: 1.0
# Norm of Q-values: 0.5
# delta (3) - State: 12, Action: 0, Delta: 0.0
# Perform Episode - Update Type 3 - State: 12, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 12: 1.0
# Norm of Q-values: 0.5
# delta (3) - State: 11, Action: 3, Delta: 0.0
# Perform Episode - Update Type 3 - State: 11, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 11: 1.0
# Norm of Q-values: 0.5
# delta (3) - State: 6, Action: 2, Delta: 0.0
# Perform Episode - Update Type 3 - State: 6, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 6: 1.0
# Norm of Q-values: 0.5
# delta (3) - State: 11, Action: 3, Delta: 0.0
# Perform Episode - Update Type 3 - State: 11, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 11: 1.0
# Norm of Q-values: 0.5
# delta (3) - State: 6, Action: 3, Delta: 0.0
# Perform Episode - Update Type 3 - State: 6, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 6: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 15/30
# Step: 0, State: 24, Terminated: False, Truncated: False
# delta (3) - State: 24, Action: 2, Delta: 0.75
# Perform Episode - Update Type 3 - State: 24, Sum Q: 0.25, Delta: 0.75
# Policy sum for state 24: 1.0
# Norm of Q-values: 0.875
#  Actor_critic_q function - looping Episode 16/30
# Step: 0, State: 6, Terminated: False, Truncated: False
# delta (3) - State: 6, Action: 1, Delta: 0.0
# Perform Episode - Update Type 3 - State: 6, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 6: 1.0
# Norm of Q-values: 0.875
# delta (3) - State: 7, Action: 3, Delta: 0.0
# Perform Episode - Update Type 3 - State: 7, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 7: 1.0
# Norm of Q-values: 0.875
# delta (3) - State: 2, Action: 2, Delta: 0.0
# Perform Episode - Update Type 3 - State: 2, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 2: 1.0
# Norm of Q-values: 0.875
# delta (3) - State: 7, Action: 1, Delta: 0.0
# Perform Episode - Update Type 3 - State: 7, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 7: 1.0
# Norm of Q-values: 0.875
# delta (3) - State: 8, Action: 1, Delta: 0.0
# Perform Episode - Update Type 3 - State: 8, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 8: 1.0
# Norm of Q-values: 0.875
# delta (3) - State: 9, Action: 0, Delta: 0.0
# Perform Episode - Update Type 3 - State: 9, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 9: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 17/30
# Step: 0, State: 10, Terminated: False, Truncated: False
# delta (3) - State: 10, Action: 0, Delta: 0.0
# Perform Episode - Update Type 3 - State: 10, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 10: 1.0
# Norm of Q-values: 0.875
# delta (3) - State: 10, Action: 1, Delta: 0.0
# Perform Episode - Update Type 3 - State: 10, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 10: 1.0
# Norm of Q-values: 0.875
# delta (3) - State: 11, Action: 3, Delta: 0.0
# Perform Episode - Update Type 3 - State: 11, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 11: 1.0
# Norm of Q-values: 0.875
# delta (3) - State: 6, Action: 2, Delta: 0.0
# Perform Episode - Update Type 3 - State: 6, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 6: 1.0
# Norm of Q-values: 0.875
# delta (3) - State: 11, Action: 1, Delta: 0.0
# Perform Episode - Update Type 3 - State: 11, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 11: 1.0
# Norm of Q-values: 0.875
# delta (3) - State: 12, Action: 1, Delta: 0.0
# Perform Episode - Update Type 3 - State: 12, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 12: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 18/30
# Step: 0, State: 3, Terminated: False, Truncated: False
# delta (3) - State: 3, Action: 2, Delta: 0.0
# Perform Episode - Update Type 3 - State: 3, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 3: 1.0
# Norm of Q-values: 0.875
# delta (3) - State: 8, Action: 3, Delta: 0.0
# Perform Episode - Update Type 3 - State: 8, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 8: 1.0
# Norm of Q-values: 0.875
# delta (3) - State: 3, Action: 3, Delta: 0.0
# Perform Episode - Update Type 3 - State: 3, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 3: 1.0
# Norm of Q-values: 0.875
# delta (3) - State: 3, Action: 1, Delta: 0.0
# Perform Episode - Update Type 3 - State: 3, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 3: 1.0
# Norm of Q-values: 0.875
# delta (3) - State: 4, Action: 3, Delta: 0.0
# Perform Episode - Update Type 3 - State: 4, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 4: 1.0
# Norm of Q-values: 0.875
# delta (3) - State: 4, Action: 0, Delta: 0.0
# Perform Episode - Update Type 3 - State: 4, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 4: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 19/30
# Step: 0, State: 12, Terminated: False, Truncated: False
# delta (3) - State: 12, Action: 0, Delta: 0.0
# Perform Episode - Update Type 3 - State: 12, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 12: 1.0
# Norm of Q-values: 0.875
# delta (3) - State: 11, Action: 0, Delta: 0.0
# Perform Episode - Update Type 3 - State: 11, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 11: 1.0
# Norm of Q-values: 0.875
# delta (3) - State: 10, Action: 2, Delta: 0.0
# Perform Episode - Update Type 3 - State: 10, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 10: 1.0
# Norm of Q-values: 0.875
# delta (3) - State: 15, Action: 2, Delta: 0.0
# Perform Episode - Update Type 3 - State: 15, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 15: 1.0
# Norm of Q-values: 0.875
# delta (3) - State: 20, Action: 3, Delta: 0.0
# Perform Episode - Update Type 3 - State: 20, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 20: 1.0
# Norm of Q-values: 0.875
# delta (3) - State: 15, Action: 0, Delta: 0.0
# Perform Episode - Update Type 3 - State: 15, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 15: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 20/30
# Step: 0, State: 21, Terminated: False, Truncated: False
# delta (3) - State: 21, Action: 0, Delta: 0.0
# Perform Episode - Update Type 3 - State: 21, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 21: 1.0
# Norm of Q-values: 0.875
# delta (3) - State: 20, Action: 3, Delta: 0.0
# Perform Episode - Update Type 3 - State: 20, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 20: 1.0
# Norm of Q-values: 0.875
# delta (3) - State: 15, Action: 3, Delta: 0.0
# Perform Episode - Update Type 3 - State: 15, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 15: 1.0
# Norm of Q-values: 0.875
# delta (3) - State: 10, Action: 3, Delta: 0.0
# Perform Episode - Update Type 3 - State: 10, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 10: 1.0
# Norm of Q-values: 0.875
# delta (3) - State: 5, Action: 3, Delta: 0.0
# Perform Episode - Update Type 3 - State: 5, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 5: 1.0
# Norm of Q-values: 0.875
# delta (3) - State: 0, Action: 0, Delta: 0.0
# Perform Episode - Update Type 3 - State: 0, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 0: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 21/30
# Step: 0, State: 15, Terminated: False, Truncated: False
# delta (3) - State: 15, Action: 3, Delta: 0.0
# Perform Episode - Update Type 3 - State: 15, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 15: 1.0
# Norm of Q-values: 0.875
# delta (3) - State: 10, Action: 0, Delta: 0.0
# Perform Episode - Update Type 3 - State: 10, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 10: 1.0
# Norm of Q-values: 0.875
# delta (3) - State: 10, Action: 2, Delta: 0.0
# Perform Episode - Update Type 3 - State: 10, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 10: 1.0
# Norm of Q-values: 0.875
# delta (3) - State: 15, Action: 2, Delta: 0.0
# Perform Episode - Update Type 3 - State: 15, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 15: 1.0
# Norm of Q-values: 0.875
# delta (3) - State: 20, Action: 0, Delta: 0.0
# Perform Episode - Update Type 3 - State: 20, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 20: 1.0
# Norm of Q-values: 0.875
# delta (3) - State: 20, Action: 1, Delta: 0.0
# Perform Episode - Update Type 3 - State: 20, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 20: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 22/30
# Step: 0, State: 6, Terminated: False, Truncated: False
# delta (3) - State: 6, Action: 1, Delta: 0.0
# Perform Episode - Update Type 3 - State: 6, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 6: 1.0
# Norm of Q-values: 0.875
# delta (3) - State: 7, Action: 0, Delta: 0.0
# Perform Episode - Update Type 3 - State: 7, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 7: 1.0
# Norm of Q-values: 0.875
# delta (3) - State: 6, Action: 2, Delta: 0.0
# Perform Episode - Update Type 3 - State: 6, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 6: 1.0
# Norm of Q-values: 0.875
# delta (3) - State: 11, Action: 1, Delta: 0.0
# Perform Episode - Update Type 3 - State: 11, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 11: 1.0
# Norm of Q-values: 0.875
# delta (3) - State: 12, Action: 2, Delta: 0.0
# Perform Episode - Update Type 3 - State: 12, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 12: 1.0
# Norm of Q-values: 0.875
# delta (3) - State: 17, Action: 1, Delta: 0.0
# Perform Episode - Update Type 3 - State: 17, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 17: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 23/30
# Step: 0, State: 1, Terminated: False, Truncated: False
# delta (3) - State: 1, Action: 2, Delta: 0.0
# Perform Episode - Update Type 3 - State: 1, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 1: 1.0
# Norm of Q-values: 0.875
# delta (3) - State: 6, Action: 2, Delta: 0.0
# Perform Episode - Update Type 3 - State: 6, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 6: 1.0
# Norm of Q-values: 0.875
# delta (3) - State: 11, Action: 1, Delta: 0.0
# Perform Episode - Update Type 3 - State: 11, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 11: 1.0
# Norm of Q-values: 0.875
# delta (3) - State: 12, Action: 2, Delta: 0.0
# Perform Episode - Update Type 3 - State: 12, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 12: 1.0
# Norm of Q-values: 0.875
# delta (3) - State: 17, Action: 2, Delta: 0.0
# Perform Episode - Update Type 3 - State: 17, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 17: 1.0
# Norm of Q-values: 0.875
# delta (3) - State: 22, Action: 1, Delta: 0.0
# Perform Episode - Update Type 3 - State: 22, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 22: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 24/30
# Step: 0, State: 8, Terminated: False, Truncated: False
# delta (3) - State: 8, Action: 2, Delta: 0.0
# Perform Episode - Update Type 3 - State: 8, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 8: 1.0
# Norm of Q-values: 0.875
# delta (3) - State: 13, Action: 0, Delta: 0.0
# Perform Episode - Update Type 3 - State: 13, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 13: 1.0
# Norm of Q-values: 0.875
# delta (3) - State: 12, Action: 0, Delta: 0.0
# Perform Episode - Update Type 3 - State: 12, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 12: 1.0
# Norm of Q-values: 0.875
# delta (3) - State: 11, Action: 3, Delta: 0.0
# Perform Episode - Update Type 3 - State: 11, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 11: 1.0
# Norm of Q-values: 0.875
# delta (3) - State: 6, Action: 2, Delta: 0.0
# Perform Episode - Update Type 3 - State: 6, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 6: 1.0
# Norm of Q-values: 0.875
# delta (3) - State: 11, Action: 2, Delta: 0.0
# Perform Episode - Update Type 3 - State: 11, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 11: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 25/30
# Step: 0, State: 17, Terminated: False, Truncated: False
# delta (3) - State: 17, Action: 0, Delta: 0.0
# Perform Episode - Update Type 3 - State: 17, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 17: 1.0
# Norm of Q-values: 0.875
# delta (3) - State: 16, Action: 3, Delta: 0.0
# Perform Episode - Update Type 3 - State: 16, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 16: 1.0
# Norm of Q-values: 0.875
# delta (3) - State: 11, Action: 0, Delta: 0.0
# Perform Episode - Update Type 3 - State: 11, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 11: 1.0
# Norm of Q-values: 0.875
# delta (3) - State: 10, Action: 3, Delta: 0.0
# Perform Episode - Update Type 3 - State: 10, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 10: 1.0
# Norm of Q-values: 0.875
# delta (3) - State: 5, Action: 2, Delta: 0.0
# Perform Episode - Update Type 3 - State: 5, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 5: 1.0
# Norm of Q-values: 0.875
# delta (3) - State: 10, Action: 3, Delta: 0.0
# Perform Episode - Update Type 3 - State: 10, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 10: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 26/30
# Step: 0, State: 16, Terminated: False, Truncated: False
# delta (3) - State: 16, Action: 1, Delta: 0.0
# Perform Episode - Update Type 3 - State: 16, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 16: 1.0
# Norm of Q-values: 0.875
# delta (3) - State: 17, Action: 1, Delta: 0.0
# Perform Episode - Update Type 3 - State: 17, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 17: 1.0
# Norm of Q-values: 0.875
# delta (3) - State: 18, Action: 3, Delta: 0.0
# Perform Episode - Update Type 3 - State: 18, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 18: 1.0
# Norm of Q-values: 0.875
# delta (3) - State: 13, Action: 2, Delta: 0.0
# Perform Episode - Update Type 3 - State: 13, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 13: 1.0
# Norm of Q-values: 0.875
# delta (3) - State: 18, Action: 2, Delta: 0.0
# Perform Episode - Update Type 3 - State: 18, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 18: 1.0
# Norm of Q-values: 0.875
# delta (3) - State: 23, Action: 2, Delta: 0.0
# Perform Episode - Update Type 3 - State: 23, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 23: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 27/30
# Step: 0, State: 8, Terminated: False, Truncated: False
# delta (3) - State: 8, Action: 3, Delta: 0.0
# Perform Episode - Update Type 3 - State: 8, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 8: 1.0
# Norm of Q-values: 0.875
# delta (3) - State: 3, Action: 1, Delta: 0.0
# Perform Episode - Update Type 3 - State: 3, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 3: 1.0
# Norm of Q-values: 0.875
# delta (3) - State: 4, Action: 1, Delta: 0.0
# Perform Episode - Update Type 3 - State: 4, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 4: 1.0
# Norm of Q-values: 0.875
# delta (3) - State: 4, Action: 2, Delta: 0.0
# Perform Episode - Update Type 3 - State: 4, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 4: 1.0
# Norm of Q-values: 0.875
# delta (3) - State: 9, Action: 0, Delta: 0.0
# Perform Episode - Update Type 3 - State: 9, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 9: 1.0
# Norm of Q-values: 0.875
# delta (3) - State: 8, Action: 2, Delta: 0.0
# Perform Episode - Update Type 3 - State: 8, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 8: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 28/30
# Step: 0, State: 0, Terminated: False, Truncated: False
# delta (3) - State: 0, Action: 0, Delta: 0.0
# Perform Episode - Update Type 3 - State: 0, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 0: 1.0
# Norm of Q-values: 0.875
# delta (3) - State: 0, Action: 2, Delta: 0.0
# Perform Episode - Update Type 3 - State: 0, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 0: 1.0
# Norm of Q-values: 0.875
# delta (3) - State: 5, Action: 1, Delta: 0.0
# Perform Episode - Update Type 3 - State: 5, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 5: 1.0
# Norm of Q-values: 0.875
# delta (3) - State: 6, Action: 3, Delta: 0.0
# Perform Episode - Update Type 3 - State: 6, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 6: 1.0
# Norm of Q-values: 0.875
# delta (3) - State: 1, Action: 2, Delta: 0.0
# Perform Episode - Update Type 3 - State: 1, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 1: 1.0
# Norm of Q-values: 0.875
# delta (3) - State: 6, Action: 2, Delta: 0.0
# Perform Episode - Update Type 3 - State: 6, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 6: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 29/30
# Step: 0, State: 19, Terminated: False, Truncated: False
# delta (3) - State: 19, Action: 2, Delta: 0.7875
# Perform Episode - Update Type 3 - State: 19, Sum Q: 0.0, Delta: 0.7875
# Policy sum for state 19: 0.9999999999999999
# Norm of Q-values: 0.9595124087264323
# delta (3) - State: 24, Action: 2, Delta: 0.44318181818181823
# Perform Episode - Update Type 3 - State: 24, Sum Q: 0.5568181818181818, Delta: 0.44318181818181823
# Policy sum for state 24: 1.0
# Norm of Q-values: 1.1651397703283615
#  Actor_critic_q function - looping Episode 30/30
# Step: 0, State: 24, Terminated: False, Truncated: False
# delta (3) - State: 24, Action: 2, Delta: 0.22983615221987308
# Perform Episode - Update Type 3 - State: 24, Sum Q: 0.7701638477801269, Delta: 0.22983615221987308
# Policy sum for state 24: 1.0
# Norm of Q-values: 1.2738889605151553
# Plot_steps funtion - Run 4 of 5
#  Actor_critic_q function - looping Episode 1/30
# Step: 0, State: 21, Terminated: False, Truncated: False
# delta (3) - State: 21, Action: 3, Delta: 0.0
# Perform Episode - Update Type 3 - State: 21, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 21: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 16, Action: 2, Delta: 0.0
# Perform Episode - Update Type 3 - State: 16, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 16: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 21, Action: 0, Delta: 0.0
# Perform Episode - Update Type 3 - State: 21, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 21: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 20, Action: 0, Delta: 0.0
# Perform Episode - Update Type 3 - State: 20, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 20: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 20, Action: 1, Delta: 0.0
# Perform Episode - Update Type 3 - State: 20, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 20: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 21, Action: 1, Delta: 0.0
# Perform Episode - Update Type 3 - State: 21, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 21: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 2/30
# Step: 0, State: 18, Terminated: False, Truncated: False
# delta (3) - State: 18, Action: 0, Delta: 0.0
# Perform Episode - Update Type 3 - State: 18, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 18: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 17, Action: 2, Delta: 0.0
# Perform Episode - Update Type 3 - State: 17, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 17: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 22, Action: 0, Delta: 0.0
# Perform Episode - Update Type 3 - State: 22, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 22: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 21, Action: 2, Delta: 0.0
# Perform Episode - Update Type 3 - State: 21, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 21: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 21, Action: 2, Delta: 0.0
# Perform Episode - Update Type 3 - State: 21, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 21: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 21, Action: 3, Delta: 0.0
# Perform Episode - Update Type 3 - State: 21, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 21: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 3/30
# Step: 0, State: 4, Terminated: False, Truncated: False
# delta (3) - State: 4, Action: 1, Delta: 0.0
# Perform Episode - Update Type 3 - State: 4, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 4: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 4, Action: 1, Delta: 0.0
# Perform Episode - Update Type 3 - State: 4, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 4: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 4, Action: 3, Delta: 0.0
# Perform Episode - Update Type 3 - State: 4, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 4: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 4, Action: 2, Delta: 0.0
# Perform Episode - Update Type 3 - State: 4, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 4: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 9, Action: 0, Delta: 0.0
# Perform Episode - Update Type 3 - State: 9, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 9: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 8, Action: 3, Delta: 0.0
# Perform Episode - Update Type 3 - State: 8, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 8: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 4/30
# Step: 0, State: 18, Terminated: False, Truncated: False
# delta (3) - State: 18, Action: 1, Delta: 0.0
# Perform Episode - Update Type 3 - State: 18, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 18: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 19, Action: 1, Delta: 0.0
# Perform Episode - Update Type 3 - State: 19, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 19: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 19, Action: 0, Delta: 0.0
# Perform Episode - Update Type 3 - State: 19, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 19: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 18, Action: 1, Delta: 0.0
# Perform Episode - Update Type 3 - State: 18, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 18: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 19, Action: 1, Delta: 0.0
# Perform Episode - Update Type 3 - State: 19, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 19: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 19, Action: 2, Delta: 0.0
# Perform Episode - Update Type 3 - State: 19, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 19: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 5/30
# Step: 0, State: 7, Terminated: False, Truncated: False
# delta (3) - State: 7, Action: 1, Delta: 0.0
# Perform Episode - Update Type 3 - State: 7, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 7: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 8, Action: 1, Delta: 0.0
# Perform Episode - Update Type 3 - State: 8, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 8: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 9, Action: 0, Delta: 0.0
# Perform Episode - Update Type 3 - State: 9, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 9: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 8, Action: 2, Delta: 0.0
# Perform Episode - Update Type 3 - State: 8, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 8: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 13, Action: 1, Delta: 0.0
# Perform Episode - Update Type 3 - State: 13, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 13: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 14, Action: 3, Delta: 0.0
# Perform Episode - Update Type 3 - State: 14, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 14: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 6/30
# Step: 0, State: 3, Terminated: False, Truncated: False
# delta (3) - State: 3, Action: 2, Delta: 0.0
# Perform Episode - Update Type 3 - State: 3, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 3: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 8, Action: 2, Delta: 0.0
# Perform Episode - Update Type 3 - State: 8, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 8: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 13, Action: 3, Delta: 0.0
# Perform Episode - Update Type 3 - State: 13, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 13: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 8, Action: 3, Delta: 0.0
# Perform Episode - Update Type 3 - State: 8, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 8: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 3, Action: 1, Delta: 0.0
# Perform Episode - Update Type 3 - State: 3, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 3: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 4, Action: 1, Delta: 0.0
# Perform Episode - Update Type 3 - State: 4, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 4: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 7/30
# Step: 0, State: 4, Terminated: False, Truncated: False
# delta (3) - State: 4, Action: 0, Delta: 0.0
# Perform Episode - Update Type 3 - State: 4, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 4: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 3, Action: 2, Delta: 0.0
# Perform Episode - Update Type 3 - State: 3, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 3: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 8, Action: 1, Delta: 0.0
# Perform Episode - Update Type 3 - State: 8, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 8: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 9, Action: 0, Delta: 0.0
# Perform Episode - Update Type 3 - State: 9, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 9: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 8, Action: 2, Delta: 0.0
# Perform Episode - Update Type 3 - State: 8, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 8: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 13, Action: 2, Delta: 0.0
# Perform Episode - Update Type 3 - State: 13, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 13: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 8/30
# Step: 0, State: 17, Terminated: False, Truncated: False
# delta (3) - State: 17, Action: 3, Delta: 0.0
# Perform Episode - Update Type 3 - State: 17, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 17: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 12, Action: 1, Delta: 0.0
# Perform Episode - Update Type 3 - State: 12, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 12: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 13, Action: 3, Delta: 0.0
# Perform Episode - Update Type 3 - State: 13, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 13: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 8, Action: 3, Delta: 0.0
# Perform Episode - Update Type 3 - State: 8, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 8: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 3, Action: 0, Delta: 0.0
# Perform Episode - Update Type 3 - State: 3, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 3: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 2, Action: 0, Delta: 0.0
# Perform Episode - Update Type 3 - State: 2, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 2: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 9/30
# Step: 0, State: 6, Terminated: False, Truncated: False
# delta (3) - State: 6, Action: 0, Delta: 0.0
# Perform Episode - Update Type 3 - State: 6, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 6: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 5, Action: 3, Delta: 0.0
# Perform Episode - Update Type 3 - State: 5, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 5: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 0, Action: 3, Delta: 0.0
# Perform Episode - Update Type 3 - State: 0, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 0: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 0, Action: 1, Delta: 0.0
# Perform Episode - Update Type 3 - State: 0, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 0: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 1, Action: 3, Delta: 0.0
# Perform Episode - Update Type 3 - State: 1, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 1: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 1, Action: 3, Delta: 0.0
# Perform Episode - Update Type 3 - State: 1, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 1: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 10/30
# Step: 0, State: 14, Terminated: False, Truncated: False
# delta (3) - State: 14, Action: 3, Delta: 0.0
# Perform Episode - Update Type 3 - State: 14, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 14: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 9, Action: 3, Delta: 0.0
# Perform Episode - Update Type 3 - State: 9, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 9: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 4, Action: 0, Delta: 0.0
# Perform Episode - Update Type 3 - State: 4, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 4: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 3, Action: 3, Delta: 0.0
# Perform Episode - Update Type 3 - State: 3, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 3: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 3, Action: 2, Delta: 0.0
# Perform Episode - Update Type 3 - State: 3, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 3: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 8, Action: 1, Delta: 0.0
# Perform Episode - Update Type 3 - State: 8, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 8: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 11/30
# Step: 0, State: 20, Terminated: False, Truncated: False
# delta (3) - State: 20, Action: 1, Delta: 0.0
# Perform Episode - Update Type 3 - State: 20, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 20: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 21, Action: 3, Delta: 0.0
# Perform Episode - Update Type 3 - State: 21, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 21: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 16, Action: 2, Delta: 0.0
# Perform Episode - Update Type 3 - State: 16, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 16: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 21, Action: 0, Delta: 0.0
# Perform Episode - Update Type 3 - State: 21, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 21: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 20, Action: 2, Delta: 0.0
# Perform Episode - Update Type 3 - State: 20, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 20: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 20, Action: 1, Delta: 0.0
# Perform Episode - Update Type 3 - State: 20, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 20: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 12/30
# Step: 0, State: 13, Terminated: False, Truncated: False
# delta (3) - State: 13, Action: 3, Delta: 0.0
# Perform Episode - Update Type 3 - State: 13, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 13: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 8, Action: 1, Delta: 0.0
# Perform Episode - Update Type 3 - State: 8, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 8: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 9, Action: 1, Delta: 0.0
# Perform Episode - Update Type 3 - State: 9, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 9: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 9, Action: 3, Delta: 0.0
# Perform Episode - Update Type 3 - State: 9, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 9: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 4, Action: 3, Delta: 0.0
# Perform Episode - Update Type 3 - State: 4, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 4: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 4, Action: 0, Delta: 0.0
# Perform Episode - Update Type 3 - State: 4, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 4: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 13/30
# Step: 0, State: 9, Terminated: False, Truncated: False
# delta (3) - State: 9, Action: 1, Delta: 0.0
# Perform Episode - Update Type 3 - State: 9, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 9: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 9, Action: 1, Delta: 0.0
# Perform Episode - Update Type 3 - State: 9, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 9: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 9, Action: 2, Delta: 0.0
# Perform Episode - Update Type 3 - State: 9, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 9: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 14, Action: 3, Delta: 0.0
# Perform Episode - Update Type 3 - State: 14, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 14: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 9, Action: 2, Delta: 0.0
# Perform Episode - Update Type 3 - State: 9, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 9: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 14, Action: 3, Delta: 0.0
# Perform Episode - Update Type 3 - State: 14, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 14: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 14/30
# Step: 0, State: 12, Terminated: False, Truncated: False
# delta (3) - State: 12, Action: 1, Delta: 0.0
# Perform Episode - Update Type 3 - State: 12, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 12: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 13, Action: 2, Delta: 0.0
# Perform Episode - Update Type 3 - State: 13, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 13: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 18, Action: 2, Delta: 0.0
# Perform Episode - Update Type 3 - State: 18, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 18: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 23, Action: 3, Delta: 0.0
# Perform Episode - Update Type 3 - State: 23, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 23: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 18, Action: 3, Delta: 0.0
# Perform Episode - Update Type 3 - State: 18, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 18: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 13, Action: 2, Delta: 0.0
# Perform Episode - Update Type 3 - State: 13, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 13: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 15/30
# Step: 0, State: 22, Terminated: False, Truncated: False
# delta (3) - State: 22, Action: 2, Delta: 0.0
# Perform Episode - Update Type 3 - State: 22, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 22: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 22, Action: 2, Delta: 0.0
# Perform Episode - Update Type 3 - State: 22, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 22: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 22, Action: 1, Delta: 0.0
# Perform Episode - Update Type 3 - State: 22, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 22: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 23, Action: 1, Delta: 0.0
# Perform Episode - Update Type 3 - State: 23, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 23: 1.0
# Norm of Q-values: 0.0
# delta (3) - State: 24, Action: 3, Delta: 1.0
# Perform Episode - Update Type 3 - State: 24, Sum Q: 0.0, Delta: 1.0
# Policy sum for state 24: 1.0
# Norm of Q-values: 0.5
#  Actor_critic_q function - looping Episode 16/30
# Step: 0, State: 9, Terminated: False, Truncated: False
# delta (3) - State: 9, Action: 1, Delta: 0.0
# Perform Episode - Update Type 3 - State: 9, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 9: 1.0
# Norm of Q-values: 0.5
# delta (3) - State: 9, Action: 0, Delta: 0.0
# Perform Episode - Update Type 3 - State: 9, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 9: 1.0
# Norm of Q-values: 0.5
# delta (3) - State: 8, Action: 3, Delta: 0.0
# Perform Episode - Update Type 3 - State: 8, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 8: 1.0
# Norm of Q-values: 0.5
# delta (3) - State: 3, Action: 0, Delta: 0.0
# Perform Episode - Update Type 3 - State: 3, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 3: 1.0
# Norm of Q-values: 0.5
# delta (3) - State: 2, Action: 3, Delta: 0.0
# Perform Episode - Update Type 3 - State: 2, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 2: 1.0
# Norm of Q-values: 0.5
# delta (3) - State: 2, Action: 1, Delta: 0.0
# Perform Episode - Update Type 3 - State: 2, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 2: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 17/30
# Step: 0, State: 0, Terminated: False, Truncated: False
# delta (3) - State: 0, Action: 0, Delta: 0.0
# Perform Episode - Update Type 3 - State: 0, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 0: 1.0
# Norm of Q-values: 0.5
# delta (3) - State: 0, Action: 1, Delta: 0.0
# Perform Episode - Update Type 3 - State: 0, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 0: 1.0
# Norm of Q-values: 0.5
# delta (3) - State: 1, Action: 0, Delta: 0.0
# Perform Episode - Update Type 3 - State: 1, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 1: 1.0
# Norm of Q-values: 0.5
# delta (3) - State: 0, Action: 2, Delta: 0.0
# Perform Episode - Update Type 3 - State: 0, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 0: 1.0
# Norm of Q-values: 0.5
# delta (3) - State: 5, Action: 0, Delta: 0.0
# Perform Episode - Update Type 3 - State: 5, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 5: 1.0
# Norm of Q-values: 0.5
# delta (3) - State: 5, Action: 2, Delta: 0.0
# Perform Episode - Update Type 3 - State: 5, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 5: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 18/30
# Step: 0, State: 5, Terminated: False, Truncated: False
# delta (3) - State: 5, Action: 1, Delta: 0.0
# Perform Episode - Update Type 3 - State: 5, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 5: 1.0
# Norm of Q-values: 0.5
# delta (3) - State: 6, Action: 0, Delta: 0.0
# Perform Episode - Update Type 3 - State: 6, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 6: 1.0
# Norm of Q-values: 0.5
# delta (3) - State: 5, Action: 0, Delta: 0.0
# Perform Episode - Update Type 3 - State: 5, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 5: 1.0
# Norm of Q-values: 0.5
# delta (3) - State: 5, Action: 3, Delta: 0.0
# Perform Episode - Update Type 3 - State: 5, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 5: 1.0
# Norm of Q-values: 0.5
# delta (3) - State: 0, Action: 1, Delta: 0.0
# Perform Episode - Update Type 3 - State: 0, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 0: 1.0
# Norm of Q-values: 0.5
# delta (3) - State: 1, Action: 0, Delta: 0.0
# Perform Episode - Update Type 3 - State: 1, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 1: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 19/30
# Step: 0, State: 22, Terminated: False, Truncated: False
# delta (3) - State: 22, Action: 1, Delta: 0.0
# Perform Episode - Update Type 3 - State: 22, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 22: 1.0
# Norm of Q-values: 0.5
# delta (3) - State: 23, Action: 3, Delta: 0.0
# Perform Episode - Update Type 3 - State: 23, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 23: 1.0
# Norm of Q-values: 0.5
# delta (3) - State: 18, Action: 0, Delta: 0.0
# Perform Episode - Update Type 3 - State: 18, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 18: 1.0
# Norm of Q-values: 0.5
# delta (3) - State: 17, Action: 1, Delta: 0.0
# Perform Episode - Update Type 3 - State: 17, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 17: 1.0
# Norm of Q-values: 0.5
# delta (3) - State: 18, Action: 1, Delta: 0.0
# Perform Episode - Update Type 3 - State: 18, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 18: 1.0
# Norm of Q-values: 0.5
# delta (3) - State: 19, Action: 0, Delta: 0.0
# Perform Episode - Update Type 3 - State: 19, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 19: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 20/30
# Step: 0, State: 10, Terminated: False, Truncated: False
# delta (3) - State: 10, Action: 0, Delta: 0.0
# Perform Episode - Update Type 3 - State: 10, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 10: 1.0
# Norm of Q-values: 0.5
# delta (3) - State: 10, Action: 3, Delta: 0.0
# Perform Episode - Update Type 3 - State: 10, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 10: 1.0
# Norm of Q-values: 0.5
# delta (3) - State: 5, Action: 2, Delta: 0.0
# Perform Episode - Update Type 3 - State: 5, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 5: 1.0
# Norm of Q-values: 0.5
# delta (3) - State: 10, Action: 0, Delta: 0.0
# Perform Episode - Update Type 3 - State: 10, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 10: 1.0
# Norm of Q-values: 0.5
# delta (3) - State: 10, Action: 1, Delta: 0.0
# Perform Episode - Update Type 3 - State: 10, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 10: 1.0
# Norm of Q-values: 0.5
# delta (3) - State: 11, Action: 0, Delta: 0.0
# Perform Episode - Update Type 3 - State: 11, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 11: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 21/30
# Step: 0, State: 23, Terminated: False, Truncated: False
# delta (3) - State: 23, Action: 1, Delta: 0.45
# Perform Episode - Update Type 3 - State: 23, Sum Q: 0.0, Delta: 0.45
# Policy sum for state 23: 0.9999999999999999
# Norm of Q-values: 0.5482928049865328
# delta (3) - State: 24, Action: 3, Delta: 0.75
# Perform Episode - Update Type 3 - State: 24, Sum Q: 0.25, Delta: 0.75
# Policy sum for state 24: 1.0
# Norm of Q-values: 0.9034655499796326
#  Actor_critic_q function - looping Episode 22/30
# Step: 0, State: 4, Terminated: False, Truncated: False
# delta (3) - State: 4, Action: 3, Delta: 0.0
# Perform Episode - Update Type 3 - State: 4, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 4: 1.0
# Norm of Q-values: 0.9034655499796326
# delta (3) - State: 4, Action: 0, Delta: 0.0
# Perform Episode - Update Type 3 - State: 4, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 4: 1.0
# Norm of Q-values: 0.9034655499796326
# delta (3) - State: 3, Action: 3, Delta: 0.0
# Perform Episode - Update Type 3 - State: 3, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 3: 1.0
# Norm of Q-values: 0.9034655499796326
# delta (3) - State: 3, Action: 0, Delta: 0.0
# Perform Episode - Update Type 3 - State: 3, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 3: 1.0
# Norm of Q-values: 0.9034655499796326
# delta (3) - State: 2, Action: 1, Delta: 0.0
# Perform Episode - Update Type 3 - State: 2, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 2: 1.0
# Norm of Q-values: 0.9034655499796326
# delta (3) - State: 3, Action: 2, Delta: 0.0
# Perform Episode - Update Type 3 - State: 3, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 3: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 23/30
# Step: 0, State: 4, Terminated: False, Truncated: False
# delta (3) - State: 4, Action: 2, Delta: 0.0
# Perform Episode - Update Type 3 - State: 4, Sum Q: 0.0, Delta: 0.0
# Policy sum for state 4: 1.0
# Norm of Q-values: 0.9034655499796326
# delta (3) - State: 9, Action: 3, Delta: 0.0
# ...
# Step: 0, State: 12, Terminated: False, Truncated: False
# delta (4) - State: 12, Action: 2, Delta: 0.0
# Policy sum for state 12: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 17, Action: 0, Delta: 0.0
# Policy sum for state 17: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 16, Action: 3, Delta: 0.0
# Policy sum for state 16: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 11, Action: 3, Delta: 0.0
# Policy sum for state 11: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 6, Action: 0, Delta: 0.0
# Policy sum for state 6: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 5, Action: 2, Delta: 0.0
# Policy sum for state 5: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 9/30
# Step: 0, State: 21, Terminated: False, Truncated: False
# delta (4) - State: 21, Action: 3, Delta: 0.0
# Policy sum for state 21: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 16, Action: 0, Delta: 0.0
# Policy sum for state 16: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 15, Action: 0, Delta: 0.0
# Policy sum for state 15: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 15, Action: 0, Delta: 0.0
# Policy sum for state 15: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 15, Action: 1, Delta: 0.0
# Policy sum for state 15: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 16, Action: 0, Delta: 0.0
# Policy sum for state 16: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 10/30
# Step: 0, State: 3, Terminated: False, Truncated: False
# delta (4) - State: 3, Action: 3, Delta: 0.0
# Policy sum for state 3: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 3, Action: 0, Delta: 0.0
# Policy sum for state 3: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 2, Action: 0, Delta: 0.0
# Policy sum for state 2: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 1, Action: 0, Delta: 0.0
# Policy sum for state 1: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 0, Action: 3, Delta: 0.0
# Policy sum for state 0: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 0, Action: 2, Delta: 0.0
# Policy sum for state 0: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 11/30
# Step: 0, State: 15, Terminated: False, Truncated: False
# delta (4) - State: 15, Action: 3, Delta: 0.0
# Policy sum for state 15: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 10, Action: 1, Delta: 0.0
# Policy sum for state 10: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 11, Action: 1, Delta: 0.0
# Policy sum for state 11: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 12, Action: 1, Delta: 0.0
# Policy sum for state 12: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 13, Action: 3, Delta: 0.0
# Policy sum for state 13: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 8, Action: 1, Delta: 0.0
# Policy sum for state 8: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 12/30
# Step: 0, State: 15, Terminated: False, Truncated: False
# delta (4) - State: 15, Action: 2, Delta: 0.0
# Policy sum for state 15: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 20, Action: 1, Delta: 0.0
# Policy sum for state 20: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 21, Action: 0, Delta: 0.0
# Policy sum for state 21: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 20, Action: 3, Delta: 0.0
# Policy sum for state 20: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 15, Action: 0, Delta: 0.0
# Policy sum for state 15: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 15, Action: 1, Delta: 0.0
# Policy sum for state 15: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 13/30
# Step: 0, State: 6, Terminated: False, Truncated: False
# delta (4) - State: 6, Action: 3, Delta: 0.0
# Policy sum for state 6: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 1, Action: 2, Delta: 0.0
# Policy sum for state 1: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 6, Action: 2, Delta: 0.0
# Policy sum for state 6: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 11, Action: 2, Delta: 0.0
# Policy sum for state 11: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 16, Action: 1, Delta: 0.0
# Policy sum for state 16: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 17, Action: 1, Delta: 0.0
# Policy sum for state 17: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 14/30
# Step: 0, State: 22, Terminated: False, Truncated: False
# delta (4) - State: 22, Action: 3, Delta: 0.0
# Policy sum for state 22: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 17, Action: 0, Delta: 0.0
# Policy sum for state 17: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 16, Action: 0, Delta: 0.0
# Policy sum for state 16: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 15, Action: 1, Delta: 0.0
# Policy sum for state 15: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 16, Action: 0, Delta: 0.0
# Policy sum for state 16: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 15, Action: 3, Delta: 0.0
# Policy sum for state 15: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 15/30
# Step: 0, State: 4, Terminated: False, Truncated: False
# delta (4) - State: 4, Action: 2, Delta: 0.0
# Policy sum for state 4: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 9, Action: 3, Delta: 0.0
# Policy sum for state 9: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 4, Action: 3, Delta: 0.0
# Policy sum for state 4: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 4, Action: 1, Delta: 0.0
# Policy sum for state 4: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 4, Action: 0, Delta: 0.0
# Policy sum for state 4: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 3, Action: 2, Delta: 0.0
# Policy sum for state 3: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 16/30
# Step: 0, State: 7, Terminated: False, Truncated: False
# delta (4) - State: 7, Action: 1, Delta: 0.0
# Policy sum for state 7: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 8, Action: 1, Delta: 0.0
# Policy sum for state 8: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 9, Action: 2, Delta: 0.0
# Policy sum for state 9: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 14, Action: 1, Delta: 0.0
# Policy sum for state 14: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 14, Action: 3, Delta: 0.0
# Policy sum for state 14: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 9, Action: 0, Delta: 0.0
# Policy sum for state 9: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 17/30
# Step: 0, State: 15, Terminated: False, Truncated: False
# delta (4) - State: 15, Action: 2, Delta: 0.0
# Policy sum for state 15: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 20, Action: 1, Delta: 0.0
# Policy sum for state 20: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 21, Action: 1, Delta: 0.0
# Policy sum for state 21: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 22, Action: 3, Delta: 0.0
# Policy sum for state 22: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 17, Action: 0, Delta: 0.0
# Policy sum for state 17: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 16, Action: 1, Delta: 0.0
# Policy sum for state 16: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 18/30
# Step: 0, State: 22, Terminated: False, Truncated: False
# delta (4) - State: 22, Action: 1, Delta: 0.0
# Policy sum for state 22: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 23, Action: 3, Delta: 0.0
# Policy sum for state 23: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 18, Action: 3, Delta: 0.0
# Policy sum for state 18: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 13, Action: 3, Delta: 0.0
# Policy sum for state 13: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 8, Action: 2, Delta: 0.0
# Policy sum for state 8: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 13, Action: 2, Delta: 0.0
# Policy sum for state 13: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 19/30
# Step: 0, State: 14, Terminated: False, Truncated: False
# delta (4) - State: 14, Action: 1, Delta: 0.0
# Policy sum for state 14: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 14, Action: 0, Delta: 0.0
# Policy sum for state 14: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 13, Action: 2, Delta: 0.0
# Policy sum for state 13: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 18, Action: 1, Delta: 0.0
# Policy sum for state 18: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 19, Action: 3, Delta: 0.0
# Policy sum for state 19: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 14, Action: 1, Delta: 0.0
# Policy sum for state 14: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 20/30
# Step: 0, State: 14, Terminated: False, Truncated: False
# delta (4) - State: 14, Action: 2, Delta: 0.0
# Policy sum for state 14: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 19, Action: 3, Delta: 0.0
# Policy sum for state 19: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 14, Action: 3, Delta: 0.0
# Policy sum for state 14: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 9, Action: 3, Delta: 0.0
# Policy sum for state 9: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 4, Action: 3, Delta: 0.0
# Policy sum for state 4: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 4, Action: 3, Delta: 0.0
# Policy sum for state 4: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 21/30
# Step: 0, State: 22, Terminated: False, Truncated: False
# delta (4) - State: 22, Action: 0, Delta: 0.0
# Policy sum for state 22: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 21, Action: 0, Delta: 0.0
# Policy sum for state 21: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 20, Action: 3, Delta: 0.0
# Policy sum for state 20: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 15, Action: 1, Delta: 0.0
# Policy sum for state 15: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 16, Action: 1, Delta: 0.0
# Policy sum for state 16: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 17, Action: 0, Delta: 0.0
# Policy sum for state 17: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 22/30
# Step: 0, State: 10, Terminated: False, Truncated: False
# delta (4) - State: 10, Action: 3, Delta: 0.0
# Policy sum for state 10: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 5, Action: 2, Delta: 0.0
# Policy sum for state 5: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 10, Action: 2, Delta: 0.0
# Policy sum for state 10: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 15, Action: 0, Delta: 0.0
# Policy sum for state 15: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 15, Action: 2, Delta: 0.0
# Policy sum for state 15: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 20, Action: 0, Delta: 0.0
# Policy sum for state 20: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 23/30
# Step: 0, State: 24, Terminated: False, Truncated: False
# delta (4) - State: 24, Action: 1, Delta: 1.0
# Policy sum for state 24: 0.9999999999999999
# Norm of Q-values: 0.5
#  Actor_critic_q function - looping Episode 24/30
# Step: 0, State: 15, Terminated: False, Truncated: False
# delta (4) - State: 15, Action: 0, Delta: 0.0
# Policy sum for state 15: 1.0
# Norm of Q-values: 0.5
# delta (4) - State: 15, Action: 0, Delta: 0.0
# Policy sum for state 15: 1.0
# Norm of Q-values: 0.5
# delta (4) - State: 15, Action: 2, Delta: 0.0
# Policy sum for state 15: 1.0
# Norm of Q-values: 0.5
# delta (4) - State: 20, Action: 0, Delta: 0.0
# Policy sum for state 20: 1.0
# Norm of Q-values: 0.5
# delta (4) - State: 20, Action: 0, Delta: 0.0
# Policy sum for state 20: 1.0
# Norm of Q-values: 0.5
# delta (4) - State: 20, Action: 2, Delta: 0.0
# Policy sum for state 20: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 25/30
# Step: 0, State: 7, Terminated: False, Truncated: False
# delta (4) - State: 7, Action: 2, Delta: 0.0
# Policy sum for state 7: 1.0
# Norm of Q-values: 0.5
# delta (4) - State: 12, Action: 1, Delta: 0.0
# Policy sum for state 12: 1.0
# Norm of Q-values: 0.5
# delta (4) - State: 13, Action: 3, Delta: 0.0
# Policy sum for state 13: 1.0
# Norm of Q-values: 0.5
# delta (4) - State: 8, Action: 2, Delta: 0.0
# Policy sum for state 8: 1.0
# Norm of Q-values: 0.5
# delta (4) - State: 13, Action: 2, Delta: 0.0
# Policy sum for state 13: 1.0
# Norm of Q-values: 0.5
# delta (4) - State: 18, Action: 1, Delta: 0.0
# Policy sum for state 18: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 26/30
# Step: 0, State: 21, Terminated: False, Truncated: False
# delta (4) - State: 21, Action: 0, Delta: 0.0
# Policy sum for state 21: 1.0
# Norm of Q-values: 0.5
# delta (4) - State: 20, Action: 2, Delta: 0.0
# Policy sum for state 20: 1.0
# Norm of Q-values: 0.5
# delta (4) - State: 20, Action: 0, Delta: 0.0
# Policy sum for state 20: 1.0
# Norm of Q-values: 0.5
# delta (4) - State: 20, Action: 2, Delta: 0.0
# Policy sum for state 20: 1.0
# Norm of Q-values: 0.5
# delta (4) - State: 20, Action: 1, Delta: 0.0
# Policy sum for state 20: 1.0
# Norm of Q-values: 0.5
# delta (4) - State: 21, Action: 0, Delta: 0.0
# Policy sum for state 21: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 27/30
# Step: 0, State: 11, Terminated: False, Truncated: False
# delta (4) - State: 11, Action: 1, Delta: 0.0
# Policy sum for state 11: 1.0
# Norm of Q-values: 0.5
# delta (4) - State: 12, Action: 3, Delta: 0.0
# Policy sum for state 12: 1.0
# Norm of Q-values: 0.5
# delta (4) - State: 7, Action: 0, Delta: 0.0
# Policy sum for state 7: 1.0
# Norm of Q-values: 0.5
# delta (4) - State: 6, Action: 1, Delta: 0.0
# Policy sum for state 6: 1.0
# Norm of Q-values: 0.5
# delta (4) - State: 7, Action: 3, Delta: 0.0
# Policy sum for state 7: 1.0
# Norm of Q-values: 0.5
# delta (4) - State: 2, Action: 1, Delta: 0.0
# Policy sum for state 2: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 28/30
# Step: 0, State: 16, Terminated: False, Truncated: False
# delta (4) - State: 16, Action: 2, Delta: 0.0
# Policy sum for state 16: 1.0
# Norm of Q-values: 0.5
# delta (4) - State: 21, Action: 0, Delta: 0.0
# Policy sum for state 21: 1.0
# Norm of Q-values: 0.5
# delta (4) - State: 20, Action: 2, Delta: 0.0
# Policy sum for state 20: 1.0
# Norm of Q-values: 0.5
# delta (4) - State: 20, Action: 3, Delta: 0.0
# Policy sum for state 20: 1.0
# Norm of Q-values: 0.5
# delta (4) - State: 15, Action: 0, Delta: 0.0
# Policy sum for state 15: 1.0
# Norm of Q-values: 0.5
# delta (4) - State: 15, Action: 2, Delta: 0.0
# Policy sum for state 15: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 29/30
# Step: 0, State: 22, Terminated: False, Truncated: False
# delta (4) - State: 22, Action: 3, Delta: 0.0
# Policy sum for state 22: 1.0
# Norm of Q-values: 0.5
# delta (4) - State: 17, Action: 1, Delta: 0.0
# Policy sum for state 17: 1.0
# Norm of Q-values: 0.5
# delta (4) - State: 18, Action: 3, Delta: 0.0
# Policy sum for state 18: 1.0
# Norm of Q-values: 0.5
# delta (4) - State: 13, Action: 3, Delta: 0.0
# Policy sum for state 13: 1.0
# Norm of Q-values: 0.5
# delta (4) - State: 8, Action: 2, Delta: 0.0
# Policy sum for state 8: 1.0
# Norm of Q-values: 0.5
# delta (4) - State: 13, Action: 2, Delta: 0.0
# Policy sum for state 13: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 30/30
# Step: 0, State: 20, Terminated: False, Truncated: False
# delta (4) - State: 20, Action: 2, Delta: 0.0
# Policy sum for state 20: 1.0
# Norm of Q-values: 0.5
# delta (4) - State: 20, Action: 0, Delta: 0.0
# Policy sum for state 20: 1.0
# Norm of Q-values: 0.5
# delta (4) - State: 20, Action: 1, Delta: 0.0
# Policy sum for state 20: 1.0
# Norm of Q-values: 0.5
# delta (4) - State: 21, Action: 1, Delta: 0.0
# Policy sum for state 21: 1.0
# Norm of Q-values: 0.5
# delta (4) - State: 22, Action: 3, Delta: 0.0
# Policy sum for state 22: 1.0
# Norm of Q-values: 0.5
# delta (4) - State: 17, Action: 0, Delta: 0.0
# Policy sum for state 17: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#
# Summary Table:
#     Update Rule  Mean Steps  Standard Deviation
# 0        SARSA    5.506667            0.483690
# 1   Q-learning    5.513333            0.523280
# 2   Mean SARSA    5.653333            0.511034
# 3  Fourth Rule    5.766667            0.358081
# nb_episodes: 30

# %% [markdown]
# ### More tests...

# %%
ac_params = {
    "save_curves": False,
    "save_heatmap": True,
    "mdp": {
        "name": "MazeMDP-v0",
        "width": 5,
        "height": 5,
        "ratio": 0.2,
        "render_mode": "rgb_array",
        },

    "log_dir": "./tmp",
    "video_dir": "./tmp/videos",

    "nb_episodes": 100,
    "render": False, # True, #
    "nb_repeats": 5,

    "alpha_critic": 0.8, # ICI ON AUGMENTE LEARNING RATE DU CRITIC (because drives actor's LR)
    "alpha_actor": 0.5,
    }

cfg=OmegaConf.create(ac_params)
mdp = make_mdp(cfg) # the mdp is made once and for all, this is an ugly global variable

import time
from datetime import timedelta
N = 100

start_time = time.time()  # mesurer temps
plot_steps(nb_runs=N)
end_time = time.time()

elapsed_time = timedelta(seconds=(end_time - start_time))
print(f"Temps d'exécution pour {N} runs : {elapsed_time}")

# print("average v value:", v_vals.mean())
# Out:
# Streaming output truncated to the last 5000 lines.
# Policy sum for state 3: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 3, Action: 1, Delta: 0.0
# Policy sum for state 3: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 3, Action: 3, Delta: 0.0
# Policy sum for state 3: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 3, Action: 3, Delta: 0.0
# Policy sum for state 3: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 3, Action: 0, Delta: 0.0
# Policy sum for state 3: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 3, Action: 1, Delta: 0.0
# Policy sum for state 3: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 17/20
# Step: 0, State: 16, Terminated: False, Truncated: False
# delta (4) - State: 16, Action: 0, Delta: 0.0
# Policy sum for state 16: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 16, Action: 3, Delta: 0.0
# Policy sum for state 16: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 12, Action: 0, Delta: 0.0
# Policy sum for state 12: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 12, Action: 0, Delta: 0.0
# Policy sum for state 12: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 12, Action: 1, Delta: 0.0
# Policy sum for state 12: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 13, Action: 2, Delta: 0.0
# Policy sum for state 13: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 18/20
# Step: 0, State: 19, Terminated: False, Truncated: False
# delta (4) - State: 19, Action: 1, Delta: 1.0
# Policy sum for state 19: 0.9999999999999999
# Norm of Q-values: 0.01414213562373095
#  Actor_critic_q function - looping Episode 19/20
# Step: 0, State: 15, Terminated: False, Truncated: False
# delta (4) - State: 15, Action: 0, Delta: 0.0
# Policy sum for state 15: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 14, Action: 3, Delta: 0.0
# Policy sum for state 14: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 14, Action: 3, Delta: 0.0
# Policy sum for state 14: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 14, Action: 0, Delta: 0.0
# Policy sum for state 14: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 13, Action: 0, Delta: 0.0
# Policy sum for state 13: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 12, Action: 3, Delta: 0.0
# Policy sum for state 12: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 20/20
# Step: 0, State: 14, Terminated: False, Truncated: False
# delta (4) - State: 14, Action: 3, Delta: 0.0
# Policy sum for state 14: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 14, Action: 1, Delta: 0.0
# Policy sum for state 14: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 15, Action: 0, Delta: 0.0
# Policy sum for state 15: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 14, Action: 2, Delta: 0.0
# Policy sum for state 14: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 14, Action: 1, Delta: 0.0
# Policy sum for state 14: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 15, Action: 0, Delta: 0.0
# Policy sum for state 15: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
# Plot_steps funtion - Run 88 of 100
#  Actor_critic_q function - looping Episode 1/20
# Step: 0, State: 14, Terminated: False, Truncated: False
# delta (4) - State: 14, Action: 0, Delta: 0.0
# Policy sum for state 14: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 13, Action: 2, Delta: 0.0
# Policy sum for state 13: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 17, Action: 3, Delta: 0.0
# Policy sum for state 17: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 13, Action: 3, Delta: 0.0
# Policy sum for state 13: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 13, Action: 3, Delta: 0.0
# Policy sum for state 13: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 13, Action: 0, Delta: 0.0
# Policy sum for state 13: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 2/20
# Step: 0, State: 11, Terminated: False, Truncated: False
# delta (4) - State: 11, Action: 0, Delta: 0.0
# Policy sum for state 11: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 10, Action: 0, Delta: 0.0
# Policy sum for state 10: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 10, Action: 2, Delta: 0.0
# Policy sum for state 10: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 15, Action: 2, Delta: 0.0
# Policy sum for state 15: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 18, Action: 2, Delta: 0.0
# Policy sum for state 18: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 18, Action: 0, Delta: 0.0
# Policy sum for state 18: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 3/20
# Step: 0, State: 19, Terminated: False, Truncated: False
# delta (4) - State: 19, Action: 3, Delta: 1.0
# Policy sum for state 19: 1.0
# Norm of Q-values: 0.01
#  Actor_critic_q function - looping Episode 4/20
# Step: 0, State: 17, Terminated: False, Truncated: False
# delta (4) - State: 17, Action: 3, Delta: 0.0
# Policy sum for state 17: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 13, Action: 2, Delta: 0.0
# Policy sum for state 13: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 17, Action: 3, Delta: 0.0
# Policy sum for state 17: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 13, Action: 2, Delta: 0.0
# Policy sum for state 13: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 17, Action: 3, Delta: 0.0
# Policy sum for state 17: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 13, Action: 2, Delta: 0.0
# Policy sum for state 13: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 5/20
# Step: 0, State: 11, Terminated: False, Truncated: False
# delta (4) - State: 11, Action: 3, Delta: 0.0
# Policy sum for state 11: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 8, Action: 0, Delta: 0.0
# Policy sum for state 8: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 7, Action: 0, Delta: 0.0
# Policy sum for state 7: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 6, Action: 1, Delta: 0.0
# Policy sum for state 6: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 7, Action: 3, Delta: 0.0
# Policy sum for state 7: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 7, Action: 3, Delta: 0.0
# Policy sum for state 7: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 6/20
# Step: 0, State: 0, Terminated: False, Truncated: False
# delta (4) - State: 0, Action: 0, Delta: 0.0
# Policy sum for state 0: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 0, Action: 1, Delta: 0.0
# Policy sum for state 0: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 1, Action: 2, Delta: 0.0
# Policy sum for state 1: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 5, Action: 2, Delta: 0.0
# Policy sum for state 5: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 5, Action: 3, Delta: 0.0
# Policy sum for state 5: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 1, Action: 3, Delta: 0.0
# Policy sum for state 1: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 7/20
# Step: 0, State: 1, Terminated: False, Truncated: False
# delta (4) - State: 1, Action: 2, Delta: 0.0
# Policy sum for state 1: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 5, Action: 2, Delta: 0.0
# Policy sum for state 5: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 5, Action: 2, Delta: 0.0
# Policy sum for state 5: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 5, Action: 1, Delta: 0.0
# Policy sum for state 5: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 6, Action: 2, Delta: 0.0
# Policy sum for state 6: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 6, Action: 0, Delta: 0.0
# Policy sum for state 6: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 8/20
# Step: 0, State: 13, Terminated: False, Truncated: False
# delta (4) - State: 13, Action: 1, Delta: 0.0
# Policy sum for state 13: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 14, Action: 0, Delta: 0.0
# Policy sum for state 14: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 13, Action: 2, Delta: 0.0
# Policy sum for state 13: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 17, Action: 2, Delta: 0.0
# Policy sum for state 17: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 17, Action: 2, Delta: 0.0
# Policy sum for state 17: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 17, Action: 2, Delta: 0.0
# Policy sum for state 17: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 9/20
# Step: 0, State: 13, Terminated: False, Truncated: False
# delta (4) - State: 13, Action: 0, Delta: 0.0
# Policy sum for state 13: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 12, Action: 1, Delta: 0.0
# Policy sum for state 12: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 13, Action: 0, Delta: 0.0
# Policy sum for state 13: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 12, Action: 0, Delta: 0.0
# Policy sum for state 12: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 12, Action: 2, Delta: 0.0
# Policy sum for state 12: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 16, Action: 3, Delta: 0.0
# Policy sum for state 16: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 10/20
# Step: 0, State: 19, Terminated: False, Truncated: False
# delta (4) - State: 19, Action: 2, Delta: 1.0
# Policy sum for state 19: 1.0
# Norm of Q-values: 0.01414213562373095
#  Actor_critic_q function - looping Episode 11/20
# Step: 0, State: 5, Terminated: False, Truncated: False
# delta (4) - State: 5, Action: 1, Delta: 0.0
# Policy sum for state 5: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 6, Action: 0, Delta: 0.0
# Policy sum for state 6: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 5, Action: 0, Delta: 0.0
# Policy sum for state 5: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 4, Action: 3, Delta: 0.0
# Policy sum for state 4: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 0, Action: 0, Delta: 0.0
# Policy sum for state 0: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 0, Action: 3, Delta: 0.0
# Policy sum for state 0: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 12/20
# Step: 0, State: 0, Terminated: False, Truncated: False
# delta (4) - State: 0, Action: 3, Delta: 0.0
# Policy sum for state 0: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 0, Action: 3, Delta: 0.0
# Policy sum for state 0: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 0, Action: 1, Delta: 0.0
# Policy sum for state 0: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 1, Action: 3, Delta: 0.0
# Policy sum for state 1: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 1, Action: 3, Delta: 0.0
# Policy sum for state 1: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 1, Action: 1, Delta: 0.0
# Policy sum for state 1: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 13/20
# Step: 0, State: 1, Terminated: False, Truncated: False
# delta (4) - State: 1, Action: 1, Delta: 0.0
# Policy sum for state 1: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 2, Action: 2, Delta: 0.0
# Policy sum for state 2: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 6, Action: 0, Delta: 0.0
# Policy sum for state 6: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 5, Action: 3, Delta: 0.0
# Policy sum for state 5: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 1, Action: 1, Delta: 0.0
# Policy sum for state 1: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 2, Action: 0, Delta: 0.0
# Policy sum for state 2: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 14/20
# Step: 0, State: 14, Terminated: False, Truncated: False
# delta (4) - State: 14, Action: 1, Delta: 0.0
# Policy sum for state 14: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 15, Action: 3, Delta: 0.0
# Policy sum for state 15: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 10, Action: 1, Delta: 0.0
# Policy sum for state 10: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 11, Action: 3, Delta: 0.0
# Policy sum for state 11: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 8, Action: 3, Delta: 0.0
# Policy sum for state 8: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 3, Action: 1, Delta: 0.0
# Policy sum for state 3: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 15/20
# Step: 0, State: 0, Terminated: False, Truncated: False
# delta (4) - State: 0, Action: 3, Delta: 0.0
# Policy sum for state 0: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 0, Action: 3, Delta: 0.0
# Policy sum for state 0: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 0, Action: 2, Delta: 0.0
# Policy sum for state 0: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 4, Action: 2, Delta: 0.0
# Policy sum for state 4: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 9, Action: 3, Delta: 0.0
# Policy sum for state 9: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 4, Action: 0, Delta: 0.0
# Policy sum for state 4: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 16/20
# Step: 0, State: 15, Terminated: False, Truncated: False
# delta (4) - State: 15, Action: 0, Delta: 0.0
# Policy sum for state 15: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 14, Action: 0, Delta: 0.0
# Policy sum for state 14: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 13, Action: 1, Delta: 0.0
# Policy sum for state 13: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 14, Action: 2, Delta: 0.0
# Policy sum for state 14: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 14, Action: 2, Delta: 0.0
# Policy sum for state 14: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 14, Action: 2, Delta: 0.0
# Policy sum for state 14: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 17/20
# Step: 0, State: 13, Terminated: False, Truncated: False
# delta (4) - State: 13, Action: 3, Delta: 0.0
# Policy sum for state 13: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 13, Action: 2, Delta: 0.0
# Policy sum for state 13: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 17, Action: 3, Delta: 0.0
# Policy sum for state 17: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 13, Action: 3, Delta: 0.0
# Policy sum for state 13: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 13, Action: 1, Delta: 0.0
# Policy sum for state 13: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 14, Action: 1, Delta: 0.0
# Policy sum for state 14: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 18/20
# Step: 0, State: 13, Terminated: False, Truncated: False
# delta (4) - State: 13, Action: 3, Delta: 0.0
# Policy sum for state 13: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 13, Action: 3, Delta: 0.0
# Policy sum for state 13: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 13, Action: 0, Delta: 0.0
# Policy sum for state 13: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 12, Action: 2, Delta: 0.0
# Policy sum for state 12: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 16, Action: 2, Delta: 0.0
# Policy sum for state 16: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 16, Action: 2, Delta: 0.0
# Policy sum for state 16: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 19/20
# Step: 0, State: 19, Terminated: False, Truncated: False
# delta (4) - State: 19, Action: 0, Delta: 1.0
# Policy sum for state 19: 0.9999999999999999
# Norm of Q-values: 0.017320508075688773
#  Actor_critic_q function - looping Episode 20/20
# Step: 0, State: 6, Terminated: False, Truncated: False
# delta (4) - State: 6, Action: 0, Delta: 0.0
# Policy sum for state 6: 1.0
# Norm of Q-values: 0.017320508075688773
# delta (4) - State: 5, Action: 1, Delta: 0.0
# Policy sum for state 5: 1.0
# Norm of Q-values: 0.017320508075688773
# delta (4) - State: 6, Action: 2, Delta: 0.0
# Policy sum for state 6: 1.0
# Norm of Q-values: 0.017320508075688773
# delta (4) - State: 6, Action: 1, Delta: 0.0
# Policy sum for state 6: 1.0
# Norm of Q-values: 0.017320508075688773
# delta (4) - State: 7, Action: 0, Delta: 0.0
# Policy sum for state 7: 1.0
# Norm of Q-values: 0.017320508075688773
# delta (4) - State: 6, Action: 1, Delta: 0.0
# Policy sum for state 6: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
# Plot_steps funtion - Run 89 of 100
#  Actor_critic_q function - looping Episode 1/20
# Step: 0, State: 3, Terminated: False, Truncated: False
# delta (4) - State: 3, Action: 3, Delta: 0.0
# Policy sum for state 3: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 3, Action: 1, Delta: 0.0
# Policy sum for state 3: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 3, Action: 3, Delta: 0.0
# Policy sum for state 3: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 3, Action: 1, Delta: 0.0
# Policy sum for state 3: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 3, Action: 2, Delta: 0.0
# Policy sum for state 3: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 8, Action: 1, Delta: 0.0
# Policy sum for state 8: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 2/20
# Step: 0, State: 15, Terminated: False, Truncated: False
# delta (4) - State: 15, Action: 1, Delta: 0.0
# Policy sum for state 15: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 15, Action: 3, Delta: 0.0
# Policy sum for state 15: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 10, Action: 3, Delta: 0.0
# Policy sum for state 10: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 7, Action: 2, Delta: 0.0
# Policy sum for state 7: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 10, Action: 0, Delta: 0.0
# Policy sum for state 10: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 10, Action: 2, Delta: 0.0
# Policy sum for state 10: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 3/20
# Step: 0, State: 13, Terminated: False, Truncated: False
# delta (4) - State: 13, Action: 0, Delta: 0.0
# Policy sum for state 13: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 12, Action: 1, Delta: 0.0
# Policy sum for state 12: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 13, Action: 3, Delta: 0.0
# Policy sum for state 13: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 13, Action: 0, Delta: 0.0
# Policy sum for state 13: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 12, Action: 1, Delta: 0.0
# Policy sum for state 12: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 13, Action: 0, Delta: 0.0
# Policy sum for state 13: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 4/20
# Step: 0, State: 10, Terminated: False, Truncated: False
# delta (4) - State: 10, Action: 2, Delta: 0.0
# Policy sum for state 10: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 15, Action: 3, Delta: 0.0
# Policy sum for state 15: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 10, Action: 3, Delta: 0.0
# Policy sum for state 10: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 7, Action: 3, Delta: 0.0
# Policy sum for state 7: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 7, Action: 0, Delta: 0.0
# Policy sum for state 7: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 6, Action: 2, Delta: 0.0
# Policy sum for state 6: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 5/20
# Step: 0, State: 6, Terminated: False, Truncated: False
# delta (4) - State: 6, Action: 2, Delta: 0.0
# Policy sum for state 6: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 6, Action: 2, Delta: 0.0
# Policy sum for state 6: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 6, Action: 0, Delta: 0.0
# Policy sum for state 6: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 5, Action: 1, Delta: 0.0
# Policy sum for state 5: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 6, Action: 2, Delta: 0.0
# Policy sum for state 6: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 6, Action: 0, Delta: 0.0
# Policy sum for state 6: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 6/20
# Step: 0, State: 19, Terminated: False, Truncated: False
# delta (4) - State: 19, Action: 0, Delta: 1.0
# Policy sum for state 19: 1.0
# Norm of Q-values: 0.01
#  Actor_critic_q function - looping Episode 7/20
# Step: 0, State: 19, Terminated: False, Truncated: False
# delta (4) - State: 19, Action: 2, Delta: 1.0
# Policy sum for state 19: 0.9999999999999999
# Norm of Q-values: 0.01414213562373095
#  Actor_critic_q function - looping Episode 8/20
# Step: 0, State: 8, Terminated: False, Truncated: False
# delta (4) - State: 8, Action: 2, Delta: 0.0
# Policy sum for state 8: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 11, Action: 1, Delta: 0.0
# Policy sum for state 11: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 11, Action: 0, Delta: 0.0
# Policy sum for state 11: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 10, Action: 2, Delta: 0.0
# Policy sum for state 10: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 15, Action: 0, Delta: 0.0
# Policy sum for state 15: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 14, Action: 0, Delta: 0.0
# Policy sum for state 14: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 9/20
# Step: 0, State: 2, Terminated: False, Truncated: False
# delta (4) - State: 2, Action: 3, Delta: 0.0
# Policy sum for state 2: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 2, Action: 2, Delta: 0.0
# Policy sum for state 2: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 6, Action: 1, Delta: 0.0
# Policy sum for state 6: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 7, Action: 3, Delta: 0.0
# Policy sum for state 7: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 7, Action: 0, Delta: 0.0
# Policy sum for state 7: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 6, Action: 2, Delta: 0.0
# Policy sum for state 6: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 10/20
# Step: 0, State: 9, Terminated: False, Truncated: False
# delta (4) - State: 9, Action: 3, Delta: 0.0
# Policy sum for state 9: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 4, Action: 3, Delta: 0.0
# Policy sum for state 4: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 0, Action: 0, Delta: 0.0
# Policy sum for state 0: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 0, Action: 0, Delta: 0.0
# Policy sum for state 0: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 0, Action: 1, Delta: 0.0
# Policy sum for state 0: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 1, Action: 1, Delta: 0.0
# Policy sum for state 1: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 11/20
# Step: 0, State: 11, Terminated: False, Truncated: False
# delta (4) - State: 11, Action: 2, Delta: 0.0
# Policy sum for state 11: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 11, Action: 2, Delta: 0.0
# Policy sum for state 11: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 11, Action: 0, Delta: 0.0
# Policy sum for state 11: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 10, Action: 2, Delta: 0.0
# Policy sum for state 10: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 15, Action: 2, Delta: 0.0
# Policy sum for state 15: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 18, Action: 2, Delta: 0.0
# Policy sum for state 18: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 12/20
# Step: 0, State: 5, Terminated: False, Truncated: False
# delta (4) - State: 5, Action: 3, Delta: 0.0
# Policy sum for state 5: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 1, Action: 3, Delta: 0.0
# Policy sum for state 1: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 1, Action: 2, Delta: 0.0
# Policy sum for state 1: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 5, Action: 2, Delta: 0.0
# Policy sum for state 5: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 5, Action: 3, Delta: 0.0
# Policy sum for state 5: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 1, Action: 2, Delta: 0.0
# Policy sum for state 1: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 13/20
# Step: 0, State: 10, Terminated: False, Truncated: False
# delta (4) - State: 10, Action: 3, Delta: 0.0
# Policy sum for state 10: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 7, Action: 2, Delta: 0.0
# Policy sum for state 7: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 10, Action: 2, Delta: 0.0
# Policy sum for state 10: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 15, Action: 1, Delta: 0.0
# Policy sum for state 15: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 15, Action: 1, Delta: 0.0
# Policy sum for state 15: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 15, Action: 3, Delta: 0.0
# Policy sum for state 15: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 14/20
# Step: 0, State: 16, Terminated: False, Truncated: False
# delta (4) - State: 16, Action: 1, Delta: 0.0
# Policy sum for state 16: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 17, Action: 0, Delta: 0.0
# Policy sum for state 17: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 16, Action: 1, Delta: 0.0
# Policy sum for state 16: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 17, Action: 1, Delta: 0.0
# Policy sum for state 17: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 17, Action: 1, Delta: 0.0
# Policy sum for state 17: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 17, Action: 2, Delta: 0.0
# Policy sum for state 17: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 15/20
# Step: 0, State: 2, Terminated: False, Truncated: False
# delta (4) - State: 2, Action: 1, Delta: 0.0
# Policy sum for state 2: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 2, Action: 0, Delta: 0.0
# Policy sum for state 2: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 1, Action: 0, Delta: 0.0
# Policy sum for state 1: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 0, Action: 1, Delta: 0.0
# Policy sum for state 0: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 1, Action: 0, Delta: 0.0
# Policy sum for state 1: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 0, Action: 1, Delta: 0.0
# Policy sum for state 0: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 16/20
# Step: 0, State: 1, Terminated: False, Truncated: False
# delta (4) - State: 1, Action: 0, Delta: 0.0
# Policy sum for state 1: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 0, Action: 2, Delta: 0.0
# Policy sum for state 0: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 4, Action: 3, Delta: 0.0
# Policy sum for state 4: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 0, Action: 1, Delta: 0.0
# Policy sum for state 0: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 1, Action: 2, Delta: 0.0
# Policy sum for state 1: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 5, Action: 0, Delta: 0.0
# Policy sum for state 5: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 17/20
# Step: 0, State: 0, Terminated: False, Truncated: False
# delta (4) - State: 0, Action: 1, Delta: 0.0
# Policy sum for state 0: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 1, Action: 2, Delta: 0.0
# Policy sum for state 1: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 5, Action: 2, Delta: 0.0
# Policy sum for state 5: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 5, Action: 0, Delta: 0.0
# Policy sum for state 5: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 4, Action: 3, Delta: 0.0
# Policy sum for state 4: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 0, Action: 2, Delta: 0.0
# Policy sum for state 0: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 18/20
# Step: 0, State: 11, Terminated: False, Truncated: False
# delta (4) - State: 11, Action: 2, Delta: 0.0
# Policy sum for state 11: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 11, Action: 1, Delta: 0.0
# Policy sum for state 11: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 11, Action: 3, Delta: 0.0
# Policy sum for state 11: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 8, Action: 0, Delta: 0.0
# Policy sum for state 8: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 7, Action: 3, Delta: 0.0
# Policy sum for state 7: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 7, Action: 0, Delta: 0.0
# Policy sum for state 7: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 19/20
# Step: 0, State: 17, Terminated: False, Truncated: False
# delta (4) - State: 17, Action: 2, Delta: 0.0
# Policy sum for state 17: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 17, Action: 2, Delta: 0.0
# Policy sum for state 17: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 17, Action: 1, Delta: 0.0
# Policy sum for state 17: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 17, Action: 2, Delta: 0.0
# Policy sum for state 17: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 17, Action: 2, Delta: 0.0
# Policy sum for state 17: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 17, Action: 0, Delta: 0.0
# Policy sum for state 17: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 20/20
# Step: 0, State: 6, Terminated: False, Truncated: False
# delta (4) - State: 6, Action: 2, Delta: 0.0
# Policy sum for state 6: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 6, Action: 2, Delta: 0.0
# Policy sum for state 6: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 6, Action: 0, Delta: 0.0
# Policy sum for state 6: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 5, Action: 0, Delta: 0.0
# Policy sum for state 5: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 4, Action: 1, Delta: 0.0
# Policy sum for state 4: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 5, Action: 0, Delta: 0.0
# Policy sum for state 5: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
# Plot_steps funtion - Run 90 of 100
#  Actor_critic_q function - looping Episode 1/20
# Step: 0, State: 8, Terminated: False, Truncated: False
# delta (4) - State: 8, Action: 3, Delta: 0.0
# Policy sum for state 8: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 3, Action: 1, Delta: 0.0
# Policy sum for state 3: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 3, Action: 3, Delta: 0.0
# Policy sum for state 3: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 3, Action: 3, Delta: 0.0
# Policy sum for state 3: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 3, Action: 0, Delta: 0.0
# Policy sum for state 3: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 3, Action: 2, Delta: 0.0
# Policy sum for state 3: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 2/20
# Step: 0, State: 1, Terminated: False, Truncated: False
# delta (4) - State: 1, Action: 2, Delta: 0.0
# Policy sum for state 1: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 5, Action: 1, Delta: 0.0
# Policy sum for state 5: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 6, Action: 2, Delta: 0.0
# Policy sum for state 6: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 6, Action: 0, Delta: 0.0
# Policy sum for state 6: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 5, Action: 2, Delta: 0.0
# Policy sum for state 5: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 5, Action: 0, Delta: 0.0
# Policy sum for state 5: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 3/20
# Step: 0, State: 7, Terminated: False, Truncated: False
# delta (4) - State: 7, Action: 0, Delta: 0.0
# Policy sum for state 7: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 6, Action: 1, Delta: 0.0
# Policy sum for state 6: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 7, Action: 0, Delta: 0.0
# Policy sum for state 7: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 6, Action: 3, Delta: 0.0
# Policy sum for state 6: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 2, Action: 1, Delta: 0.0
# Policy sum for state 2: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 2, Action: 2, Delta: 0.0
# Policy sum for state 2: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 4/20
# Step: 0, State: 13, Terminated: False, Truncated: False
# delta (4) - State: 13, Action: 3, Delta: 0.0
# Policy sum for state 13: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 13, Action: 0, Delta: 0.0
# Policy sum for state 13: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 12, Action: 1, Delta: 0.0
# Policy sum for state 12: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 13, Action: 3, Delta: 0.0
# Policy sum for state 13: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 13, Action: 3, Delta: 0.0
# Policy sum for state 13: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 13, Action: 1, Delta: 0.0
# Policy sum for state 13: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 5/20
# Step: 0, State: 6, Terminated: False, Truncated: False
# delta (4) - State: 6, Action: 1, Delta: 0.0
# Policy sum for state 6: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 7, Action: 2, Delta: 0.0
# Policy sum for state 7: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 10, Action: 1, Delta: 0.0
# Policy sum for state 10: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 11, Action: 3, Delta: 0.0
# Policy sum for state 11: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 8, Action: 0, Delta: 0.0
# Policy sum for state 8: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 7, Action: 1, Delta: 0.0
# Policy sum for state 7: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 6/20
# Step: 0, State: 3, Terminated: False, Truncated: False
# delta (4) - State: 3, Action: 1, Delta: 0.0
# Policy sum for state 3: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 3, Action: 1, Delta: 0.0
# Policy sum for state 3: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 3, Action: 3, Delta: 0.0
# Policy sum for state 3: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 3, Action: 2, Delta: 0.0
# Policy sum for state 3: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 8, Action: 3, Delta: 0.0
# Policy sum for state 8: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 3, Action: 1, Delta: 0.0
# Policy sum for state 3: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 7/20
# Step: 0, State: 14, Terminated: False, Truncated: False
# delta (4) - State: 14, Action: 0, Delta: 0.0
# Policy sum for state 14: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 13, Action: 3, Delta: 0.0
# Policy sum for state 13: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 13, Action: 1, Delta: 0.0
# Policy sum for state 13: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 14, Action: 3, Delta: 0.0
# Policy sum for state 14: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 14, Action: 0, Delta: 0.0
# Policy sum for state 14: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 13, Action: 0, Delta: 0.0
# Policy sum for state 13: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 8/20
# Step: 0, State: 6, Terminated: False, Truncated: False
# delta (4) - State: 6, Action: 2, Delta: 0.0
# Policy sum for state 6: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 6, Action: 2, Delta: 0.0
# Policy sum for state 6: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 6, Action: 1, Delta: 0.0
# Policy sum for state 6: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 7, Action: 0, Delta: 0.0
# Policy sum for state 7: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 6, Action: 2, Delta: 0.0
# Policy sum for state 6: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 6, Action: 3, Delta: 0.0
# Policy sum for state 6: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 9/20
# Step: 0, State: 3, Terminated: False, Truncated: False
# delta (4) - State: 3, Action: 2, Delta: 0.0
# Policy sum for state 3: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 8, Action: 0, Delta: 0.0
# Policy sum for state 8: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 7, Action: 3, Delta: 0.0
# Policy sum for state 7: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 7, Action: 1, Delta: 0.0
# Policy sum for state 7: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 8, Action: 0, Delta: 0.0
# Policy sum for state 8: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 7, Action: 2, Delta: 0.0
# Policy sum for state 7: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 10/20
# Step: 0, State: 8, Terminated: False, Truncated: False
# delta (4) - State: 8, Action: 3, Delta: 0.0
# Policy sum for state 8: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 3, Action: 0, Delta: 0.0
# Policy sum for state 3: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 3, Action: 2, Delta: 0.0
# Policy sum for state 3: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 8, Action: 3, Delta: 0.0
# Policy sum for state 8: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 3, Action: 3, Delta: 0.0
# Policy sum for state 3: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 3, Action: 2, Delta: 0.0
# Policy sum for state 3: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 11/20
# Step: 0, State: 19, Terminated: False, Truncated: False
# delta (4) - State: 19, Action: 3, Delta: 1.0
# Policy sum for state 19: 1.0
# Norm of Q-values: 0.01
#  Actor_critic_q function - looping Episode 12/20
# Step: 0, State: 8, Terminated: False, Truncated: False
# delta (4) - State: 8, Action: 1, Delta: 0.0
# Policy sum for state 8: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 8, Action: 2, Delta: 0.0
# Policy sum for state 8: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 11, Action: 3, Delta: 0.0
# Policy sum for state 11: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 8, Action: 3, Delta: 0.0
# Policy sum for state 8: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 3, Action: 3, Delta: 0.0
# Policy sum for state 3: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 3, Action: 3, Delta: 0.0
# Policy sum for state 3: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 13/20
# Step: 0, State: 11, Terminated: False, Truncated: False
# delta (4) - State: 11, Action: 1, Delta: 0.0
# Policy sum for state 11: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 11, Action: 2, Delta: 0.0
# Policy sum for state 11: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 11, Action: 3, Delta: 0.0
# Policy sum for state 11: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 8, Action: 2, Delta: 0.0
# Policy sum for state 8: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 11, Action: 0, Delta: 0.0
# Policy sum for state 11: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 10, Action: 3, Delta: 0.0
# Policy sum for state 10: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 14/20
# Step: 0, State: 3, Terminated: False, Truncated: False
# delta (4) - State: 3, Action: 2, Delta: 0.0
# Policy sum for state 3: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 8, Action: 0, Delta: 0.0
# Policy sum for state 8: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 7, Action: 0, Delta: 0.0
# Policy sum for state 7: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 6, Action: 1, Delta: 0.0
# Policy sum for state 6: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 7, Action: 1, Delta: 0.0
# Policy sum for state 7: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 8, Action: 0, Delta: 0.0
# Policy sum for state 8: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 15/20
# Step: 0, State: 6, Terminated: False, Truncated: False
# delta (4) - State: 6, Action: 0, Delta: 0.0
# Policy sum for state 6: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 5, Action: 0, Delta: 0.0
# Policy sum for state 5: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 4, Action: 3, Delta: 0.0
# Policy sum for state 4: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 0, Action: 0, Delta: 0.0
# Policy sum for state 0: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 0, Action: 2, Delta: 0.0
# Policy sum for state 0: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 4, Action: 0, Delta: 0.0
# Policy sum for state 4: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 16/20
# Step: 0, State: 6, Terminated: False, Truncated: False
# delta (4) - State: 6, Action: 2, Delta: 0.0
# Policy sum for state 6: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 6, Action: 2, Delta: 0.0
# Policy sum for state 6: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 6, Action: 3, Delta: 0.0
# Policy sum for state 6: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 2, Action: 2, Delta: 0.0
# Policy sum for state 2: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 6, Action: 2, Delta: 0.0
# Policy sum for state 6: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 6, Action: 0, Delta: 0.0
# Policy sum for state 6: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 17/20
# Step: 0, State: 1, Terminated: False, Truncated: False
# delta (4) - State: 1, Action: 3, Delta: 0.0
# Policy sum for state 1: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 1, Action: 0, Delta: 0.0
# Policy sum for state 1: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 0, Action: 1, Delta: 0.0
# Policy sum for state 0: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 1, Action: 2, Delta: 0.0
# Policy sum for state 1: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 5, Action: 0, Delta: 0.0
# Policy sum for state 5: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 4, Action: 2, Delta: 0.0
# Policy sum for state 4: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 18/20
# Step: 0, State: 3, Terminated: False, Truncated: False
# delta (4) - State: 3, Action: 0, Delta: 0.0
# Policy sum for state 3: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 3, Action: 3, Delta: 0.0
# Policy sum for state 3: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 3, Action: 3, Delta: 0.0
# Policy sum for state 3: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 3, Action: 1, Delta: 0.0
# Policy sum for state 3: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 3, Action: 2, Delta: 0.0
# Policy sum for state 3: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 8, Action: 0, Delta: 0.0
# Policy sum for state 8: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 19/20
# Step: 0, State: 8, Terminated: False, Truncated: False
# delta (4) - State: 8, Action: 2, Delta: 0.0
# Policy sum for state 8: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 11, Action: 2, Delta: 0.0
# Policy sum for state 11: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 11, Action: 2, Delta: 0.0
# Policy sum for state 11: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 11, Action: 1, Delta: 0.0
# Policy sum for state 11: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 11, Action: 3, Delta: 0.0
# Policy sum for state 11: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 8, Action: 1, Delta: 0.0
# Policy sum for state 8: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 20/20
# Step: 0, State: 12, Terminated: False, Truncated: False
# delta (4) - State: 12, Action: 2, Delta: 0.0
# Policy sum for state 12: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 16, Action: 3, Delta: 0.0
# Policy sum for state 16: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 12, Action: 1, Delta: 0.0
# Policy sum for state 12: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 13, Action: 1, Delta: 0.0
# Policy sum for state 13: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 14, Action: 1, Delta: 0.0
# Policy sum for state 14: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 15, Action: 2, Delta: 0.0
# Policy sum for state 15: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
# Plot_steps funtion - Run 91 of 100
#  Actor_critic_q function - looping Episode 1/20
# Step: 0, State: 11, Terminated: False, Truncated: False
# delta (4) - State: 11, Action: 1, Delta: 0.0
# Policy sum for state 11: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 11, Action: 1, Delta: 0.0
# Policy sum for state 11: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 11, Action: 0, Delta: 0.0
# Policy sum for state 11: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 10, Action: 3, Delta: 0.0
# Policy sum for state 10: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 7, Action: 3, Delta: 0.0
# Policy sum for state 7: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 7, Action: 3, Delta: 0.0
# Policy sum for state 7: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 2/20
# Step: 0, State: 5, Terminated: False, Truncated: False
# delta (4) - State: 5, Action: 3, Delta: 0.0
# Policy sum for state 5: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 1, Action: 3, Delta: 0.0
# Policy sum for state 1: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 1, Action: 1, Delta: 0.0
# Policy sum for state 1: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 2, Action: 3, Delta: 0.0
# Policy sum for state 2: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 2, Action: 0, Delta: 0.0
# Policy sum for state 2: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 1, Action: 2, Delta: 0.0
# Policy sum for state 1: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 3/20
# Step: 0, State: 11, Terminated: False, Truncated: False
# delta (4) - State: 11, Action: 2, Delta: 0.0
# Policy sum for state 11: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 11, Action: 2, Delta: 0.0
# Policy sum for state 11: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 11, Action: 3, Delta: 0.0
# Policy sum for state 11: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 8, Action: 0, Delta: 0.0
# Policy sum for state 8: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 7, Action: 0, Delta: 0.0
# Policy sum for state 7: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 6, Action: 1, Delta: 0.0
# Policy sum for state 6: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 4/20
# Step: 0, State: 19, Terminated: False, Truncated: False
# delta (4) - State: 19, Action: 0, Delta: 1.0
# Policy sum for state 19: 1.0
# Norm of Q-values: 0.01
#  Actor_critic_q function - looping Episode 5/20
# Step: 0, State: 3, Terminated: False, Truncated: False
# delta (4) - State: 3, Action: 2, Delta: 0.0
# Policy sum for state 3: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 8, Action: 3, Delta: 0.0
# Policy sum for state 8: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 3, Action: 1, Delta: 0.0
# Policy sum for state 3: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 3, Action: 0, Delta: 0.0
# Policy sum for state 3: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 3, Action: 3, Delta: 0.0
# Policy sum for state 3: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 3, Action: 0, Delta: 0.0
# Policy sum for state 3: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 6/20
# Step: 0, State: 7, Terminated: False, Truncated: False
# delta (4) - State: 7, Action: 1, Delta: 0.0
# Policy sum for state 7: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 8, Action: 2, Delta: 0.0
# Policy sum for state 8: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 11, Action: 3, Delta: 0.0
# Policy sum for state 11: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 8, Action: 1, Delta: 0.0
# Policy sum for state 8: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 8, Action: 1, Delta: 0.0
# Policy sum for state 8: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 8, Action: 0, Delta: 0.0
# Policy sum for state 8: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
# ...
# Policy sum for state 6: 1.0
# Norm of Q-values: 0.022272002156617503
# delta (4) - State: 6, Action: 1, Delta: 0.0
# Policy sum for state 6: 1.0
# Norm of Q-values: 0.022272002156617503
# delta (4) - State: 7, Action: 0, Delta: 0.0
# Policy sum for state 7: 1.0
# Norm of Q-values: 0.022272002156617503
# delta (4) - State: 6, Action: 0, Delta: 0.0
# Policy sum for state 6: 1.0
# Norm of Q-values: 0.022272002156617503
# delta (4) - State: 5, Action: 0, Delta: 0.0
# Policy sum for state 5: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 20/20
# Step: 0, State: 4, Terminated: False, Truncated: False
# delta (4) - State: 4, Action: 1, Delta: 0.0
# Policy sum for state 4: 1.0
# Norm of Q-values: 0.022272002156617503
# delta (4) - State: 5, Action: 0, Delta: 0.0
# Policy sum for state 5: 1.0
# Norm of Q-values: 0.022272002156617503
# delta (4) - State: 4, Action: 0, Delta: 0.0
# Policy sum for state 4: 1.0
# Norm of Q-values: 0.022272002156617503
# delta (4) - State: 4, Action: 2, Delta: 0.0
# Policy sum for state 4: 1.0
# Norm of Q-values: 0.022272002156617503
# delta (4) - State: 9, Action: 3, Delta: 0.0
# Policy sum for state 9: 1.0
# Norm of Q-values: 0.022272002156617503
# delta (4) - State: 4, Action: 1, Delta: 0.0
# Policy sum for state 4: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
# Plot_steps funtion - Run 100 of 100
#  Actor_critic_q function - looping Episode 1/20
# Step: 0, State: 13, Terminated: False, Truncated: False
# delta (4) - State: 13, Action: 1, Delta: 0.0
# Policy sum for state 13: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 14, Action: 2, Delta: 0.0
# Policy sum for state 14: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 14, Action: 3, Delta: 0.0
# Policy sum for state 14: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 14, Action: 2, Delta: 0.0
# Policy sum for state 14: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 14, Action: 3, Delta: 0.0
# Policy sum for state 14: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 14, Action: 0, Delta: 0.0
# Policy sum for state 14: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 2/20
# Step: 0, State: 10, Terminated: False, Truncated: False
# delta (4) - State: 10, Action: 0, Delta: 0.0
# Policy sum for state 10: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 10, Action: 1, Delta: 0.0
# Policy sum for state 10: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 11, Action: 2, Delta: 0.0
# Policy sum for state 11: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 11, Action: 1, Delta: 0.0
# Policy sum for state 11: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 11, Action: 0, Delta: 0.0
# Policy sum for state 11: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 10, Action: 0, Delta: 0.0
# Policy sum for state 10: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 3/20
# Step: 0, State: 12, Terminated: False, Truncated: False
# delta (4) - State: 12, Action: 2, Delta: 0.0
# Policy sum for state 12: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 16, Action: 1, Delta: 0.0
# Policy sum for state 16: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 17, Action: 0, Delta: 0.0
# Policy sum for state 17: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 16, Action: 1, Delta: 0.0
# Policy sum for state 16: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 17, Action: 2, Delta: 0.0
# Policy sum for state 17: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 17, Action: 3, Delta: 0.0
# Policy sum for state 17: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 4/20
# Step: 0, State: 4, Terminated: False, Truncated: False
# delta (4) - State: 4, Action: 2, Delta: 0.0
# Policy sum for state 4: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 9, Action: 0, Delta: 0.0
# Policy sum for state 9: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 9, Action: 1, Delta: 0.0
# Policy sum for state 9: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 9, Action: 2, Delta: 0.0
# Policy sum for state 9: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 12, Action: 0, Delta: 0.0
# Policy sum for state 12: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 12, Action: 3, Delta: 0.0
# Policy sum for state 12: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 5/20
# Step: 0, State: 18, Terminated: False, Truncated: False
# delta (4) - State: 18, Action: 0, Delta: 0.0
# Policy sum for state 18: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 18, Action: 1, Delta: 0.0
# Policy sum for state 18: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 19, Action: 0, Delta: 1.0
# Policy sum for state 19: 1.0
# Norm of Q-values: 0.01
#  Actor_critic_q function - looping Episode 6/20
# Step: 0, State: 13, Terminated: False, Truncated: False
# delta (4) - State: 13, Action: 1, Delta: 0.0
# Policy sum for state 13: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 14, Action: 2, Delta: 0.0
# Policy sum for state 14: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 14, Action: 0, Delta: 0.0
# Policy sum for state 14: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 13, Action: 2, Delta: 0.0
# Policy sum for state 13: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 17, Action: 1, Delta: 0.0
# Policy sum for state 17: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 17, Action: 0, Delta: 0.0
# Policy sum for state 17: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 7/20
# Step: 0, State: 19, Terminated: False, Truncated: False
# delta (4) - State: 19, Action: 1, Delta: 1.0
# Policy sum for state 19: 1.0
# Norm of Q-values: 0.01414213562373095
#  Actor_critic_q function - looping Episode 8/20
# Step: 0, State: 17, Terminated: False, Truncated: False
# delta (4) - State: 17, Action: 0, Delta: 0.0
# Policy sum for state 17: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 16, Action: 3, Delta: 0.0
# Policy sum for state 16: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 12, Action: 0, Delta: 0.0
# Policy sum for state 12: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 12, Action: 2, Delta: 0.0
# Policy sum for state 12: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 16, Action: 3, Delta: 0.0
# Policy sum for state 16: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 12, Action: 2, Delta: 0.0
# Policy sum for state 12: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 9/20
# Step: 0, State: 0, Terminated: False, Truncated: False
# delta (4) - State: 0, Action: 2, Delta: 0.0
# Policy sum for state 0: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 4, Action: 1, Delta: 0.0
# Policy sum for state 4: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 5, Action: 2, Delta: 0.0
# Policy sum for state 5: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 5, Action: 2, Delta: 0.0
# Policy sum for state 5: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 5, Action: 3, Delta: 0.0
# Policy sum for state 5: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 1, Action: 1, Delta: 0.0
# Policy sum for state 1: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 10/20
# Step: 0, State: 14, Terminated: False, Truncated: False
# delta (4) - State: 14, Action: 0, Delta: 0.0
# Policy sum for state 14: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 13, Action: 1, Delta: 0.0
# Policy sum for state 13: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 14, Action: 1, Delta: 0.0
# Policy sum for state 14: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 15, Action: 3, Delta: 0.0
# Policy sum for state 15: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 10, Action: 0, Delta: 0.0
# Policy sum for state 10: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 10, Action: 1, Delta: 0.0
# Policy sum for state 10: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 11/20
# Step: 0, State: 13, Terminated: False, Truncated: False
# delta (4) - State: 13, Action: 3, Delta: 0.0
# Policy sum for state 13: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 13, Action: 1, Delta: 0.0
# Policy sum for state 13: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 14, Action: 1, Delta: 0.0
# Policy sum for state 14: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 15, Action: 3, Delta: 0.0
# Policy sum for state 15: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 10, Action: 0, Delta: 0.0
# Policy sum for state 10: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 10, Action: 1, Delta: 0.0
# Policy sum for state 10: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 12/20
# Step: 0, State: 2, Terminated: False, Truncated: False
# delta (4) - State: 2, Action: 1, Delta: 0.0
# Policy sum for state 2: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 2, Action: 0, Delta: 0.0
# Policy sum for state 2: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 1, Action: 3, Delta: 0.0
# Policy sum for state 1: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 1, Action: 2, Delta: 0.0
# Policy sum for state 1: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 5, Action: 2, Delta: 0.0
# Policy sum for state 5: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 5, Action: 1, Delta: 0.0
# Policy sum for state 5: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 13/20
# Step: 0, State: 7, Terminated: False, Truncated: False
# delta (4) - State: 7, Action: 1, Delta: 0.0
# Policy sum for state 7: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 8, Action: 3, Delta: 0.0
# Policy sum for state 8: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 3, Action: 0, Delta: 0.0
# Policy sum for state 3: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 3, Action: 3, Delta: 0.0
# Policy sum for state 3: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 3, Action: 2, Delta: 0.0
# Policy sum for state 3: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 8, Action: 3, Delta: 0.0
# Policy sum for state 8: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 14/20
# Step: 0, State: 4, Terminated: False, Truncated: False
# delta (4) - State: 4, Action: 3, Delta: 0.0
# Policy sum for state 4: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 0, Action: 3, Delta: 0.0
# Policy sum for state 0: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 0, Action: 2, Delta: 0.0
# Policy sum for state 0: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 4, Action: 1, Delta: 0.0
# Policy sum for state 4: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 5, Action: 2, Delta: 0.0
# Policy sum for state 5: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 5, Action: 1, Delta: 0.0
# Policy sum for state 5: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 15/20
# Step: 0, State: 15, Terminated: False, Truncated: False
# delta (4) - State: 15, Action: 1, Delta: 0.0
# Policy sum for state 15: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 15, Action: 0, Delta: 0.0
# Policy sum for state 15: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 14, Action: 1, Delta: 0.0
# Policy sum for state 14: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 15, Action: 3, Delta: 0.0
# Policy sum for state 15: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 10, Action: 3, Delta: 0.0
# Policy sum for state 10: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 7, Action: 3, Delta: 0.0
# Policy sum for state 7: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 16/20
# Step: 0, State: 11, Terminated: False, Truncated: False
# delta (4) - State: 11, Action: 1, Delta: 0.0
# Policy sum for state 11: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 11, Action: 1, Delta: 0.0
# Policy sum for state 11: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 11, Action: 3, Delta: 0.0
# Policy sum for state 11: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 8, Action: 3, Delta: 0.0
# Policy sum for state 8: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 3, Action: 2, Delta: 0.0
# Policy sum for state 3: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 8, Action: 0, Delta: 0.0
# Policy sum for state 8: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 17/20
# Step: 0, State: 1, Terminated: False, Truncated: False
# delta (4) - State: 1, Action: 2, Delta: 0.0
# Policy sum for state 1: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 5, Action: 0, Delta: 0.0
# Policy sum for state 5: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 4, Action: 2, Delta: 0.0
# Policy sum for state 4: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 9, Action: 1, Delta: 0.0
# Policy sum for state 9: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 9, Action: 3, Delta: 0.0
# Policy sum for state 9: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 4, Action: 1, Delta: 0.0
# Policy sum for state 4: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 18/20
# Step: 0, State: 16, Terminated: False, Truncated: False
# delta (4) - State: 16, Action: 0, Delta: 0.0
# Policy sum for state 16: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 16, Action: 0, Delta: 0.0
# Policy sum for state 16: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 16, Action: 1, Delta: 0.0
# Policy sum for state 16: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 17, Action: 0, Delta: 0.0
# Policy sum for state 17: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 16, Action: 2, Delta: 0.0
# Policy sum for state 16: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 16, Action: 3, Delta: 0.0
# Policy sum for state 16: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 19/20
# Step: 0, State: 3, Terminated: False, Truncated: False
# delta (4) - State: 3, Action: 3, Delta: 0.0
# Policy sum for state 3: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 3, Action: 2, Delta: 0.0
# Policy sum for state 3: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 8, Action: 1, Delta: 0.0
# Policy sum for state 8: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 8, Action: 1, Delta: 0.0
# Policy sum for state 8: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 8, Action: 2, Delta: 0.0
# Policy sum for state 8: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 11, Action: 2, Delta: 0.0
# Policy sum for state 11: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 20/20
# Step: 0, State: 13, Terminated: False, Truncated: False
# delta (4) - State: 13, Action: 2, Delta: 0.0
# Policy sum for state 13: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 17, Action: 1, Delta: 0.0
# Policy sum for state 17: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 17, Action: 1, Delta: 0.0
# Policy sum for state 17: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 17, Action: 3, Delta: 0.0
# Policy sum for state 17: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 13, Action: 2, Delta: 0.0
# Policy sum for state 13: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 17, Action: 1, Delta: 0.0
# Policy sum for state 17: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#
# Summary Table:
#     Update Rule  Mean Steps  Standard Deviation
# 0        SARSA      5.6470            0.113362
# 1   Q-learning      5.6550            0.115521
# 2   Mean SARSA      5.5985            0.150774
# 3  Fourth Rule      5.6395            0.095785
# nb_episodes: 20
# Temps d'exécution pour 100 runs : 0:00:06.806045

# %%
ac_params = {
    "save_curves": False,
    "save_heatmap": True,
    "mdp": {
        "name": "MazeMDP-v0",
        "width": 5,
        "height": 5,
        "ratio": 0.2,
        "render_mode": "rgb_array",
        },

    "log_dir": "./tmp",
    "video_dir": "./tmp/videos",

    "nb_episodes": 100,
    "render": False, # True, #
    "nb_repeats": 5,

    "alpha_critic": 0.5, # CAS inverse du précédent (à titre d'observation)
    "alpha_actor": 0.8,
    }

cfg=OmegaConf.create(ac_params)
mdp = make_mdp(cfg) # the mdp is made once and for all, this is an ugly global variable

import time
from datetime import timedelta
N = 100

start_time = time.time()  # mesurer temps
plot_steps(nb_runs=N)
end_time = time.time()

elapsed_time = timedelta(seconds=(end_time - start_time))
print(f"Temps d'exécution pour {N} runs : {elapsed_time}")

# print("average v value:", v_vals.mean())
# Out:
# Streaming output truncated to the last 5000 lines.
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 18/20
# Step: 0, State: 3, Terminated: False, Truncated: False
# delta (4) - State: 3, Action: 3, Delta: 0.0
# Policy sum for state 3: 1.0
# Norm of Q-values: 0.014142422068677513
# delta (4) - State: 3, Action: 1, Delta: 0.0
# Policy sum for state 3: 1.0
# Norm of Q-values: 0.014142422068677513
# delta (4) - State: 3, Action: 2, Delta: 0.0
# Policy sum for state 3: 1.0
# Norm of Q-values: 0.014142422068677513
# delta (4) - State: 8, Action: 2, Delta: 0.0
# Policy sum for state 8: 1.0
# Norm of Q-values: 0.014142422068677513
# delta (4) - State: 8, Action: 0, Delta: 0.0
# Policy sum for state 8: 1.0
# Norm of Q-values: 0.014142422068677513
# delta (4) - State: 7, Action: 2, Delta: 6.561000000000002e-09
# Policy sum for state 7: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 19/20
# Step: 0, State: 10, Terminated: False, Truncated: False
# delta (4) - State: 10, Action: 1, Delta: 6.561000000000002e-09
# Policy sum for state 10: 1.0
# Norm of Q-values: 0.014142422068677513
# delta (4) - State: 11, Action: 3, Delta: 5.904900000000002e-11
# Policy sum for state 11: 1.0
# Norm of Q-values: 0.014142422068677513
# delta (4) - State: 7, Action: 3, Delta: 0.0
# Policy sum for state 7: 1.0
# Norm of Q-values: 0.014142422068677513
# delta (4) - State: 2, Action: 3, Delta: 0.0
# Policy sum for state 2: 1.0
# Norm of Q-values: 0.014142422068677513
# delta (4) - State: 2, Action: 2, Delta: 5.904900000000002e-11
# Policy sum for state 2: 1.0
# Norm of Q-values: 0.014142422068677513
# delta (4) - State: 7, Action: 3, Delta: 5.314410000000003e-13
# Policy sum for state 7: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 20/20
# Step: 0, State: 19, Terminated: False, Truncated: False
# delta (4) - State: 19, Action: 2, Delta: 0.99
# Policy sum for state 19: 1.0
# Norm of Q-values: 0.022271463848804747
# Plot_steps funtion - Run 88 of 100
#  Actor_critic_q function - looping Episode 1/20
# Step: 0, State: 5, Terminated: False, Truncated: False
# delta (4) - State: 5, Action: 3, Delta: 0.0
# Policy sum for state 5: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 0, Action: 3, Delta: 0.0
# Policy sum for state 0: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 0, Action: 1, Delta: 0.0
# Policy sum for state 0: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 1, Action: 1, Delta: 0.0
# Policy sum for state 1: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 2, Action: 2, Delta: 0.0
# Policy sum for state 2: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 7, Action: 3, Delta: 0.0
# Policy sum for state 7: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 2/20
# Step: 0, State: 5, Terminated: False, Truncated: False
# delta (4) - State: 5, Action: 0, Delta: 0.0
# Policy sum for state 5: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 4, Action: 2, Delta: 0.0
# Policy sum for state 4: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 4, Action: 0, Delta: 0.0
# Policy sum for state 4: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 4, Action: 3, Delta: 0.0
# Policy sum for state 4: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 4, Action: 1, Delta: 0.0
# Policy sum for state 4: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 5, Action: 0, Delta: 0.0
# Policy sum for state 5: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 3/20
# Step: 0, State: 12, Terminated: False, Truncated: False
# delta (4) - State: 12, Action: 1, Delta: 0.0
# Policy sum for state 12: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 13, Action: 3, Delta: 0.0
# Policy sum for state 13: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 9, Action: 2, Delta: 0.0
# Policy sum for state 9: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 13, Action: 0, Delta: 0.0
# Policy sum for state 13: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 12, Action: 2, Delta: 0.0
# Policy sum for state 12: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 17, Action: 0, Delta: 0.0
# Policy sum for state 17: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 4/20
# Step: 0, State: 14, Terminated: False, Truncated: False
# delta (4) - State: 14, Action: 0, Delta: 0.0
# Policy sum for state 14: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 13, Action: 3, Delta: 0.0
# Policy sum for state 13: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 9, Action: 3, Delta: 0.0
# Policy sum for state 9: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 5, Action: 3, Delta: 0.0
# Policy sum for state 5: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 0, Action: 3, Delta: 0.0
# Policy sum for state 0: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 0, Action: 2, Delta: 0.0
# Policy sum for state 0: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 5/20
# Step: 0, State: 19, Terminated: False, Truncated: False
# delta (4) - State: 19, Action: 1, Delta: 1.0
# Policy sum for state 19: 1.0
# Norm of Q-values: 0.01
#  Actor_critic_q function - looping Episode 6/20
# Step: 0, State: 17, Terminated: False, Truncated: False
# delta (4) - State: 17, Action: 2, Delta: 0.0
# Policy sum for state 17: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 17, Action: 0, Delta: 0.0
# Policy sum for state 17: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 17, Action: 0, Delta: 0.0
# Policy sum for state 17: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 17, Action: 2, Delta: 0.0
# Policy sum for state 17: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 17, Action: 3, Delta: 0.0
# Policy sum for state 17: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 12, Action: 2, Delta: 0.0
# Policy sum for state 12: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 7/20
# Step: 0, State: 4, Terminated: False, Truncated: False
# delta (4) - State: 4, Action: 1, Delta: 0.0
# Policy sum for state 4: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 5, Action: 3, Delta: 0.0
# Policy sum for state 5: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 0, Action: 0, Delta: 0.0
# Policy sum for state 0: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 0, Action: 3, Delta: 0.0
# Policy sum for state 0: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 0, Action: 2, Delta: 0.0
# Policy sum for state 0: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 5, Action: 1, Delta: 0.0
# Policy sum for state 5: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 8/20
# Step: 0, State: 14, Terminated: False, Truncated: False
# delta (4) - State: 14, Action: 2, Delta: 0.009000000000000001
# Policy sum for state 14: 1.0
# Norm of Q-values: 0.010000404991799083
# delta (4) - State: 19, Action: 1, Delta: 0.99
# Policy sum for state 19: 1.0
# Norm of Q-values: 0.01990020351654726
#  Actor_critic_q function - looping Episode 9/20
# Step: 0, State: 19, Terminated: False, Truncated: False
# delta (4) - State: 19, Action: 2, Delta: 1.0
# Policy sum for state 19: 1.0
# Norm of Q-values: 0.0222714638046088
#  Actor_critic_q function - looping Episode 10/20
# Step: 0, State: 3, Terminated: False, Truncated: False
# delta (4) - State: 3, Action: 0, Delta: 0.0
# Policy sum for state 3: 1.0
# Norm of Q-values: 0.0222714638046088
# delta (4) - State: 2, Action: 2, Delta: 0.0
# Policy sum for state 2: 1.0
# Norm of Q-values: 0.0222714638046088
# delta (4) - State: 7, Action: 1, Delta: 0.0
# Policy sum for state 7: 1.0
# Norm of Q-values: 0.0222714638046088
# delta (4) - State: 8, Action: 1, Delta: 0.0
# Policy sum for state 8: 1.0
# Norm of Q-values: 0.0222714638046088
# delta (4) - State: 8, Action: 1, Delta: 0.0
# Policy sum for state 8: 1.0
# Norm of Q-values: 0.0222714638046088
# delta (4) - State: 8, Action: 2, Delta: 0.0
# Policy sum for state 8: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 11/20
# Step: 0, State: 11, Terminated: False, Truncated: False
# delta (4) - State: 11, Action: 0, Delta: 0.0
# Policy sum for state 11: 1.0
# Norm of Q-values: 0.0222714638046088
# delta (4) - State: 10, Action: 3, Delta: 0.0
# Policy sum for state 10: 1.0
# Norm of Q-values: 0.0222714638046088
# delta (4) - State: 6, Action: 2, Delta: 0.0
# Policy sum for state 6: 1.0
# Norm of Q-values: 0.0222714638046088
# delta (4) - State: 10, Action: 0, Delta: 0.0
# Policy sum for state 10: 1.0
# Norm of Q-values: 0.0222714638046088
# delta (4) - State: 9, Action: 3, Delta: 0.0
# Policy sum for state 9: 1.0
# Norm of Q-values: 0.0222714638046088
# delta (4) - State: 5, Action: 3, Delta: 0.0
# Policy sum for state 5: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 12/20
# Step: 0, State: 8, Terminated: False, Truncated: False
# delta (4) - State: 8, Action: 1, Delta: 0.0
# Policy sum for state 8: 1.0
# Norm of Q-values: 0.0222714638046088
# delta (4) - State: 8, Action: 1, Delta: 0.0
# Policy sum for state 8: 1.0
# Norm of Q-values: 0.0222714638046088
# delta (4) - State: 8, Action: 0, Delta: 0.0
# Policy sum for state 8: 1.0
# Norm of Q-values: 0.0222714638046088
# delta (4) - State: 7, Action: 3, Delta: 0.0
# Policy sum for state 7: 1.0
# Norm of Q-values: 0.0222714638046088
# delta (4) - State: 2, Action: 0, Delta: 0.0
# Policy sum for state 2: 1.0
# Norm of Q-values: 0.0222714638046088
# delta (4) - State: 1, Action: 2, Delta: 0.0
# Policy sum for state 1: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 13/20
# Step: 0, State: 15, Terminated: False, Truncated: False
# delta (4) - State: 15, Action: 3, Delta: 0.0
# Policy sum for state 15: 1.0
# Norm of Q-values: 0.0222714638046088
# delta (4) - State: 11, Action: 2, Delta: 0.0
# Policy sum for state 11: 1.0
# Norm of Q-values: 0.0222714638046088
# delta (4) - State: 15, Action: 0, Delta: 8.1e-05
# Policy sum for state 15: 1.0
# Norm of Q-values: 0.02227146381933841
# delta (4) - State: 14, Action: 0, Delta: 0.0
# Policy sum for state 14: 1.0
# Norm of Q-values: 0.02227146381933841
# delta (4) - State: 13, Action: 2, Delta: 0.0
# Policy sum for state 13: 1.0
# Norm of Q-values: 0.02227146381933841
# delta (4) - State: 18, Action: 3, Delta: 0.0
# Policy sum for state 18: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 14/20
# Step: 0, State: 14, Terminated: False, Truncated: False
# delta (4) - State: 14, Action: 3, Delta: 0.0
# Policy sum for state 14: 1.0
# Norm of Q-values: 0.02227146381933841
# delta (4) - State: 10, Action: 1, Delta: 0.0
# Policy sum for state 10: 1.0
# Norm of Q-values: 0.02227146381933841
# delta (4) - State: 11, Action: 1, Delta: 0.0
# Policy sum for state 11: 1.0
# Norm of Q-values: 0.02227146381933841
# delta (4) - State: 11, Action: 3, Delta: 0.0
# Policy sum for state 11: 1.0
# Norm of Q-values: 0.02227146381933841
# delta (4) - State: 7, Action: 1, Delta: 0.0
# Policy sum for state 7: 1.0
# Norm of Q-values: 0.02227146381933841
# delta (4) - State: 8, Action: 3, Delta: 0.0
# Policy sum for state 8: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 15/20
# Step: 0, State: 1, Terminated: False, Truncated: False
# delta (4) - State: 1, Action: 0, Delta: 0.0
# Policy sum for state 1: 1.0
# Norm of Q-values: 0.02227146381933841
# delta (4) - State: 0, Action: 3, Delta: 0.0
# Policy sum for state 0: 1.0
# Norm of Q-values: 0.02227146381933841
# delta (4) - State: 0, Action: 1, Delta: 0.0
# Policy sum for state 0: 1.0
# Norm of Q-values: 0.02227146381933841
# delta (4) - State: 1, Action: 3, Delta: 0.0
# Policy sum for state 1: 1.0
# Norm of Q-values: 0.02227146381933841
# delta (4) - State: 1, Action: 1, Delta: 0.0
# Policy sum for state 1: 1.0
# Norm of Q-values: 0.02227146381933841
# delta (4) - State: 2, Action: 1, Delta: 0.0
# Policy sum for state 2: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 16/20
# Step: 0, State: 12, Terminated: False, Truncated: False
# delta (4) - State: 12, Action: 2, Delta: 0.0
# Policy sum for state 12: 1.0
# Norm of Q-values: 0.02227146381933841
# delta (4) - State: 17, Action: 2, Delta: 0.0
# Policy sum for state 17: 1.0
# Norm of Q-values: 0.02227146381933841
# delta (4) - State: 17, Action: 3, Delta: 0.0
# Policy sum for state 17: 1.0
# Norm of Q-values: 0.02227146381933841
# delta (4) - State: 12, Action: 2, Delta: 0.0
# Policy sum for state 12: 1.0
# Norm of Q-values: 0.02227146381933841
# delta (4) - State: 17, Action: 3, Delta: 0.0
# Policy sum for state 17: 1.0
# Norm of Q-values: 0.02227146381933841
# delta (4) - State: 12, Action: 1, Delta: 0.0
# Policy sum for state 12: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 17/20
# Step: 0, State: 5, Terminated: False, Truncated: False
# delta (4) - State: 5, Action: 0, Delta: 0.0
# Policy sum for state 5: 1.0
# Norm of Q-values: 0.02227146381933841
# delta (4) - State: 4, Action: 3, Delta: 0.0
# Policy sum for state 4: 1.0
# Norm of Q-values: 0.02227146381933841
# delta (4) - State: 4, Action: 1, Delta: 0.0
# Policy sum for state 4: 1.0
# Norm of Q-values: 0.02227146381933841
# delta (4) - State: 5, Action: 1, Delta: 0.0
# Policy sum for state 5: 1.0
# Norm of Q-values: 0.02227146381933841
# delta (4) - State: 6, Action: 0, Delta: 0.0
# Policy sum for state 6: 1.0
# Norm of Q-values: 0.02227146381933841
# delta (4) - State: 5, Action: 2, Delta: 0.0
# Policy sum for state 5: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 18/20
# Step: 0, State: 4, Terminated: False, Truncated: False
# delta (4) - State: 4, Action: 3, Delta: 0.0
# Policy sum for state 4: 1.0
# Norm of Q-values: 0.02227146381933841
# delta (4) - State: 4, Action: 1, Delta: 0.0
# Policy sum for state 4: 1.0
# Norm of Q-values: 0.02227146381933841
# delta (4) - State: 5, Action: 1, Delta: 0.0
# Policy sum for state 5: 1.0
# Norm of Q-values: 0.02227146381933841
# delta (4) - State: 6, Action: 3, Delta: 0.0
# Policy sum for state 6: 1.0
# Norm of Q-values: 0.02227146381933841
# delta (4) - State: 1, Action: 0, Delta: 0.0
# Policy sum for state 1: 1.0
# Norm of Q-values: 0.02227146381933841
# delta (4) - State: 0, Action: 0, Delta: 0.0
# Policy sum for state 0: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 19/20
# Step: 0, State: 6, Terminated: False, Truncated: False
# delta (4) - State: 6, Action: 3, Delta: 0.0
# Policy sum for state 6: 1.0
# Norm of Q-values: 0.02227146381933841
# delta (4) - State: 1, Action: 2, Delta: 0.0
# Policy sum for state 1: 1.0
# Norm of Q-values: 0.02227146381933841
# delta (4) - State: 6, Action: 0, Delta: 0.0
# Policy sum for state 6: 1.0
# Norm of Q-values: 0.02227146381933841
# delta (4) - State: 5, Action: 1, Delta: 0.0
# Policy sum for state 5: 1.0
# Norm of Q-values: 0.02227146381933841
# delta (4) - State: 6, Action: 0, Delta: 0.0
# Policy sum for state 6: 1.0
# Norm of Q-values: 0.02227146381933841
# delta (4) - State: 5, Action: 0, Delta: 0.0
# Policy sum for state 5: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 20/20
# Step: 0, State: 12, Terminated: False, Truncated: False
# delta (4) - State: 12, Action: 0, Delta: 0.0
# Policy sum for state 12: 1.0
# Norm of Q-values: 0.02227146381933841
# delta (4) - State: 12, Action: 0, Delta: 0.0
# Policy sum for state 12: 1.0
# Norm of Q-values: 0.02227146381933841
# delta (4) - State: 12, Action: 2, Delta: 0.0
# Policy sum for state 12: 1.0
# Norm of Q-values: 0.02227146381933841
# delta (4) - State: 17, Action: 3, Delta: 0.0
# Policy sum for state 17: 1.0
# Norm of Q-values: 0.02227146381933841
# delta (4) - State: 12, Action: 1, Delta: 0.0
# Policy sum for state 12: 1.0
# Norm of Q-values: 0.02227146381933841
# delta (4) - State: 13, Action: 2, Delta: 0.0
# Policy sum for state 13: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
# Plot_steps funtion - Run 89 of 100
#  Actor_critic_q function - looping Episode 1/20
# Step: 0, State: 11, Terminated: False, Truncated: False
# delta (4) - State: 11, Action: 1, Delta: 0.0
# Policy sum for state 11: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 11, Action: 2, Delta: 0.0
# Policy sum for state 11: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 15, Action: 2, Delta: 0.0
# Policy sum for state 15: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 15, Action: 2, Delta: 0.0
# Policy sum for state 15: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 15, Action: 1, Delta: 0.0
# Policy sum for state 15: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 16, Action: 3, Delta: 0.0
# Policy sum for state 16: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 2/20
# Step: 0, State: 14, Terminated: False, Truncated: False
# delta (4) - State: 14, Action: 3, Delta: 0.0
# Policy sum for state 14: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 10, Action: 2, Delta: 0.0
# Policy sum for state 10: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 14, Action: 2, Delta: 0.0
# Policy sum for state 14: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 19, Action: 2, Delta: 1.0
# Policy sum for state 19: 1.0
# Norm of Q-values: 0.01
#  Actor_critic_q function - looping Episode 3/20
# Step: 0, State: 12, Terminated: False, Truncated: False
# delta (4) - State: 12, Action: 3, Delta: 0.0
# Policy sum for state 12: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 12, Action: 3, Delta: 0.0
# Policy sum for state 12: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 12, Action: 2, Delta: 0.0
# Policy sum for state 12: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 17, Action: 2, Delta: 0.0
# Policy sum for state 17: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 17, Action: 0, Delta: 0.0
# Policy sum for state 17: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 17, Action: 2, Delta: 0.0
# Policy sum for state 17: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 4/20
# Step: 0, State: 7, Terminated: False, Truncated: False
# delta (4) - State: 7, Action: 1, Delta: 0.0
# Policy sum for state 7: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 8, Action: 3, Delta: 0.0
# Policy sum for state 8: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 3, Action: 2, Delta: 0.0
# Policy sum for state 3: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 8, Action: 1, Delta: 0.0
# Policy sum for state 8: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 8, Action: 0, Delta: 0.0
# Policy sum for state 8: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 7, Action: 0, Delta: 0.0
# Policy sum for state 7: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 5/20
# Step: 0, State: 14, Terminated: False, Truncated: False
# delta (4) - State: 14, Action: 3, Delta: 0.0
# Policy sum for state 14: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 10, Action: 2, Delta: 0.0
# Policy sum for state 10: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 14, Action: 1, Delta: 0.0
# Policy sum for state 14: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 15, Action: 0, Delta: 0.0
# Policy sum for state 15: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 14, Action: 0, Delta: 0.0
# Policy sum for state 14: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 13, Action: 0, Delta: 0.0
# Policy sum for state 13: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 6/20
# Step: 0, State: 18, Terminated: False, Truncated: False
# delta (4) - State: 18, Action: 1, Delta: 0.009000000000000001
# Policy sum for state 18: 1.0000000000000002
# Norm of Q-values: 0.010000404991799083
# delta (4) - State: 19, Action: 2, Delta: 0.99
# Policy sum for state 19: 1.0
# Norm of Q-values: 0.01990020351654726
#  Actor_critic_q function - looping Episode 7/20
# Step: 0, State: 13, Terminated: False, Truncated: False
# delta (4) - State: 13, Action: 2, Delta: 8.1e-05
# Policy sum for state 13: 1.0
# Norm of Q-values: 0.01990020353303202
# delta (4) - State: 18, Action: 2, Delta: 8.1e-05
# Policy sum for state 18: 0.9999999999999999
# Norm of Q-values: 0.019900203549516774
# delta (4) - State: 18, Action: 1, Delta: 0.017820000000000003
# Policy sum for state 18: 1.0
# Norm of Q-values: 0.019901807268491976
# delta (4) - State: 19, Action: 1, Delta: 1.0
# Policy sum for state 19: 0.9999999999999999
# Norm of Q-values: 0.022272896815461612
#  Actor_critic_q function - looping Episode 8/20
# Step: 0, State: 11, Terminated: False, Truncated: False
# delta (4) - State: 11, Action: 2, Delta: 0.0
# Policy sum for state 11: 1.0
# Norm of Q-values: 0.022272896815461612
# delta (4) - State: 15, Action: 3, Delta: 0.0
# Policy sum for state 15: 1.0
# Norm of Q-values: 0.022272896815461612
# delta (4) - State: 11, Action: 1, Delta: 0.0
# Policy sum for state 11: 1.0
# Norm of Q-values: 0.022272896815461612
# delta (4) - State: 11, Action: 2, Delta: 0.0
# Policy sum for state 11: 1.0
# Norm of Q-values: 0.022272896815461612
# delta (4) - State: 15, Action: 0, Delta: 0.0
# Policy sum for state 15: 1.0
# Norm of Q-values: 0.022272896815461612
# delta (4) - State: 14, Action: 1, Delta: 0.0
# Policy sum for state 14: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 9/20
# Step: 0, State: 7, Terminated: False, Truncated: False
# delta (4) - State: 7, Action: 2, Delta: 0.0
# Policy sum for state 7: 1.0
# Norm of Q-values: 0.022272896815461612
# delta (4) - State: 11, Action: 1, Delta: 0.0
# Policy sum for state 11: 1.0
# Norm of Q-values: 0.022272896815461612
# delta (4) - State: 11, Action: 3, Delta: 0.0
# Policy sum for state 11: 1.0
# Norm of Q-values: 0.022272896815461612
# delta (4) - State: 7, Action: 2, Delta: 0.0
# Policy sum for state 7: 1.0
# Norm of Q-values: 0.022272896815461612
# delta (4) - State: 11, Action: 1, Delta: 0.0
# Policy sum for state 11: 1.0
# Norm of Q-values: 0.022272896815461612
# delta (4) - State: 11, Action: 2, Delta: 0.0
# Policy sum for state 11: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 10/20
# Step: 0, State: 1, Terminated: False, Truncated: False
# delta (4) - State: 1, Action: 2, Delta: 0.0
# Policy sum for state 1: 1.0
# Norm of Q-values: 0.022272896815461612
# delta (4) - State: 6, Action: 2, Delta: 0.0
# Policy sum for state 6: 1.0
# Norm of Q-values: 0.022272896815461612
# delta (4) - State: 10, Action: 3, Delta: 0.0
# Policy sum for state 10: 1.0
# Norm of Q-values: 0.022272896815461612
# delta (4) - State: 6, Action: 1, Delta: 0.0
# Policy sum for state 6: 1.0
# Norm of Q-values: 0.022272896815461612
# delta (4) - State: 7, Action: 2, Delta: 0.0
# Policy sum for state 7: 1.0
# Norm of Q-values: 0.022272896815461612
# delta (4) - State: 11, Action: 0, Delta: 0.0
# Policy sum for state 11: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 11/20
# Step: 0, State: 10, Terminated: False, Truncated: False
# delta (4) - State: 10, Action: 3, Delta: 0.0
# Policy sum for state 10: 1.0
# Norm of Q-values: 0.022272896815461612
# delta (4) - State: 6, Action: 1, Delta: 0.0
# Policy sum for state 6: 1.0
# Norm of Q-values: 0.022272896815461612
# delta (4) - State: 7, Action: 2, Delta: 0.0
# Policy sum for state 7: 1.0
# Norm of Q-values: 0.022272896815461612
# delta (4) - State: 11, Action: 3, Delta: 0.0
# Policy sum for state 11: 1.0
# Norm of Q-values: 0.022272896815461612
# delta (4) - State: 7, Action: 3, Delta: 0.0
# Policy sum for state 7: 1.0
# Norm of Q-values: 0.022272896815461612
# delta (4) - State: 2, Action: 2, Delta: 0.0
# Policy sum for state 2: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 12/20
# Step: 0, State: 5, Terminated: False, Truncated: False
# delta (4) - State: 5, Action: 1, Delta: 0.0
# Policy sum for state 5: 1.0
# Norm of Q-values: 0.022272896815461612
# delta (4) - State: 6, Action: 2, Delta: 0.0
# Policy sum for state 6: 1.0
# Norm of Q-values: 0.022272896815461612
# delta (4) - State: 10, Action: 3, Delta: 0.0
# Policy sum for state 10: 1.0
# Norm of Q-values: 0.022272896815461612
# delta (4) - State: 6, Action: 1, Delta: 0.0
# Policy sum for state 6: 1.0
# Norm of Q-values: 0.022272896815461612
# delta (4) - State: 7, Action: 3, Delta: 0.0
# Policy sum for state 7: 1.0
# Norm of Q-values: 0.022272896815461612
# delta (4) - State: 2, Action: 0, Delta: 0.0
# Policy sum for state 2: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 13/20
# Step: 0, State: 8, Terminated: False, Truncated: False
# delta (4) - State: 8, Action: 3, Delta: 0.0
# Policy sum for state 8: 1.0
# Norm of Q-values: 0.022272896815461612
# delta (4) - State: 3, Action: 2, Delta: 0.0
# Policy sum for state 3: 1.0
# Norm of Q-values: 0.022272896815461612
# delta (4) - State: 8, Action: 3, Delta: 0.0
# Policy sum for state 8: 1.0
# Norm of Q-values: 0.022272896815461612
# delta (4) - State: 3, Action: 3, Delta: 0.0
# Policy sum for state 3: 1.0
# Norm of Q-values: 0.022272896815461612
# delta (4) - State: 3, Action: 3, Delta: 0.0
# Policy sum for state 3: 1.0
# Norm of Q-values: 0.022272896815461612
# delta (4) - State: 3, Action: 0, Delta: 0.0
# Policy sum for state 3: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 14/20
# Step: 0, State: 0, Terminated: False, Truncated: False
# delta (4) - State: 0, Action: 3, Delta: 0.0
# Policy sum for state 0: 1.0
# Norm of Q-values: 0.022272896815461612
# delta (4) - State: 0, Action: 2, Delta: 0.0
# Policy sum for state 0: 1.0
# Norm of Q-values: 0.022272896815461612
# delta (4) - State: 5, Action: 2, Delta: 0.0
# Policy sum for state 5: 1.0
# Norm of Q-values: 0.022272896815461612
# delta (4) - State: 9, Action: 3, Delta: 0.0
# Policy sum for state 9: 1.0
# Norm of Q-values: 0.022272896815461612
# delta (4) - State: 5, Action: 2, Delta: 0.0
# Policy sum for state 5: 1.0
# Norm of Q-values: 0.022272896815461612
# delta (4) - State: 9, Action: 3, Delta: 0.0
# Policy sum for state 9: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 15/20
# Step: 0, State: 18, Terminated: False, Truncated: False
# delta (4) - State: 18, Action: 2, Delta: 0.00024057000000000004
# Policy sum for state 18: 0.9999999999999998
# Norm of Q-values: 0.02227289703286994
# delta (4) - State: 18, Action: 2, Delta: 0.0002381643
# Policy sum for state 18: 1.0
# Norm of Q-values: 0.022272897504059697
# delta (4) - State: 18, Action: 0, Delta: 0.0
# Policy sum for state 18: 1.0
# Norm of Q-values: 0.022272897504059697
# delta (4) - State: 17, Action: 1, Delta: 0.00024138000000000002
# Policy sum for state 17: 1.0
# Norm of Q-values: 0.022272897634856115
# delta (4) - State: 18, Action: 1, Delta: 0.017641800000000003
# Policy sum for state 18: 1.0
# Norm of Q-values: 0.022275720481697178
# delta (4) - State: 19, Action: 3, Delta: 1.0
# Policy sum for state 19: 1.0000000000000002
# Norm of Q-values: 0.024417365193212456
#  Actor_critic_q function - looping Episode 16/20
# Step: 0, State: 19, Terminated: False, Truncated: False
# delta (4) - State: 19, Action: 2, Delta: 0.9801
# Policy sum for state 19: 0.9999999999999999
# Norm of Q-values: 0.03289904442348901
#  Actor_critic_q function - looping Episode 17/20
# Step: 0, State: 2, Terminated: False, Truncated: False
# delta (4) - State: 2, Action: 2, Delta: 0.0
# Policy sum for state 2: 1.0
# Norm of Q-values: 0.03289904442348901
# delta (4) - State: 7, Action: 0, Delta: 0.0
# Policy sum for state 7: 1.0
# Norm of Q-values: 0.03289904442348901
# delta (4) - State: 6, Action: 2, Delta: 0.0
# Policy sum for state 6: 1.0
# Norm of Q-values: 0.03289904442348901
# delta (4) - State: 10, Action: 0, Delta: 0.0
# Policy sum for state 10: 1.0
# Norm of Q-values: 0.03289904442348901
# delta (4) - State: 9, Action: 1, Delta: 0.0
# Policy sum for state 9: 1.0
# Norm of Q-values: 0.03289904442348901
# delta (4) - State: 10, Action: 2, Delta: 0.0
# Policy sum for state 10: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 18/20
# Step: 0, State: 14, Terminated: False, Truncated: False
# delta (4) - State: 14, Action: 1, Delta: 0.0
# Policy sum for state 14: 1.0
# Norm of Q-values: 0.03289904442348901
# delta (4) - State: 15, Action: 3, Delta: 0.0
# Policy sum for state 15: 1.0
# Norm of Q-values: 0.03289904442348901
# delta (4) - State: 11, Action: 1, Delta: 0.0
# Policy sum for state 11: 1.0
# Norm of Q-values: 0.03289904442348901
# delta (4) - State: 11, Action: 3, Delta: 0.0
# Policy sum for state 11: 1.0
# Norm of Q-values: 0.03289904442348901
# delta (4) - State: 7, Action: 2, Delta: 0.0
# Policy sum for state 7: 1.0
# Norm of Q-values: 0.03289904442348901
# delta (4) - State: 11, Action: 3, Delta: 0.0
# Policy sum for state 11: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 19/20
# Step: 0, State: 10, Terminated: False, Truncated: False
# delta (4) - State: 10, Action: 2, Delta: 0.0
# Policy sum for state 10: 1.0
# Norm of Q-values: 0.03289904442348901
# delta (4) - State: 14, Action: 3, Delta: 0.0
# Policy sum for state 14: 1.0
# Norm of Q-values: 0.03289904442348901
# delta (4) - State: 10, Action: 3, Delta: 0.0
# Policy sum for state 10: 1.0
# Norm of Q-values: 0.03289904442348901
# delta (4) - State: 6, Action: 2, Delta: 0.0
# Policy sum for state 6: 1.0
# Norm of Q-values: 0.03289904442348901
# delta (4) - State: 10, Action: 0, Delta: 0.0
# Policy sum for state 10: 1.0
# Norm of Q-values: 0.03289904442348901
# delta (4) - State: 9, Action: 0, Delta: 0.0
# Policy sum for state 9: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 20/20
# Step: 0, State: 1, Terminated: False, Truncated: False
# delta (4) - State: 1, Action: 2, Delta: 0.0
# Policy sum for state 1: 1.0
# Norm of Q-values: 0.03289904442348901
# delta (4) - State: 6, Action: 2, Delta: 0.0
# Policy sum for state 6: 1.0
# Norm of Q-values: 0.03289904442348901
# delta (4) - State: 10, Action: 0, Delta: 0.0
# Policy sum for state 10: 1.0
# Norm of Q-values: 0.03289904442348901
# delta (4) - State: 9, Action: 1, Delta: 0.0
# Policy sum for state 9: 1.0
# Norm of Q-values: 0.03289904442348901
# delta (4) - State: 10, Action: 1, Delta: 0.0
# Policy sum for state 10: 1.0
# Norm of Q-values: 0.03289904442348901
# delta (4) - State: 11, Action: 2, Delta: 0.0
# Policy sum for state 11: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
# Plot_steps funtion - Run 90 of 100
#  Actor_critic_q function - looping Episode 1/20
# Step: 0, State: 18, Terminated: False, Truncated: False
# delta (4) - State: 18, Action: 0, Delta: 0.0
# Policy sum for state 18: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 17, Action: 0, Delta: 0.0
# Policy sum for state 17: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 17, Action: 3, Delta: 0.0
# Policy sum for state 17: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 12, Action: 1, Delta: 0.0
# Policy sum for state 12: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 13, Action: 3, Delta: 0.0
# Policy sum for state 13: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 9, Action: 0, Delta: 0.0
# Policy sum for state 9: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 2/20
# Step: 0, State: 4, Terminated: False, Truncated: False
# delta (4) - State: 4, Action: 3, Delta: 0.0
# Policy sum for state 4: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 4, Action: 2, Delta: 0.0
# Policy sum for state 4: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 4, Action: 0, Delta: 0.0
# Policy sum for state 4: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 4, Action: 2, Delta: 0.0
# Policy sum for state 4: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 4, Action: 2, Delta: 0.0
# Policy sum for state 4: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 4, Action: 1, Delta: 0.0
# Policy sum for state 4: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 3/20
# Step: 0, State: 7, Terminated: False, Truncated: False
# delta (4) - State: 7, Action: 2, Delta: 0.0
# Policy sum for state 7: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 11, Action: 2, Delta: 0.0
# Policy sum for state 11: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 15, Action: 3, Delta: 0.0
# Policy sum for state 15: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 11, Action: 1, Delta: 0.0
# Policy sum for state 11: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 11, Action: 3, Delta: 0.0
# Policy sum for state 11: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 7, Action: 1, Delta: 0.0
# Policy sum for state 7: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 4/20
# Step: 0, State: 17, Terminated: False, Truncated: False
# delta (4) - State: 17, Action: 1, Delta: 0.0
# Policy sum for state 17: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 18, Action: 1, Delta: 0.0
# Policy sum for state 18: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 19, Action: 3, Delta: 1.0
# Policy sum for state 19: 1.0
# Norm of Q-values: 0.01
#  Actor_critic_q function - looping Episode 5/20
# Step: 0, State: 11, Terminated: False, Truncated: False
# delta (4) - State: 11, Action: 2, Delta: 0.0
# Policy sum for state 11: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 15, Action: 3, Delta: 0.0
# Policy sum for state 15: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 11, Action: 0, Delta: 0.0
# Policy sum for state 11: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 10, Action: 0, Delta: 0.0
# Policy sum for state 10: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 9, Action: 1, Delta: 0.0
# Policy sum for state 9: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 10, Action: 2, Delta: 0.0
# Policy sum for state 10: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 6/20
# Step: 0, State: 18, Terminated: False, Truncated: False
# delta (4) - State: 18, Action: 2, Delta: 0.0
# Policy sum for state 18: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 18, Action: 2, Delta: 0.0
# Policy sum for state 18: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 18, Action: 3, Delta: 0.0
# Policy sum for state 18: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 13, Action: 1, Delta: 0.0
# Policy sum for state 13: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 14, Action: 0, Delta: 0.0
# Policy sum for state 14: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 13, Action: 2, Delta: 0.0
# Policy sum for state 13: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 7/20
# Step: 0, State: 0, Terminated: False, Truncated: False
# delta (4) - State: 0, Action: 0, Delta: 0.0
# Policy sum for state 0: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 0, Action: 0, Delta: 0.0
# Policy sum for state 0: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 0, Action: 1, Delta: 0.0
# Policy sum for state 0: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 1, Action: 3, Delta: 0.0
# Policy sum for state 1: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 1, Action: 2, Delta: 0.0
# Policy sum for state 1: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 6, Action: 0, Delta: 0.0
# Policy sum for state 6: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 8/20
# Step: 0, State: 3, Terminated: False, Truncated: False
# delta (4) - State: 3, Action: 0, Delta: 0.0
# Policy sum for state 3: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 2, Action: 3, Delta: 0.0
# Policy sum for state 2: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 2, Action: 2, Delta: 0.0
# Policy sum for state 2: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 7, Action: 0, Delta: 0.0
# Policy sum for state 7: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 6, Action: 1, Delta: 0.0
# Policy sum for state 6: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 7, Action: 2, Delta: 0.0
# Policy sum for state 7: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 9/20
# Step: 0, State: 17, Terminated: False, Truncated: False
# delta (4) - State: 17, Action: 1, Delta: 0.0
# Policy sum for state 17: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 18, Action: 3, Delta: 0.0
# Policy sum for state 18: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 13, Action: 3, Delta: 0.0
# Policy sum for state 13: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 9, Action: 2, Delta: 0.0
# Policy sum for state 9: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 13, Action: 1, Delta: 0.0
# Policy sum for state 13: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 14, Action: 2, Delta: 0.009000000000000001
# Policy sum for state 14: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 10/20
# Step: 0, State: 1, Terminated: False, Truncated: False
# delta (4) - State: 1, Action: 0, Delta: 0.0
# Policy sum for state 1: 1.0
# Norm of Q-values: 0.010000404991799083
# delta (4) - State: 0, Action: 3, Delta: 0.0
# Policy sum for state 0: 1.0
# Norm of Q-values: 0.010000404991799083
# delta (4) - State: 0, Action: 3, Delta: 0.0
# Policy sum for state 0: 1.0
# Norm of Q-values: 0.010000404991799083
# delta (4) - State: 0, Action: 3, Delta: 0.0
# Policy sum for state 0: 1.0
# Norm of Q-values: 0.010000404991799083
# delta (4) - State: 0, Action: 1, Delta: 0.0
# Policy sum for state 0: 1.0
# Norm of Q-values: 0.010000404991799083
# delta (4) - State: 1, Action: 1, Delta: 0.0
# Policy sum for state 1: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 11/20
# Step: 0, State: 15, Terminated: False, Truncated: False
# delta (4) - State: 15, Action: 3, Delta: 0.0
# Policy sum for state 15: 1.0
# Norm of Q-values: 0.010000404991799083
# delta (4) - State: 11, Action: 1, Delta: 0.0
# Policy sum for state 11: 1.0
# Norm of Q-values: 0.010000404991799083
# delta (4) - State: 11, Action: 1, Delta: 0.0
# Policy sum for state 11: 1.0
# Norm of Q-values: 0.010000404991799083
# delta (4) - State: 11, Action: 3, Delta: 0.0
# Policy sum for state 11: 1.0
# Norm of Q-values: 0.010000404991799083
# delta (4) - State: 7, Action: 3, Delta: 0.0
# Policy sum for state 7: 1.0
# Norm of Q-values: 0.010000404991799083
# delta (4) - State: 2, Action: 0, Delta: 0.0
# Policy sum for state 2: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 12/20
# Step: 0, State: 18, Terminated: False, Truncated: False
# delta (4) - State: 18, Action: 0, Delta: 0.0
# Policy sum for state 18: 1.0
# Norm of Q-values: 0.010000404991799083
# delta (4) - State: 17, Action: 2, Delta: 0.0
# Policy sum for state 17: 1.0
# Norm of Q-values: 0.010000404991799083
# delta (4) - State: 17, Action: 0, Delta: 0.0
# Policy sum for state 17: 1.0
# Norm of Q-values: 0.010000404991799083
# delta (4) - State: 17, Action: 0, Delta: 0.0
# Policy sum for state 17: 1.0
# Norm of Q-values: 0.010000404991799083
# delta (4) - State: 17, Action: 3, Delta: 0.0
# Policy sum for state 17: 1.0
# Norm of Q-values: 0.010000404991799083
# delta (4) - State: 12, Action: 2, Delta: 0.0
# Policy sum for state 12: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 13/20
# Step: 0, State: 12, Terminated: False, Truncated: False
# delta (4) - State: 12, Action: 0, Delta: 0.0
# Policy sum for state 12: 1.0
# Norm of Q-values: 0.010000404991799083
# delta (4) - State: 12, Action: 3, Delta: 0.0
# Policy sum for state 12: 1.0
# Norm of Q-values: 0.010000404991799083
# delta (4) - State: 12, Action: 3, Delta: 0.0
# Policy sum for state 12: 1.0
# Norm of Q-values: 0.010000404991799083
# delta (4) - State: 12, Action: 3, Delta: 0.0
# Policy sum for state 12: 1.0
# Norm of Q-values: 0.010000404991799083
# delta (4) - State: 12, Action: 0, Delta: 0.0
# Policy sum for state 12: 1.0
# Norm of Q-values: 0.010000404991799083
# delta (4) - State: 12, Action: 2, Delta: 0.0
# Policy sum for state 12: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 14/20
# Step: 0, State: 19, Terminated: False, Truncated: False
# delta (4) - State: 19, Action: 2, Delta: 1.0
# Policy sum for state 19: 1.0
# Norm of Q-values: 0.01414242199907781
#  Actor_critic_q function - looping Episode 15/20
# Step: 0, State: 2, Terminated: False, Truncated: False
# delta (4) - State: 2, Action: 0, Delta: 0.0
# Policy sum for state 2: 1.0
# Norm of Q-values: 0.01414242199907781
# delta (4) - State: 1, Action: 2, Delta: 0.0
# Policy sum for state 1: 1.0
# Norm of Q-values: 0.01414242199907781
# delta (4) - State: 6, Action: 1, Delta: 0.0
# Policy sum for state 6: 1.0
# Norm of Q-values: 0.01414242199907781
# delta (4) - State: 7, Action: 1, Delta: 0.0
# Policy sum for state 7: 1.0
# Norm of Q-values: 0.01414242199907781
# delta (4) - State: 8, Action: 3, Delta: 0.0
# Policy sum for state 8: 1.0
# Norm of Q-values: 0.01414242199907781
# delta (4) - State: 3, Action: 1, Delta: 0.0
# Policy sum for state 3: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 16/20
# Step: 0, State: 8, Terminated: False, Truncated: False
# delta (4) - State: 8, Action: 0, Delta: 0.0
# Policy sum for state 8: 1.0
# Norm of Q-values: 0.01414242199907781
# delta (4) - State: 7, Action: 1, Delta: 0.0
# Policy sum for state 7: 1.0
# Norm of Q-values: 0.01414242199907781
# delta (4) - State: 8, Action: 0, Delta: 0.0
# Policy sum for state 8: 1.0
# Norm of Q-values: 0.01414242199907781
# delta (4) - State: 7, Action: 2, Delta: 0.0
# Policy sum for state 7: 1.0
# Norm of Q-values: 0.01414242199907781
# delta (4) - State: 11, Action: 0, Delta: 0.0
# Policy sum for state 11: 1.0
# Norm of Q-values: 0.01414242199907781
# delta (4) - State: 10, Action: 1, Delta: 0.0
# Policy sum for state 10: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 17/20
# Step: 0, State: 12, Terminated: False, Truncated: False
# delta (4) - State: 12, Action: 0, Delta: 0.0
# Policy sum for state 12: 1.0
# Norm of Q-values: 0.01414242199907781
# delta (4) - State: 12, Action: 3, Delta: 0.0
# Policy sum for state 12: 1.0
# Norm of Q-values: 0.01414242199907781
# delta (4) - State: 12, Action: 1, Delta: 0.0
# Policy sum for state 12: 1.0
# Norm of Q-values: 0.01414242199907781
# delta (4) - State: 13, Action: 3, Delta: 0.0
# Policy sum for state 13: 1.0
# Norm of Q-values: 0.01414242199907781
# delta (4) - State: 9, Action: 0, Delta: 0.0
# Policy sum for state 9: 1.0
# Norm of Q-values: 0.01414242199907781
# delta (4) - State: 9, Action: 2, Delta: 0.0
# Policy sum for state 9: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 18/20
# Step: 0, State: 4, Terminated: False, Truncated: False
# delta (4) - State: 4, Action: 1, Delta: 0.0
# Policy sum for state 4: 1.0
# Norm of Q-values: 0.01414242199907781
# delta (4) - State: 5, Action: 0, Delta: 0.0
# Policy sum for state 5: 1.0
# Norm of Q-values: 0.01414242199907781
# delta (4) - State: 4, Action: 2, Delta: 0.0
# Policy sum for state 4: 1.0
# Norm of Q-values: 0.01414242199907781
# delta (4) - State: 4, Action: 1, Delta: 0.0
# Policy sum for state 4: 1.0
# Norm of Q-values: 0.01414242199907781
# delta (4) - State: 5, Action: 3, Delta: 0.0
# Policy sum for state 5: 1.0
# Norm of Q-values: 0.01414242199907781
# delta (4) - State: 0, Action: 0, Delta: 0.0
# Policy sum for state 0: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 19/20
# Step: 0, State: 11, Terminated: False, Truncated: False
# delta (4) - State: 11, Action: 2, Delta: 0.0
# Policy sum for state 11: 1.0
# Norm of Q-values: 0.01414242199907781
# delta (4) - State: 15, Action: 0, Delta: 8.1e-05
# Policy sum for state 15: 1.0
# Norm of Q-values: 0.014142422022273978
# delta (4) - State: 14, Action: 3, Delta: 0.0
# Policy sum for state 14: 1.0
# Norm of Q-values: 0.014142422022273978
# delta (4) - State: 10, Action: 3, Delta: 0.0
# Policy sum for state 10: 1.0
# Norm of Q-values: 0.014142422022273978
# delta (4) - State: 6, Action: 0, Delta: 0.0
# Policy sum for state 6: 1.0
# Norm of Q-values: 0.014142422022273978
# delta (4) - State: 5, Action: 1, Delta: 0.0
# Policy sum for state 5: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 20/20
# Step: 0, State: 0, Terminated: False, Truncated: False
# delta (4) - State: 0, Action: 1, Delta: 0.0
# Policy sum for state 0: 1.0
# Norm of Q-values: 0.014142422022273978
# delta (4) - State: 1, Action: 3, Delta: 0.0
# Policy sum for state 1: 1.0
# Norm of Q-values: 0.014142422022273978
# delta (4) - State: 1, Action: 2, Delta: 0.0
# Policy sum for state 1: 1.0
# Norm of Q-values: 0.014142422022273978
# delta (4) - State: 6, Action: 0, Delta: 0.0
# Policy sum for state 6: 1.0
# Norm of Q-values: 0.014142422022273978
# delta (4) - State: 5, Action: 3, Delta: 0.0
# Policy sum for state 5: 1.0
# Norm of Q-values: 0.014142422022273978
# delta (4) - State: 0, Action: 0, Delta: 0.0
# Policy sum for state 0: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
# Plot_steps funtion - Run 91 of 100
#  Actor_critic_q function - looping Episode 1/20
# Step: 0, State: 0, Terminated: False, Truncated: False
# delta (4) - State: 0, Action: 0, Delta: 0.0
# Policy sum for state 0: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 0, Action: 1, Delta: 0.0
# Policy sum for state 0: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 1, Action: 1, Delta: 0.0
# Policy sum for state 1: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 2, Action: 2, Delta: 0.0
# Policy sum for state 2: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 7, Action: 2, Delta: 0.0
# Policy sum for state 7: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 11, Action: 3, Delta: 0.0
# Policy sum for state 11: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 2/20
# Step: 0, State: 18, Terminated: False, Truncated: False
# delta (4) - State: 18, Action: 0, Delta: 0.0
# Policy sum for state 18: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 17, Action: 3, Delta: 0.0
# Policy sum for state 17: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 12, Action: 2, Delta: 0.0
# Policy sum for state 12: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 17, Action: 1, Delta: 0.0
# Policy sum for state 17: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 18, Action: 1, Delta: 0.0
# Policy sum for state 18: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 19, Action: 1, Delta: 1.0
# Policy sum for state 19: 1.0
# Norm of Q-values: 0.01
#  Actor_critic_q function - looping Episode 3/20
# Step: 0, State: 12, Terminated: False, Truncated: False
# delta (4) - State: 12, Action: 2, Delta: 0.0
# Policy sum for state 12: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 17, Action: 2, Delta: 0.0
# Policy sum for state 17: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 17, Action: 3, Delta: 0.0
# Policy sum for state 17: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 12, Action: 1, Delta: 0.0
# Policy sum for state 12: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 13, Action: 3, Delta: 0.0
# Policy sum for state 13: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 9, Action: 3, Delta: 0.0
# Policy sum for state 9: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 4/20
# Step: 0, State: 19, Terminated: False, Truncated: False
# delta (4) - State: 19, Action: 2, Delta: 1.0
# Policy sum for state 19: 0.9999999999999999
# Norm of Q-values: 0.01414213562373095
#  Actor_critic_q function - looping Episode 5/20
# Step: 0, State: 11, Terminated: False, Truncated: False
# delta (4) - State: 11, Action: 2, Delta: 0.0
# Policy sum for state 11: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 15, Action: 0, Delta: 0.0
# Policy sum for state 15: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 14, Action: 0, Delta: 0.0
# Policy sum for state 14: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 13, Action: 1, Delta: 0.0
# Policy sum for state 13: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 14, Action: 3, Delta: 0.0
# Policy sum for state 14: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 10, Action: 0, Delta: 0.0
# Policy sum for state 10: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 6/20
# Step: 0, State: 9, Terminated: False, Truncated: False
# delta (4) - State: 9, Action: 0, Delta: 0.0
# Policy sum for state 9: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 9, Action: 0, Delta: 0.0
# Policy sum for state 9: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 9, Action: 1, Delta: 0.0
# Policy sum for state 9: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 10, Action: 0, Delta: 0.0
# Policy sum for state 10: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 9, Action: 0, Delta: 0.0
# Policy sum for state 9: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 9, Action: 3, Delta: 0.0
# Policy sum for state 9: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 7/20
# Step: 0, State: 9, Terminated: False, Truncated: False
# delta (4) - State: 9, Action: 2, Delta: 0.0
# Policy sum for state 9: 1.0
# Norm of Q-values: 0.01414213562373095
# ...
# delta (4) - State: 2, Action: 2, Delta: 0.0
# Policy sum for state 2: 1.0
# Norm of Q-values: 0.022271281956816047
# delta (4) - State: 7, Action: 0, Delta: 0.0
# Policy sum for state 7: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 20/20
# Step: 0, State: 17, Terminated: False, Truncated: False
# delta (4) - State: 17, Action: 0, Delta: 0.0
# Policy sum for state 17: 1.0
# Norm of Q-values: 0.022271281956816047
# delta (4) - State: 17, Action: 2, Delta: 0.0
# Policy sum for state 17: 1.0
# Norm of Q-values: 0.022271281956816047
# delta (4) - State: 17, Action: 2, Delta: 0.0
# Policy sum for state 17: 1.0
# Norm of Q-values: 0.022271281956816047
# delta (4) - State: 17, Action: 0, Delta: 0.0
# Policy sum for state 17: 1.0
# Norm of Q-values: 0.022271281956816047
# delta (4) - State: 17, Action: 1, Delta: 0.0
# Policy sum for state 17: 1.0
# Norm of Q-values: 0.022271281956816047
# delta (4) - State: 18, Action: 2, Delta: 0.0
# Policy sum for state 18: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
# Plot_steps funtion - Run 100 of 100
#  Actor_critic_q function - looping Episode 1/20
# Step: 0, State: 11, Terminated: False, Truncated: False
# delta (4) - State: 11, Action: 0, Delta: 0.0
# Policy sum for state 11: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 10, Action: 0, Delta: 0.0
# Policy sum for state 10: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 9, Action: 3, Delta: 0.0
# Policy sum for state 9: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 5, Action: 3, Delta: 0.0
# Policy sum for state 5: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 0, Action: 1, Delta: 0.0
# Policy sum for state 0: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 1, Action: 0, Delta: 0.0
# Policy sum for state 1: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 2/20
# Step: 0, State: 9, Terminated: False, Truncated: False
# delta (4) - State: 9, Action: 0, Delta: 0.0
# Policy sum for state 9: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 9, Action: 3, Delta: 0.0
# Policy sum for state 9: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 5, Action: 3, Delta: 0.0
# Policy sum for state 5: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 0, Action: 3, Delta: 0.0
# Policy sum for state 0: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 0, Action: 2, Delta: 0.0
# Policy sum for state 0: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 5, Action: 0, Delta: 0.0
# Policy sum for state 5: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 3/20
# Step: 0, State: 10, Terminated: False, Truncated: False
# delta (4) - State: 10, Action: 0, Delta: 0.0
# Policy sum for state 10: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 9, Action: 1, Delta: 0.0
# Policy sum for state 9: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 10, Action: 3, Delta: 0.0
# Policy sum for state 10: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 6, Action: 1, Delta: 0.0
# Policy sum for state 6: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 7, Action: 2, Delta: 0.0
# Policy sum for state 7: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 11, Action: 2, Delta: 0.0
# Policy sum for state 11: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 4/20
# Step: 0, State: 16, Terminated: False, Truncated: False
# delta (4) - State: 16, Action: 0, Delta: 0.0
# Policy sum for state 16: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 15, Action: 2, Delta: 0.0
# Policy sum for state 15: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 15, Action: 2, Delta: 0.0
# Policy sum for state 15: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 15, Action: 3, Delta: 0.0
# Policy sum for state 15: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 11, Action: 3, Delta: 0.0
# Policy sum for state 11: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 7, Action: 0, Delta: 0.0
# Policy sum for state 7: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 5/20
# Step: 0, State: 0, Terminated: False, Truncated: False
# delta (4) - State: 0, Action: 2, Delta: 0.0
# Policy sum for state 0: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 5, Action: 0, Delta: 0.0
# Policy sum for state 5: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 4, Action: 0, Delta: 0.0
# Policy sum for state 4: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 4, Action: 1, Delta: 0.0
# Policy sum for state 4: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 5, Action: 3, Delta: 0.0
# Policy sum for state 5: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 0, Action: 3, Delta: 0.0
# Policy sum for state 0: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 6/20
# Step: 0, State: 10, Terminated: False, Truncated: False
# delta (4) - State: 10, Action: 1, Delta: 0.0
# Policy sum for state 10: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 11, Action: 2, Delta: 0.0
# Policy sum for state 11: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 15, Action: 3, Delta: 0.0
# Policy sum for state 15: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 11, Action: 3, Delta: 0.0
# Policy sum for state 11: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 7, Action: 1, Delta: 0.0
# Policy sum for state 7: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 8, Action: 2, Delta: 0.0
# Policy sum for state 8: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 7/20
# Step: 0, State: 13, Terminated: False, Truncated: False
# delta (4) - State: 13, Action: 1, Delta: 0.0
# Policy sum for state 13: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 14, Action: 0, Delta: 0.0
# Policy sum for state 14: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 13, Action: 3, Delta: 0.0
# Policy sum for state 13: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 9, Action: 3, Delta: 0.0
# Policy sum for state 9: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 5, Action: 2, Delta: 0.0
# Policy sum for state 5: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 9, Action: 2, Delta: 0.0
# Policy sum for state 9: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 8/20
# Step: 0, State: 15, Terminated: False, Truncated: False
# delta (4) - State: 15, Action: 3, Delta: 0.0
# Policy sum for state 15: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 11, Action: 2, Delta: 0.0
# Policy sum for state 11: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 15, Action: 0, Delta: 0.0
# Policy sum for state 15: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 14, Action: 2, Delta: 0.0
# Policy sum for state 14: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 19, Action: 3, Delta: 1.0
# Policy sum for state 19: 1.0
# Norm of Q-values: 0.01
#  Actor_critic_q function - looping Episode 9/20
# Step: 0, State: 5, Terminated: False, Truncated: False
# delta (4) - State: 5, Action: 1, Delta: 0.0
# Policy sum for state 5: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 6, Action: 3, Delta: 0.0
# Policy sum for state 6: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 1, Action: 0, Delta: 0.0
# Policy sum for state 1: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 0, Action: 1, Delta: 0.0
# Policy sum for state 0: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 1, Action: 2, Delta: 0.0
# Policy sum for state 1: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 6, Action: 3, Delta: 0.0
# Policy sum for state 6: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 10/20
# Step: 0, State: 14, Terminated: False, Truncated: False
# delta (4) - State: 14, Action: 2, Delta: 0.009000000000000001
# Policy sum for state 14: 1.0
# Norm of Q-values: 0.010000404991799083
# delta (4) - State: 19, Action: 2, Delta: 1.0
# Policy sum for state 19: 1.0
# Norm of Q-values: 0.01414242199907781
#  Actor_critic_q function - looping Episode 11/20
# Step: 0, State: 13, Terminated: False, Truncated: False
# delta (4) - State: 13, Action: 0, Delta: 0.0
# Policy sum for state 13: 1.0
# Norm of Q-values: 0.01414242199907781
# delta (4) - State: 12, Action: 3, Delta: 0.0
# Policy sum for state 12: 1.0
# Norm of Q-values: 0.01414242199907781
# delta (4) - State: 12, Action: 0, Delta: 0.0
# Policy sum for state 12: 1.0
# Norm of Q-values: 0.01414242199907781
# delta (4) - State: 12, Action: 0, Delta: 0.0
# Policy sum for state 12: 1.0
# Norm of Q-values: 0.01414242199907781
# delta (4) - State: 12, Action: 3, Delta: 0.0
# Policy sum for state 12: 1.0
# Norm of Q-values: 0.01414242199907781
# delta (4) - State: 12, Action: 1, Delta: 0.0
# Policy sum for state 12: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 12/20
# Step: 0, State: 6, Terminated: False, Truncated: False
# delta (4) - State: 6, Action: 2, Delta: 0.0
# Policy sum for state 6: 1.0
# Norm of Q-values: 0.01414242199907781
# delta (4) - State: 10, Action: 0, Delta: 0.0
# Policy sum for state 10: 1.0
# Norm of Q-values: 0.01414242199907781
# delta (4) - State: 9, Action: 0, Delta: 0.0
# Policy sum for state 9: 1.0
# Norm of Q-values: 0.01414242199907781
# delta (4) - State: 9, Action: 0, Delta: 0.0
# Policy sum for state 9: 1.0
# Norm of Q-values: 0.01414242199907781
# delta (4) - State: 9, Action: 2, Delta: 0.0
# Policy sum for state 9: 1.0
# Norm of Q-values: 0.01414242199907781
# delta (4) - State: 13, Action: 3, Delta: 0.0
# Policy sum for state 13: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 13/20
# Step: 0, State: 13, Terminated: False, Truncated: False
# delta (4) - State: 13, Action: 1, Delta: 8.1e-05
# Policy sum for state 13: 1.0
# Norm of Q-values: 0.014142422022273978
# delta (4) - State: 14, Action: 1, Delta: 0.0
# Policy sum for state 14: 1.0
# Norm of Q-values: 0.014142422022273978
# delta (4) - State: 15, Action: 3, Delta: 0.0
# Policy sum for state 15: 1.0
# Norm of Q-values: 0.014142422022273978
# delta (4) - State: 11, Action: 0, Delta: 0.0
# Policy sum for state 11: 1.0
# Norm of Q-values: 0.014142422022273978
# delta (4) - State: 10, Action: 0, Delta: 0.0
# Policy sum for state 10: 1.0
# Norm of Q-values: 0.014142422022273978
# delta (4) - State: 9, Action: 0, Delta: 0.0
# Policy sum for state 9: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 14/20
# Step: 0, State: 11, Terminated: False, Truncated: False
# delta (4) - State: 11, Action: 3, Delta: 0.0
# Policy sum for state 11: 1.0
# Norm of Q-values: 0.014142422022273978
# delta (4) - State: 7, Action: 3, Delta: 0.0
# Policy sum for state 7: 1.0
# Norm of Q-values: 0.014142422022273978
# delta (4) - State: 2, Action: 0, Delta: 0.0
# Policy sum for state 2: 1.0
# Norm of Q-values: 0.014142422022273978
# delta (4) - State: 1, Action: 2, Delta: 0.0
# Policy sum for state 1: 1.0
# Norm of Q-values: 0.014142422022273978
# delta (4) - State: 6, Action: 0, Delta: 0.0
# Policy sum for state 6: 1.0
# Norm of Q-values: 0.014142422022273978
# delta (4) - State: 5, Action: 2, Delta: 0.0
# Policy sum for state 5: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 15/20
# Step: 0, State: 10, Terminated: False, Truncated: False
# delta (4) - State: 10, Action: 1, Delta: 0.0
# Policy sum for state 10: 1.0
# Norm of Q-values: 0.014142422022273978
# delta (4) - State: 11, Action: 1, Delta: 0.0
# Policy sum for state 11: 1.0
# Norm of Q-values: 0.014142422022273978
# delta (4) - State: 11, Action: 0, Delta: 0.0
# Policy sum for state 11: 1.0
# Norm of Q-values: 0.014142422022273978
# delta (4) - State: 10, Action: 0, Delta: 0.0
# Policy sum for state 10: 1.0
# Norm of Q-values: 0.014142422022273978
# delta (4) - State: 9, Action: 0, Delta: 0.0
# Policy sum for state 9: 1.0
# Norm of Q-values: 0.014142422022273978
# delta (4) - State: 9, Action: 0, Delta: 0.0
# Policy sum for state 9: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 16/20
# Step: 0, State: 17, Terminated: False, Truncated: False
# delta (4) - State: 17, Action: 1, Delta: 0.0
# Policy sum for state 17: 1.0
# Norm of Q-values: 0.014142422022273978
# delta (4) - State: 18, Action: 0, Delta: 0.0
# Policy sum for state 18: 1.0
# Norm of Q-values: 0.014142422022273978
# delta (4) - State: 17, Action: 3, Delta: 0.0
# Policy sum for state 17: 1.0
# Norm of Q-values: 0.014142422022273978
# delta (4) - State: 12, Action: 1, Delta: 7.290000000000001e-07
# Policy sum for state 12: 1.0
# Norm of Q-values: 0.014142422022275856
# delta (4) - State: 13, Action: 1, Delta: 8.019e-05
# Policy sum for state 13: 1.0000000000000002
# Norm of Q-values: 0.014142422090938835
# delta (4) - State: 14, Action: 0, Delta: 1.4507100000000002e-06
# Policy sum for state 14: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 17/20
# Step: 0, State: 10, Terminated: False, Truncated: False
# delta (4) - State: 10, Action: 3, Delta: 0.0
# Policy sum for state 10: 1.0
# Norm of Q-values: 0.014142422090946275
# delta (4) - State: 6, Action: 2, Delta: 0.0
# Policy sum for state 6: 1.0
# Norm of Q-values: 0.014142422090946275
# delta (4) - State: 10, Action: 3, Delta: 0.0
# Policy sum for state 10: 1.0
# Norm of Q-values: 0.014142422090946275
# delta (4) - State: 6, Action: 0, Delta: 0.0
# Policy sum for state 6: 1.0
# Norm of Q-values: 0.014142422090946275
# delta (4) - State: 5, Action: 1, Delta: 0.0
# Policy sum for state 5: 1.0
# Norm of Q-values: 0.014142422090946275
# delta (4) - State: 6, Action: 1, Delta: 0.0
# Policy sum for state 6: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 18/20
# Step: 0, State: 11, Terminated: False, Truncated: False
# delta (4) - State: 11, Action: 0, Delta: 0.0
# Policy sum for state 11: 1.0
# Norm of Q-values: 0.014142422090946275
# delta (4) - State: 10, Action: 3, Delta: 0.0
# Policy sum for state 10: 1.0
# Norm of Q-values: 0.014142422090946275
# delta (4) - State: 6, Action: 2, Delta: 0.0
# Policy sum for state 6: 1.0
# Norm of Q-values: 0.014142422090946275
# delta (4) - State: 10, Action: 3, Delta: 0.0
# Policy sum for state 10: 1.0
# Norm of Q-values: 0.014142422090946275
# delta (4) - State: 6, Action: 0, Delta: 0.0
# Policy sum for state 6: 1.0
# Norm of Q-values: 0.014142422090946275
# delta (4) - State: 5, Action: 1, Delta: 0.0
# Policy sum for state 5: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 19/20
# Step: 0, State: 15, Terminated: False, Truncated: False
# delta (4) - State: 15, Action: 0, Delta: 8.1e-05
# Policy sum for state 15: 1.0
# Norm of Q-values: 0.014142422114142444
# delta (4) - State: 14, Action: 3, Delta: 0.0
# Policy sum for state 14: 1.0
# Norm of Q-values: 0.014142422114142444
# delta (4) - State: 10, Action: 1, Delta: 0.0
# Policy sum for state 10: 1.0
# Norm of Q-values: 0.014142422114142444
# delta (4) - State: 11, Action: 1, Delta: 0.0
# Policy sum for state 11: 1.0
# Norm of Q-values: 0.014142422114142444
# delta (4) - State: 11, Action: 1, Delta: 0.0
# Policy sum for state 11: 1.0
# Norm of Q-values: 0.014142422114142444
# delta (4) - State: 11, Action: 0, Delta: 0.0
# Policy sum for state 11: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 20/20
# Step: 0, State: 9, Terminated: False, Truncated: False
# delta (4) - State: 9, Action: 2, Delta: 1.4507100000000002e-06
# Policy sum for state 9: 1.0
# Norm of Q-values: 0.014142422114149884
# delta (4) - State: 13, Action: 0, Delta: 6.561000000000002e-09
# Policy sum for state 13: 1.0
# Norm of Q-values: 0.014142422114149884
# delta (4) - State: 12, Action: 2, Delta: 0.0
# Policy sum for state 12: 1.0
# Norm of Q-values: 0.014142422114149884
# delta (4) - State: 17, Action: 3, Delta: 6.561000000000002e-09
# Policy sum for state 17: 1.0
# Norm of Q-values: 0.014142422114149884
# delta (4) - State: 12, Action: 1, Delta: 1.4434200000000001e-06
# Policy sum for state 12: 0.9999999999999999
# Norm of Q-values: 0.014142422114164692
# delta (4) - State: 13, Action: 3, Delta: 1.3056390000000003e-08
# Policy sum for state 13: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#
# Summary Table:
#     Update Rule  Mean Steps  Standard Deviation
# 0        SARSA      5.4965            0.102872
# 1   Q-learning      5.5370            0.107940
# 2   Mean SARSA      5.5915            0.131806
# 3  Fourth Rule      5.5345            0.126747
# nb_episodes: 20
# Temps d'exécution pour 100 runs : 0:00:06.258326

# %%
gammas = [0.9, 0.95, 0.99]  # Valeurs de gamma à tester

for gamma in gammas:
    print(f"Test avec gamma = {gamma}")

    ac_params = {
        "save_curves": False,
        "save_heatmap": True,
        "mdp": {
            "name": "MazeMDP-v0",
            "width": 5,
            "height": 5,
            "ratio": 0.2,
            "render_mode": "rgb_array",
            "gamma": gamma,  # Ajouter gamma ici
        },
        "log_dir": "./tmp",
        "video_dir": "./tmp/videos",
        "nb_episodes": 100,
        "render": False,
        "nb_repeats": 5,
        "alpha_critic": 0.8,
        "alpha_actor": 0.5,
    }

    cfg = OmegaConf.create(ac_params)
    mdp = make_mdp(cfg)  # Création de l'environnement avec la nouvelle valeur de gamma

    import time
    from datetime import timedelta
    N = 100

    start_time = time.time()  # mesurer temps
    plot_steps(nb_runs=N)
    end_time = time.time()

    elapsed_time = timedelta(seconds=(end_time - start_time))
    print(f"Temps d'exécution pour {N} runs avec gamma = {gamma} : {elapsed_time}\n")
# Out:
# Streaming output truncated to the last 5000 lines.
# Policy sum for state 10: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 9, Action: 1, Delta: 0.0
# Policy sum for state 9: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 17/20
# Step: 0, State: 1, Terminated: False, Truncated: False
# delta (4) - State: 1, Action: 3, Delta: 0.0
# Policy sum for state 1: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 1, Action: 3, Delta: 0.0
# Policy sum for state 1: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 1, Action: 0, Delta: 0.0
# Policy sum for state 1: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 1, Action: 1, Delta: 0.0
# Policy sum for state 1: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 1, Action: 2, Delta: 0.0
# Policy sum for state 1: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 5, Action: 0, Delta: 0.0
# Policy sum for state 5: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 18/20
# Step: 0, State: 12, Terminated: False, Truncated: False
# delta (4) - State: 12, Action: 2, Delta: 0.0
# Policy sum for state 12: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 16, Action: 3, Delta: 0.0
# Policy sum for state 16: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 12, Action: 0, Delta: 0.0
# Policy sum for state 12: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 12, Action: 0, Delta: 0.0
# Policy sum for state 12: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 12, Action: 3, Delta: 0.0
# Policy sum for state 12: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 12, Action: 3, Delta: 0.0
# Policy sum for state 12: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 19/20
# Step: 0, State: 4, Terminated: False, Truncated: False
# delta (4) - State: 4, Action: 2, Delta: 0.0
# Policy sum for state 4: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 8, Action: 0, Delta: 0.0
# Policy sum for state 8: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 8, Action: 3, Delta: 0.0
# Policy sum for state 8: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 4, Action: 3, Delta: 0.0
# Policy sum for state 4: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 4, Action: 0, Delta: 0.0
# Policy sum for state 4: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 3, Action: 3, Delta: 0.0
# Policy sum for state 3: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 20/20
# Step: 0, State: 13, Terminated: False, Truncated: False
# delta (4) - State: 13, Action: 0, Delta: 0.0
# Policy sum for state 13: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 12, Action: 3, Delta: 0.0
# Policy sum for state 12: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 12, Action: 1, Delta: 0.0
# Policy sum for state 12: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 13, Action: 0, Delta: 0.0
# Policy sum for state 13: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 12, Action: 3, Delta: 0.0
# Policy sum for state 12: 1.0
# Norm of Q-values: 0.01414213562373095
# delta (4) - State: 12, Action: 1, Delta: 0.0
# Policy sum for state 12: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
# Plot_steps funtion - Run 88 of 100
#  Actor_critic_q function - looping Episode 1/20
# Step: 0, State: 10, Terminated: False, Truncated: False
# delta (4) - State: 10, Action: 0, Delta: 0.0
# Policy sum for state 10: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 9, Action: 2, Delta: 0.0
# Policy sum for state 9: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 9, Action: 3, Delta: 0.0
# Policy sum for state 9: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 5, Action: 0, Delta: 0.0
# Policy sum for state 5: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 4, Action: 3, Delta: 0.0
# Policy sum for state 4: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 4, Action: 2, Delta: 0.0
# Policy sum for state 4: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 2/20
# Step: 0, State: 18, Terminated: False, Truncated: False
# delta (4) - State: 18, Action: 3, Delta: 0.0
# Policy sum for state 18: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 14, Action: 2, Delta: 0.0
# Policy sum for state 14: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 18, Action: 0, Delta: 0.0
# Policy sum for state 18: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 17, Action: 1, Delta: 0.0
# Policy sum for state 17: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 18, Action: 2, Delta: 0.0
# Policy sum for state 18: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 18, Action: 1, Delta: 0.0
# Policy sum for state 18: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 3/20
# Step: 0, State: 12, Terminated: False, Truncated: False
# delta (4) - State: 12, Action: 2, Delta: 0.0
# Policy sum for state 12: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 16, Action: 1, Delta: 0.0
# Policy sum for state 16: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 16, Action: 2, Delta: 0.0
# Policy sum for state 16: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 16, Action: 3, Delta: 0.0
# Policy sum for state 16: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 12, Action: 3, Delta: 0.0
# Policy sum for state 12: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 12, Action: 2, Delta: 0.0
# Policy sum for state 12: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 4/20
# Step: 0, State: 12, Terminated: False, Truncated: False
# delta (4) - State: 12, Action: 0, Delta: 0.0
# Policy sum for state 12: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 12, Action: 3, Delta: 0.0
# Policy sum for state 12: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 12, Action: 3, Delta: 0.0
# Policy sum for state 12: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 12, Action: 0, Delta: 0.0
# Policy sum for state 12: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 12, Action: 2, Delta: 0.0
# Policy sum for state 12: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 16, Action: 2, Delta: 0.0
# Policy sum for state 16: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 5/20
# Step: 0, State: 9, Terminated: False, Truncated: False
# delta (4) - State: 9, Action: 3, Delta: 0.0
# Policy sum for state 9: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 5, Action: 0, Delta: 0.0
# Policy sum for state 5: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 4, Action: 0, Delta: 0.0
# Policy sum for state 4: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 3, Action: 2, Delta: 0.0
# Policy sum for state 3: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 3, Action: 0, Delta: 0.0
# Policy sum for state 3: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 3, Action: 2, Delta: 0.0
# Policy sum for state 3: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 6/20
# Step: 0, State: 3, Terminated: False, Truncated: False
# delta (4) - State: 3, Action: 0, Delta: 0.0
# Policy sum for state 3: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 3, Action: 2, Delta: 0.0
# Policy sum for state 3: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 3, Action: 3, Delta: 0.0
# Policy sum for state 3: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 0, Action: 0, Delta: 0.0
# Policy sum for state 0: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 0, Action: 0, Delta: 0.0
# Policy sum for state 0: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 0, Action: 2, Delta: 0.0
# Policy sum for state 0: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 7/20
# Step: 0, State: 8, Terminated: False, Truncated: False
# delta (4) - State: 8, Action: 2, Delta: 0.0
# Policy sum for state 8: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 13, Action: 0, Delta: 0.0
# Policy sum for state 13: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 12, Action: 1, Delta: 0.0
# Policy sum for state 12: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 13, Action: 2, Delta: 0.0
# Policy sum for state 13: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 13, Action: 1, Delta: 0.0
# Policy sum for state 13: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 13, Action: 2, Delta: 0.0
# Policy sum for state 13: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 8/20
# Step: 0, State: 18, Terminated: False, Truncated: False
# delta (4) - State: 18, Action: 1, Delta: 0.0
# Policy sum for state 18: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 19, Action: 1, Delta: 1.0
# Policy sum for state 19: 1.0
# Norm of Q-values: 0.01
#  Actor_critic_q function - looping Episode 9/20
# Step: 0, State: 18, Terminated: False, Truncated: False
# delta (4) - State: 18, Action: 1, Delta: 0.009000000000000001
# Policy sum for state 18: 1.0000000000000002
# Norm of Q-values: 0.010000404991799083
# delta (4) - State: 19, Action: 1, Delta: 0.99
# Policy sum for state 19: 1.0
# Norm of Q-values: 0.01990020351654726
#  Actor_critic_q function - looping Episode 10/20
# Step: 0, State: 19, Terminated: False, Truncated: False
# delta (4) - State: 19, Action: 1, Delta: 0.9801
# Policy sum for state 19: 1.0000000000000002
# Norm of Q-values: 0.029701136358732137
#  Actor_critic_q function - looping Episode 11/20
# Step: 0, State: 1, Terminated: False, Truncated: False
# delta (4) - State: 1, Action: 3, Delta: 0.0
# Policy sum for state 1: 1.0
# Norm of Q-values: 0.029701136358732137
# delta (4) - State: 1, Action: 3, Delta: 0.0
# Policy sum for state 1: 1.0
# Norm of Q-values: 0.029701136358732137
# delta (4) - State: 1, Action: 3, Delta: 0.0
# Policy sum for state 1: 1.0
# Norm of Q-values: 0.029701136358732137
# delta (4) - State: 1, Action: 0, Delta: 0.0
# Policy sum for state 1: 1.0
# Norm of Q-values: 0.029701136358732137
# delta (4) - State: 1, Action: 0, Delta: 0.0
# Policy sum for state 1: 1.0
# Norm of Q-values: 0.029701136358732137
# delta (4) - State: 1, Action: 0, Delta: 0.0
# Policy sum for state 1: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 12/20
# Step: 0, State: 7, Terminated: False, Truncated: False
# delta (4) - State: 7, Action: 0, Delta: 0.0
# Policy sum for state 7: 1.0
# Norm of Q-values: 0.029701136358732137
# delta (4) - State: 6, Action: 3, Delta: 0.0
# Policy sum for state 6: 1.0
# Norm of Q-values: 0.029701136358732137
# delta (4) - State: 6, Action: 2, Delta: 0.0
# Policy sum for state 6: 1.0
# Norm of Q-values: 0.029701136358732137
# delta (4) - State: 10, Action: 0, Delta: 0.0
# Policy sum for state 10: 1.0
# Norm of Q-values: 0.029701136358732137
# delta (4) - State: 9, Action: 2, Delta: 0.0
# Policy sum for state 9: 1.0
# Norm of Q-values: 0.029701136358732137
# delta (4) - State: 9, Action: 0, Delta: 0.0
# Policy sum for state 9: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 13/20
# Step: 0, State: 1, Terminated: False, Truncated: False
# delta (4) - State: 1, Action: 3, Delta: 0.0
# Policy sum for state 1: 1.0
# Norm of Q-values: 0.029701136358732137
# delta (4) - State: 1, Action: 3, Delta: 0.0
# Policy sum for state 1: 1.0
# Norm of Q-values: 0.029701136358732137
# delta (4) - State: 1, Action: 1, Delta: 0.0
# Policy sum for state 1: 1.0
# Norm of Q-values: 0.029701136358732137
# delta (4) - State: 1, Action: 1, Delta: 0.0
# Policy sum for state 1: 1.0
# Norm of Q-values: 0.029701136358732137
# delta (4) - State: 1, Action: 1, Delta: 0.0
# Policy sum for state 1: 1.0
# Norm of Q-values: 0.029701136358732137
# delta (4) - State: 1, Action: 3, Delta: 0.0
# Policy sum for state 1: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 14/20
# Step: 0, State: 15, Terminated: False, Truncated: False
# delta (4) - State: 15, Action: 0, Delta: 0.0
# Policy sum for state 15: 1.0
# Norm of Q-values: 0.029701136358732137
# delta (4) - State: 14, Action: 0, Delta: 0.0
# Policy sum for state 14: 1.0
# Norm of Q-values: 0.029701136358732137
# delta (4) - State: 14, Action: 1, Delta: 0.0
# Policy sum for state 14: 1.0
# Norm of Q-values: 0.029701136358732137
# delta (4) - State: 15, Action: 0, Delta: 0.0
# Policy sum for state 15: 1.0
# Norm of Q-values: 0.029701136358732137
# delta (4) - State: 14, Action: 0, Delta: 0.0
# Policy sum for state 14: 1.0
# Norm of Q-values: 0.029701136358732137
# delta (4) - State: 14, Action: 3, Delta: 0.0
# Policy sum for state 14: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 15/20
# Step: 0, State: 12, Terminated: False, Truncated: False
# delta (4) - State: 12, Action: 2, Delta: 0.0
# Policy sum for state 12: 1.0
# Norm of Q-values: 0.029701136358732137
# delta (4) - State: 16, Action: 0, Delta: 0.0
# Policy sum for state 16: 1.0
# Norm of Q-values: 0.029701136358732137
# delta (4) - State: 16, Action: 2, Delta: 0.0
# Policy sum for state 16: 1.0
# Norm of Q-values: 0.029701136358732137
# delta (4) - State: 16, Action: 3, Delta: 0.0
# Policy sum for state 16: 1.0
# Norm of Q-values: 0.029701136358732137
# delta (4) - State: 12, Action: 0, Delta: 0.0
# Policy sum for state 12: 1.0
# Norm of Q-values: 0.029701136358732137
# delta (4) - State: 12, Action: 2, Delta: 0.0
# Policy sum for state 12: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 16/20
# Step: 0, State: 9, Terminated: False, Truncated: False
# delta (4) - State: 9, Action: 2, Delta: 0.0
# Policy sum for state 9: 1.0
# Norm of Q-values: 0.029701136358732137
# delta (4) - State: 9, Action: 3, Delta: 0.0
# Policy sum for state 9: 1.0
# Norm of Q-values: 0.029701136358732137
# delta (4) - State: 5, Action: 2, Delta: 0.0
# Policy sum for state 5: 1.0
# Norm of Q-values: 0.029701136358732137
# delta (4) - State: 9, Action: 2, Delta: 0.0
# Policy sum for state 9: 1.0
# Norm of Q-values: 0.029701136358732137
# delta (4) - State: 9, Action: 3, Delta: 0.0
# Policy sum for state 9: 1.0
# Norm of Q-values: 0.029701136358732137
# delta (4) - State: 5, Action: 2, Delta: 0.0
# Policy sum for state 5: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 17/20
# Step: 0, State: 2, Terminated: False, Truncated: False
# delta (4) - State: 2, Action: 3, Delta: 0.0
# Policy sum for state 2: 1.0
# Norm of Q-values: 0.029701136358732137
# delta (4) - State: 2, Action: 0, Delta: 0.0
# Policy sum for state 2: 1.0
# Norm of Q-values: 0.029701136358732137
# delta (4) - State: 2, Action: 0, Delta: 0.0
# Policy sum for state 2: 1.0
# Norm of Q-values: 0.029701136358732137
# delta (4) - State: 2, Action: 1, Delta: 0.0
# Policy sum for state 2: 1.0
# Norm of Q-values: 0.029701136358732137
# delta (4) - State: 2, Action: 1, Delta: 0.0
# Policy sum for state 2: 1.0
# Norm of Q-values: 0.029701136358732137
# delta (4) - State: 2, Action: 3, Delta: 0.0
# Policy sum for state 2: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 18/20
# Step: 0, State: 0, Terminated: False, Truncated: False
# delta (4) - State: 0, Action: 0, Delta: 0.0
# Policy sum for state 0: 1.0
# Norm of Q-values: 0.029701136358732137
# delta (4) - State: 0, Action: 2, Delta: 0.0
# Policy sum for state 0: 1.0
# Norm of Q-values: 0.029701136358732137
# delta (4) - State: 3, Action: 2, Delta: 0.0
# Policy sum for state 3: 1.0
# Norm of Q-values: 0.029701136358732137
# delta (4) - State: 3, Action: 1, Delta: 0.0
# Policy sum for state 3: 1.0
# Norm of Q-values: 0.029701136358732137
# delta (4) - State: 4, Action: 1, Delta: 0.0
# Policy sum for state 4: 1.0
# Norm of Q-values: 0.029701136358732137
# delta (4) - State: 5, Action: 1, Delta: 0.0
# Policy sum for state 5: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 19/20
# Step: 0, State: 16, Terminated: False, Truncated: False
# delta (4) - State: 16, Action: 1, Delta: 0.0
# Policy sum for state 16: 1.0
# Norm of Q-values: 0.029701136358732137
# delta (4) - State: 16, Action: 3, Delta: 0.0
# Policy sum for state 16: 1.0
# Norm of Q-values: 0.029701136358732137
# delta (4) - State: 12, Action: 3, Delta: 0.0
# Policy sum for state 12: 1.0
# Norm of Q-values: 0.029701136358732137
# delta (4) - State: 12, Action: 1, Delta: 0.0
# Policy sum for state 12: 1.0
# Norm of Q-values: 0.029701136358732137
# delta (4) - State: 13, Action: 3, Delta: 0.0
# Policy sum for state 13: 1.0
# Norm of Q-values: 0.029701136358732137
# delta (4) - State: 8, Action: 3, Delta: 0.0
# Policy sum for state 8: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 20/20
# Step: 0, State: 10, Terminated: False, Truncated: False
# delta (4) - State: 10, Action: 1, Delta: 0.0
# Policy sum for state 10: 1.0
# Norm of Q-values: 0.029701136358732137
# delta (4) - State: 11, Action: 2, Delta: 0.0
# Policy sum for state 11: 1.0
# Norm of Q-values: 0.029701136358732137
# delta (4) - State: 15, Action: 0, Delta: 0.0
# Policy sum for state 15: 1.0
# Norm of Q-values: 0.029701136358732137
# delta (4) - State: 14, Action: 1, Delta: 0.0
# Policy sum for state 14: 1.0
# Norm of Q-values: 0.029701136358732137
# delta (4) - State: 15, Action: 3, Delta: 0.0
# Policy sum for state 15: 1.0
# Norm of Q-values: 0.029701136358732137
# delta (4) - State: 11, Action: 0, Delta: 0.0
# Policy sum for state 11: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
# Plot_steps funtion - Run 89 of 100
#  Actor_critic_q function - looping Episode 1/20
# Step: 0, State: 2, Terminated: False, Truncated: False
# delta (4) - State: 2, Action: 2, Delta: 0.0
# Policy sum for state 2: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 7, Action: 3, Delta: 0.0
# Policy sum for state 7: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 2, Action: 2, Delta: 0.0
# Policy sum for state 2: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 7, Action: 1, Delta: 0.0
# Policy sum for state 7: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 7, Action: 3, Delta: 0.0
# Policy sum for state 7: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 2, Action: 2, Delta: 0.0
# Policy sum for state 2: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 2/20
# Step: 0, State: 4, Terminated: False, Truncated: False
# delta (4) - State: 4, Action: 3, Delta: 0.0
# Policy sum for state 4: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 4, Action: 2, Delta: 0.0
# Policy sum for state 4: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 8, Action: 0, Delta: 0.0
# Policy sum for state 8: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 8, Action: 1, Delta: 0.0
# Policy sum for state 8: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 9, Action: 1, Delta: 0.0
# Policy sum for state 9: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 10, Action: 0, Delta: 0.0
# Policy sum for state 10: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 3/20
# Step: 0, State: 10, Terminated: False, Truncated: False
# delta (4) - State: 10, Action: 3, Delta: 0.0
# Policy sum for state 10: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 6, Action: 3, Delta: 0.0
# Policy sum for state 6: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 6, Action: 2, Delta: 0.0
# Policy sum for state 6: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 10, Action: 3, Delta: 0.0
# Policy sum for state 10: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 6, Action: 0, Delta: 0.0
# Policy sum for state 6: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 5, Action: 1, Delta: 0.0
# Policy sum for state 5: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 4/20
# Step: 0, State: 8, Terminated: False, Truncated: False
# delta (4) - State: 8, Action: 1, Delta: 0.0
# Policy sum for state 8: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 9, Action: 2, Delta: 0.0
# Policy sum for state 9: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 9, Action: 2, Delta: 0.0
# Policy sum for state 9: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 9, Action: 2, Delta: 0.0
# Policy sum for state 9: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 9, Action: 1, Delta: 0.0
# Policy sum for state 9: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 10, Action: 2, Delta: 0.0
# Policy sum for state 10: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 5/20
# Step: 0, State: 6, Terminated: False, Truncated: False
# delta (4) - State: 6, Action: 2, Delta: 0.0
# Policy sum for state 6: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 10, Action: 2, Delta: 0.0
# Policy sum for state 10: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 14, Action: 0, Delta: 0.0
# Policy sum for state 14: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 14, Action: 0, Delta: 0.0
# Policy sum for state 14: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 14, Action: 0, Delta: 0.0
# Policy sum for state 14: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 14, Action: 3, Delta: 0.0
# Policy sum for state 14: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 6/20
# Step: 0, State: 4, Terminated: False, Truncated: False
# delta (4) - State: 4, Action: 2, Delta: 0.0
# Policy sum for state 4: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 8, Action: 0, Delta: 0.0
# Policy sum for state 8: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 8, Action: 3, Delta: 0.0
# Policy sum for state 8: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 4, Action: 2, Delta: 0.0
# Policy sum for state 4: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 8, Action: 3, Delta: 0.0
# Policy sum for state 8: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 4, Action: 3, Delta: 0.0
# Policy sum for state 4: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 7/20
# Step: 0, State: 2, Terminated: False, Truncated: False
# delta (4) - State: 2, Action: 3, Delta: 0.0
# Policy sum for state 2: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 2, Action: 1, Delta: 0.0
# Policy sum for state 2: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 2, Action: 3, Delta: 0.0
# Policy sum for state 2: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 2, Action: 2, Delta: 0.0
# Policy sum for state 2: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 7, Action: 2, Delta: 0.0
# Policy sum for state 7: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 11, Action: 2, Delta: 0.0
# Policy sum for state 11: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 8/20
# Step: 0, State: 3, Terminated: False, Truncated: False
# delta (4) - State: 3, Action: 2, Delta: 0.0
# Policy sum for state 3: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 3, Action: 1, Delta: 0.0
# Policy sum for state 3: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 4, Action: 2, Delta: 0.0
# Policy sum for state 4: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 8, Action: 1, Delta: 0.0
# Policy sum for state 8: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 9, Action: 2, Delta: 0.0
# Policy sum for state 9: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 9, Action: 2, Delta: 0.0
# Policy sum for state 9: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 9/20
# Step: 0, State: 5, Terminated: False, Truncated: False
# delta (4) - State: 5, Action: 0, Delta: 0.0
# Policy sum for state 5: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 4, Action: 0, Delta: 0.0
# Policy sum for state 4: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 3, Action: 1, Delta: 0.0
# Policy sum for state 3: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 4, Action: 0, Delta: 0.0
# Policy sum for state 4: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 3, Action: 2, Delta: 0.0
# Policy sum for state 3: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 3, Action: 1, Delta: 0.0
# Policy sum for state 3: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 10/20
# Step: 0, State: 10, Terminated: False, Truncated: False
# delta (4) - State: 10, Action: 0, Delta: 0.0
# Policy sum for state 10: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 9, Action: 1, Delta: 0.0
# Policy sum for state 9: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 10, Action: 0, Delta: 0.0
# Policy sum for state 10: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 9, Action: 2, Delta: 0.0
# Policy sum for state 9: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 9, Action: 1, Delta: 0.0
# Policy sum for state 9: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 10, Action: 0, Delta: 0.0
# Policy sum for state 10: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 11/20
# Step: 0, State: 7, Terminated: False, Truncated: False
# delta (4) - State: 7, Action: 1, Delta: 0.0
# Policy sum for state 7: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 7, Action: 2, Delta: 0.0
# Policy sum for state 7: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 11, Action: 3, Delta: 0.0
# Policy sum for state 11: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 7, Action: 0, Delta: 0.0
# Policy sum for state 7: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 6, Action: 0, Delta: 0.0
# Policy sum for state 6: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 5, Action: 2, Delta: 0.0
# Policy sum for state 5: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 12/20
# Step: 0, State: 4, Terminated: False, Truncated: False
# delta (4) - State: 4, Action: 1, Delta: 0.0
# Policy sum for state 4: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 5, Action: 2, Delta: 0.0
# Policy sum for state 5: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 9, Action: 2, Delta: 0.0
# Policy sum for state 9: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 9, Action: 3, Delta: 0.0
# Policy sum for state 9: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 5, Action: 3, Delta: 0.0
# Policy sum for state 5: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 1, Action: 1, Delta: 0.0
# Policy sum for state 1: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 13/20
# Step: 0, State: 6, Terminated: False, Truncated: False
# delta (4) - State: 6, Action: 0, Delta: 0.0
# Policy sum for state 6: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 5, Action: 2, Delta: 0.0
# Policy sum for state 5: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 9, Action: 0, Delta: 0.0
# Policy sum for state 9: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 8, Action: 2, Delta: 0.0
# Policy sum for state 8: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 13, Action: 1, Delta: 0.0
# Policy sum for state 13: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 13, Action: 1, Delta: 0.0
# Policy sum for state 13: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 14/20
# Step: 0, State: 6, Terminated: False, Truncated: False
# delta (4) - State: 6, Action: 3, Delta: 0.0
# Policy sum for state 6: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 6, Action: 3, Delta: 0.0
# Policy sum for state 6: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 6, Action: 0, Delta: 0.0
# Policy sum for state 6: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 5, Action: 1, Delta: 0.0
# Policy sum for state 5: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 6, Action: 2, Delta: 0.0
# Policy sum for state 6: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 10, Action: 0, Delta: 0.0
# Policy sum for state 10: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 15/20
# Step: 0, State: 9, Terminated: False, Truncated: False
# delta (4) - State: 9, Action: 1, Delta: 0.0
# Policy sum for state 9: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 10, Action: 1, Delta: 0.0
# Policy sum for state 10: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 11, Action: 0, Delta: 0.0
# Policy sum for state 11: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 10, Action: 2, Delta: 0.0
# Policy sum for state 10: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 14, Action: 2, Delta: 0.0
# Policy sum for state 14: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 18, Action: 2, Delta: 0.0
# Policy sum for state 18: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 16/20
# Step: 0, State: 18, Terminated: False, Truncated: False
# delta (4) - State: 18, Action: 2, Delta: 0.0
# Policy sum for state 18: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 18, Action: 1, Delta: 0.0
# Policy sum for state 18: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 19, Action: 2, Delta: 1.0
# Policy sum for state 19: 1.0
# Norm of Q-values: 0.01
#  Actor_critic_q function - looping Episode 17/20
# Step: 0, State: 13, Terminated: False, Truncated: False
# delta (4) - State: 13, Action: 2, Delta: 0.0
# Policy sum for state 13: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 13, Action: 1, Delta: 0.0
# Policy sum for state 13: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 13, Action: 1, Delta: 0.0
# Policy sum for state 13: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 13, Action: 3, Delta: 0.0
# Policy sum for state 13: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 8, Action: 0, Delta: 0.0
# Policy sum for state 8: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 8, Action: 3, Delta: 0.0
# Policy sum for state 8: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 18/20
# Step: 0, State: 8, Terminated: False, Truncated: False
# delta (4) - State: 8, Action: 2, Delta: 0.0
# Policy sum for state 8: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 13, Action: 2, Delta: 0.0
# Policy sum for state 13: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 13, Action: 1, Delta: 0.0
# Policy sum for state 13: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 13, Action: 3, Delta: 0.0
# Policy sum for state 13: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 8, Action: 0, Delta: 0.0
# Policy sum for state 8: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 8, Action: 0, Delta: 0.0
# Policy sum for state 8: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 19/20
# Step: 0, State: 0, Terminated: False, Truncated: False
# delta (4) - State: 0, Action: 2, Delta: 0.0
# Policy sum for state 0: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 3, Action: 3, Delta: 0.0
# Policy sum for state 3: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 0, Action: 3, Delta: 0.0
# Policy sum for state 0: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 0, Action: 2, Delta: 0.0
# Policy sum for state 0: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 3, Action: 1, Delta: 0.0
# Policy sum for state 3: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 4, Action: 3, Delta: 0.0
# Policy sum for state 4: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 20/20
# Step: 0, State: 10, Terminated: False, Truncated: False
# delta (4) - State: 10, Action: 3, Delta: 0.0
# Policy sum for state 10: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 6, Action: 3, Delta: 0.0
# Policy sum for state 6: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 6, Action: 1, Delta: 0.0
# Policy sum for state 6: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 7, Action: 2, Delta: 0.0
# Policy sum for state 7: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 11, Action: 2, Delta: 0.0
# Policy sum for state 11: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 15, Action: 1, Delta: 0.0
# Policy sum for state 15: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
# Plot_steps funtion - Run 90 of 100
#  Actor_critic_q function - looping Episode 1/20
# Step: 0, State: 7, Terminated: False, Truncated: False
# delta (4) - State: 7, Action: 0, Delta: 0.0
# Policy sum for state 7: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 6, Action: 3, Delta: 0.0
# Policy sum for state 6: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 6, Action: 3, Delta: 0.0
# Policy sum for state 6: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 6, Action: 3, Delta: 0.0
# Policy sum for state 6: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 6, Action: 2, Delta: 0.0
# Policy sum for state 6: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 10, Action: 3, Delta: 0.0
# Policy sum for state 10: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 2/20
# Step: 0, State: 10, Terminated: False, Truncated: False
# delta (4) - State: 10, Action: 0, Delta: 0.0
# Policy sum for state 10: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 9, Action: 3, Delta: 0.0
# Policy sum for state 9: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 5, Action: 0, Delta: 0.0
# Policy sum for state 5: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 4, Action: 1, Delta: 0.0
# Policy sum for state 4: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 5, Action: 2, Delta: 0.0
# Policy sum for state 5: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 9, Action: 2, Delta: 0.0
# Policy sum for state 9: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 3/20
# Step: 0, State: 10, Terminated: False, Truncated: False
# delta (4) - State: 10, Action: 2, Delta: 0.0
# Policy sum for state 10: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 14, Action: 2, Delta: 0.0
# Policy sum for state 14: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 18, Action: 0, Delta: 0.0
# Policy sum for state 18: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 17, Action: 3, Delta: 0.0
# Policy sum for state 17: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 17, Action: 0, Delta: 0.0
# Policy sum for state 17: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 17, Action: 3, Delta: 0.0
# Policy sum for state 17: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 4/20
# Step: 0, State: 6, Terminated: False, Truncated: False
# delta (4) - State: 6, Action: 2, Delta: 0.0
# Policy sum for state 6: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 10, Action: 1, Delta: 0.0
# Policy sum for state 10: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 11, Action: 3, Delta: 0.0
# Policy sum for state 11: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 7, Action: 2, Delta: 0.0
# Policy sum for state 7: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 11, Action: 3, Delta: 0.0
# Policy sum for state 11: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 7, Action: 0, Delta: 0.0
# Policy sum for state 7: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 5/20
# Step: 0, State: 0, Terminated: False, Truncated: False
# delta (4) - State: 0, Action: 0, Delta: 0.0
# Policy sum for state 0: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 0, Action: 2, Delta: 0.0
# Policy sum for state 0: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 3, Action: 1, Delta: 0.0
# Policy sum for state 3: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 4, Action: 2, Delta: 0.0
# Policy sum for state 4: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 8, Action: 2, Delta: 0.0
# Policy sum for state 8: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 13, Action: 1, Delta: 0.0
# Policy sum for state 13: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 6/20
# Step: 0, State: 7, Terminated: False, Truncated: False
# delta (4) - State: 7, Action: 2, Delta: 0.0
# Policy sum for state 7: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 11, Action: 2, Delta: 0.0
# Policy sum for state 11: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 15, Action: 0, Delta: 0.0
# Policy sum for state 15: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 14, Action: 2, Delta: 0.0
# Policy sum for state 14: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 18, Action: 1, Delta: 0.0
# Policy sum for state 18: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 19, Action: 3, Delta: 1.0
# Policy sum for state 19: 1.0
# Norm of Q-values: 0.01
#  Actor_critic_q function - looping Episode 7/20
# Step: 0, State: 7, Terminated: False, Truncated: False
# delta (4) - State: 7, Action: 1, Delta: 0.0
# Policy sum for state 7: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 7, Action: 0, Delta: 0.0
# Policy sum for state 7: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 6, Action: 2, Delta: 0.0
# Policy sum for state 6: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 10, Action: 3, Delta: 0.0
# Policy sum for state 10: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 6, Action: 1, Delta: 0.0
# Policy sum for state 6: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 7, Action: 2, Delta: 0.0
# Policy sum for state 7: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 8/20
# Step: 0, State: 18, Terminated: False, Truncated: False
# delta (4) - State: 18, Action: 0, Delta: 0.0
# Policy sum for state 18: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 17, Action: 2, Delta: 0.0
# Policy sum for state 17: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 17, Action: 3, Delta: 0.0
# Policy sum for state 17: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 17, Action: 0, Delta: 0.0
# Policy sum for state 17: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 17, Action: 0, Delta: 0.0
# Policy sum for state 17: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 17, Action: 0, Delta: 0.0
# Policy sum for state 17: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 9/20
# Step: 0, State: 18, Terminated: False, Truncated: False
# delta (4) - State: 18, Action: 2, Delta: 0.0
# Policy sum for state 18: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 18, Action: 2, Delta: 0.0
# Policy sum for state 18: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 18, Action: 0, Delta: 0.0
# Policy sum for state 18: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 17, Action: 2, Delta: 0.0
# Policy sum for state 17: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 17, Action: 0, Delta: 0.0
# Policy sum for state 17: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 17, Action: 0, Delta: 0.0
# Policy sum for state 17: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 10/20
# Step: 0, State: 2, Terminated: False, Truncated: False
# delta (4) - State: 2, Action: 0, Delta: 0.0
# Policy sum for state 2: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 2, Action: 0, Delta: 0.0
# Policy sum for state 2: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 2, Action: 0, Delta: 0.0
# Policy sum for state 2: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 2, Action: 1, Delta: 0.0
# Policy sum for state 2: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 2, Action: 3, Delta: 0.0
# Policy sum for state 2: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 2, Action: 0, Delta: 0.0
# Policy sum for state 2: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 11/20
# Step: 0, State: 8, Terminated: False, Truncated: False
# delta (4) - State: 8, Action: 3, Delta: 0.0
# Policy sum for state 8: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 4, Action: 0, Delta: 0.0
# Policy sum for state 4: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 3, Action: 3, Delta: 0.0
# Policy sum for state 3: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 0, Action: 1, Delta: 0.0
# Policy sum for state 0: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 0, Action: 0, Delta: 0.0
# Policy sum for state 0: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 0, Action: 0, Delta: 0.0
# Policy sum for state 0: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 12/20
# Step: 0, State: 14, Terminated: False, Truncated: False
# delta (4) - State: 14, Action: 0, Delta: 0.0
# Policy sum for state 14: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 14, Action: 1, Delta: 0.0
# Policy sum for state 14: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 15, Action: 1, Delta: 0.0
# Policy sum for state 15: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 15, Action: 3, Delta: 0.0
# Policy sum for state 15: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 11, Action: 3, Delta: 0.0
# Policy sum for state 11: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 7, Action: 1, Delta: 0.0
# Policy sum for state 7: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 13/20
# Step: 0, State: 0, Terminated: False, Truncated: False
# delta (4) - State: 0, Action: 2, Delta: 0.0
# Policy sum for state 0: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 3, Action: 3, Delta: 0.0
# Policy sum for state 3: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 0, Action: 1, Delta: 0.0
# Policy sum for state 0: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 0, Action: 0, Delta: 0.0
# Policy sum for state 0: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 0, Action: 1, Delta: 0.0
# Policy sum for state 0: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 0, Action: 1, Delta: 0.0
# Policy sum for state 0: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 14/20
# Step: 0, State: 1, Terminated: False, Truncated: False
# delta (4) - State: 1, Action: 2, Delta: 0.0
# Policy sum for state 1: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 5, Action: 3, Delta: 0.0
# Policy sum for state 5: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 1, Action: 2, Delta: 0.0
# Policy sum for state 1: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 5, Action: 0, Delta: 0.0
# Policy sum for state 5: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 4, Action: 3, Delta: 0.0
# Policy sum for state 4: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 4, Action: 2, Delta: 0.0
# Policy sum for state 4: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 15/20
# Step: 0, State: 0, Terminated: False, Truncated: False
# delta (4) - State: 0, Action: 1, Delta: 0.0
# Policy sum for state 0: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 0, Action: 3, Delta: 0.0
# Policy sum for state 0: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 0, Action: 2, Delta: 0.0
# Policy sum for state 0: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 3, Action: 3, Delta: 0.0
# Policy sum for state 3: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 0, Action: 1, Delta: 0.0
# Policy sum for state 0: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 0, Action: 2, Delta: 0.0
# Policy sum for state 0: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 16/20
# Step: 0, State: 9, Terminated: False, Truncated: False
# delta (4) - State: 9, Action: 1, Delta: 0.0
# Policy sum for state 9: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 10, Action: 0, Delta: 0.0
# Policy sum for state 10: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 9, Action: 0, Delta: 0.0
# Policy sum for state 9: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 8, Action: 1, Delta: 0.0
# Policy sum for state 8: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 9, Action: 2, Delta: 0.0
# Policy sum for state 9: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 9, Action: 1, Delta: 0.0
# Policy sum for state 9: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 17/20
# Step: 0, State: 8, Terminated: False, Truncated: False
# delta (4) - State: 8, Action: 3, Delta: 0.0
# Policy sum for state 8: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 4, Action: 1, Delta: 0.0
# Policy sum for state 4: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 5, Action: 1, Delta: 0.0
# Policy sum for state 5: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 6, Action: 3, Delta: 0.0
# Policy sum for state 6: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 6, Action: 2, Delta: 0.0
# Policy sum for state 6: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 10, Action: 3, Delta: 0.0
# Policy sum for state 10: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 18/20
# Step: 0, State: 18, Terminated: False, Truncated: False
# delta (4) - State: 18, Action: 2, Delta: 0.0
# Policy sum for state 18: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 18, Action: 0, Delta: 0.0
# Policy sum for state 18: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 17, Action: 2, Delta: 0.0
# Policy sum for state 17: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 17, Action: 1, Delta: 0.0
# Policy sum for state 17: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 18, Action: 1, Delta: 0.009000000000000001
# Policy sum for state 18: 1.0000000000000002
# Norm of Q-values: 0.010000404991799083
# delta (4) - State: 19, Action: 1, Delta: 1.0
# Policy sum for state 19: 1.0
# Norm of Q-values: 0.01414242199907781
#  Actor_critic_q function - looping Episode 19/20
# Step: 0, State: 10, Terminated: False, Truncated: False
# delta (4) - State: 10, Action: 3, Delta: 0.0
# Policy sum for state 10: 1.0
# Norm of Q-values: 0.01414242199907781
# delta (4) - State: 6, Action: 1, Delta: 0.0
# Policy sum for state 6: 1.0
# Norm of Q-values: 0.01414242199907781
# delta (4) - State: 7, Action: 3, Delta: 0.0
# Policy sum for state 7: 1.0
# Norm of Q-values: 0.01414242199907781
# delta (4) - State: 2, Action: 1, Delta: 0.0
# Policy sum for state 2: 1.0
# Norm of Q-values: 0.01414242199907781
# delta (4) - State: 2, Action: 1, Delta: 0.0
# Policy sum for state 2: 1.0
# Norm of Q-values: 0.01414242199907781
# delta (4) - State: 2, Action: 0, Delta: 0.0
# Policy sum for state 2: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 20/20
# Step: 0, State: 1, Terminated: False, Truncated: False
# delta (4) - State: 1, Action: 1, Delta: 0.0
# Policy sum for state 1: 1.0
# Norm of Q-values: 0.01414242199907781
# delta (4) - State: 1, Action: 3, Delta: 0.0
# Policy sum for state 1: 1.0
# Norm of Q-values: 0.01414242199907781
# delta (4) - State: 1, Action: 3, Delta: 0.0
# Policy sum for state 1: 1.0
# Norm of Q-values: 0.01414242199907781
# delta (4) - State: 1, Action: 1, Delta: 0.0
# Policy sum for state 1: 1.0
# Norm of Q-values: 0.01414242199907781
# delta (4) - State: 1, Action: 1, Delta: 0.0
# Policy sum for state 1: 1.0
# Norm of Q-values: 0.01414242199907781
# delta (4) - State: 1, Action: 0, Delta: 0.0
# Policy sum for state 1: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
# Plot_steps funtion - Run 91 of 100
#  Actor_critic_q function - looping Episode 1/20
# Step: 0, State: 11, Terminated: False, Truncated: False
# delta (4) - State: 11, Action: 2, Delta: 0.0
# Policy sum for state 11: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 15, Action: 3, Delta: 0.0
# Policy sum for state 15: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 11, Action: 1, Delta: 0.0
# Policy sum for state 11: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 11, Action: 2, Delta: 0.0
# Policy sum for state 11: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 15, Action: 3, Delta: 0.0
# Policy sum for state 15: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 11, Action: 1, Delta: 0.0
# Policy sum for state 11: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 2/20
# Step: 0, State: 14, Terminated: False, Truncated: False
# delta (4) - State: 14, Action: 1, Delta: 0.0
# Policy sum for state 14: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 15, Action: 3, Delta: 0.0
# Policy sum for state 15: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 11, Action: 1, Delta: 0.0
# Policy sum for state 11: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 11, Action: 2, Delta: 0.0
# Policy sum for state 11: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 15, Action: 1, Delta: 0.0
# Policy sum for state 15: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 15, Action: 1, Delta: 0.0
# Policy sum for state 15: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 3/20
# Step: 0, State: 16, Terminated: False, Truncated: False
# delta (4) - State: 16, Action: 1, Delta: 0.0
# Policy sum for state 16: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 16, Action: 1, Delta: 0.0
# Policy sum for state 16: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 16, Action: 2, Delta: 0.0
# Policy sum for state 16: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 16, Action: 1, Delta: 0.0
# Policy sum for state 16: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 16, Action: 3, Delta: 0.0
# Policy sum for state 16: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 12, Action: 1, Delta: 0.0
# Policy sum for state 12: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 4/20
# Step: 0, State: 15, Terminated: False, Truncated: False
# delta (4) - State: 15, Action: 2, Delta: 0.0
# Policy sum for state 15: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 19, Action: 1, Delta: 1.0
# Policy sum for state 19: 1.0
# Norm of Q-values: 0.01
#  Actor_critic_q function - looping Episode 5/20
# Step: 0, State: 11, Terminated: False, Truncated: False
# delta (4) - State: 11, Action: 1, Delta: 0.0
# Policy sum for state 11: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 11, Action: 0, Delta: 0.0
# Policy sum for state 11: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 10, Action: 2, Delta: 0.0
# Policy sum for state 10: 1.0
# Norm of Q-values: 0.01
# ...
# delta (4) - State: 3, Action: 3, Delta: 0.0
# Policy sum for state 3: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 3, Action: 0, Delta: 0.0
# Policy sum for state 3: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 3, Action: 3, Delta: 0.0
# Policy sum for state 3: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 18/20
# Step: 0, State: 18, Terminated: False, Truncated: False
# delta (4) - State: 18, Action: 1, Delta: 0.0
# Policy sum for state 18: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 18, Action: 2, Delta: 0.0
# Policy sum for state 18: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 18, Action: 0, Delta: 0.0
# Policy sum for state 18: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 17, Action: 0, Delta: 0.0
# Policy sum for state 17: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 16, Action: 2, Delta: 0.0
# Policy sum for state 16: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 16, Action: 2, Delta: 0.0
# Policy sum for state 16: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 19/20
# Step: 0, State: 1, Terminated: False, Truncated: False
# delta (4) - State: 1, Action: 2, Delta: 0.0
# Policy sum for state 1: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 5, Action: 2, Delta: 0.0
# Policy sum for state 5: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 10, Action: 3, Delta: 0.0
# Policy sum for state 10: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 5, Action: 0, Delta: 0.0
# Policy sum for state 5: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 4, Action: 3, Delta: 0.0
# Policy sum for state 4: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 0, Action: 0, Delta: 0.0
# Policy sum for state 0: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 20/20
# Step: 0, State: 4, Terminated: False, Truncated: False
# delta (4) - State: 4, Action: 1, Delta: 0.0
# Policy sum for state 4: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 5, Action: 0, Delta: 0.0
# Policy sum for state 5: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 4, Action: 3, Delta: 0.0
# Policy sum for state 4: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 0, Action: 0, Delta: 0.0
# Policy sum for state 0: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 0, Action: 2, Delta: 0.0
# Policy sum for state 0: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 4, Action: 3, Delta: 0.0
# Policy sum for state 4: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
# Plot_steps funtion - Run 100 of 100
#  Actor_critic_q function - looping Episode 1/20
# Step: 0, State: 17, Terminated: False, Truncated: False
# delta (4) - State: 17, Action: 1, Delta: 0.0
# Policy sum for state 17: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 18, Action: 3, Delta: 0.0
# Policy sum for state 18: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 13, Action: 1, Delta: 0.0
# Policy sum for state 13: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 13, Action: 3, Delta: 0.0
# Policy sum for state 13: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 8, Action: 1, Delta: 0.0
# Policy sum for state 8: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 8, Action: 3, Delta: 0.0
# Policy sum for state 8: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 2/20
# Step: 0, State: 5, Terminated: False, Truncated: False
# delta (4) - State: 5, Action: 2, Delta: 0.0
# Policy sum for state 5: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 10, Action: 0, Delta: 0.0
# Policy sum for state 10: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 9, Action: 2, Delta: 0.0
# Policy sum for state 9: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 14, Action: 1, Delta: 0.0
# Policy sum for state 14: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 15, Action: 3, Delta: 0.0
# Policy sum for state 15: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 10, Action: 3, Delta: 0.0
# Policy sum for state 10: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 3/20
# Step: 0, State: 13, Terminated: False, Truncated: False
# delta (4) - State: 13, Action: 3, Delta: 0.0
# Policy sum for state 13: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 8, Action: 0, Delta: 0.0
# Policy sum for state 8: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 7, Action: 0, Delta: 0.0
# Policy sum for state 7: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 6, Action: 2, Delta: 0.0
# Policy sum for state 6: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 11, Action: 2, Delta: 0.0
# Policy sum for state 11: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 16, Action: 3, Delta: 0.0
# Policy sum for state 16: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 4/20
# Step: 0, State: 1, Terminated: False, Truncated: False
# delta (4) - State: 1, Action: 1, Delta: 0.0
# Policy sum for state 1: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 2, Action: 0, Delta: 0.0
# Policy sum for state 2: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 1, Action: 3, Delta: 0.0
# Policy sum for state 1: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 1, Action: 3, Delta: 0.0
# Policy sum for state 1: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 1, Action: 1, Delta: 0.0
# Policy sum for state 1: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 2, Action: 0, Delta: 0.0
# Policy sum for state 2: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 5/20
# Step: 0, State: 5, Terminated: False, Truncated: False
# delta (4) - State: 5, Action: 1, Delta: 0.0
# Policy sum for state 5: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 6, Action: 0, Delta: 0.0
# Policy sum for state 6: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 5, Action: 1, Delta: 0.0
# Policy sum for state 5: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 6, Action: 3, Delta: 0.0
# Policy sum for state 6: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 2, Action: 1, Delta: 0.0
# Policy sum for state 2: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 2, Action: 1, Delta: 0.0
# Policy sum for state 2: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 6/20
# Step: 0, State: 15, Terminated: False, Truncated: False
# delta (4) - State: 15, Action: 0, Delta: 0.0
# Policy sum for state 15: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 14, Action: 0, Delta: 0.0
# Policy sum for state 14: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 14, Action: 3, Delta: 0.0
# Policy sum for state 14: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 9, Action: 1, Delta: 0.0
# Policy sum for state 9: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 10, Action: 3, Delta: 0.0
# Policy sum for state 10: 1.0
# Norm of Q-values: 0.0
# delta (4) - State: 5, Action: 0, Delta: 0.0
# Policy sum for state 5: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 7/20
# Step: 0, State: 19, Terminated: False, Truncated: False
# delta (4) - State: 19, Action: 1, Delta: 1.0
# Policy sum for state 19: 1.0
# Norm of Q-values: 0.01
#  Actor_critic_q function - looping Episode 8/20
# Step: 0, State: 7, Terminated: False, Truncated: False
# delta (4) - State: 7, Action: 2, Delta: 0.0
# Policy sum for state 7: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 12, Action: 3, Delta: 0.0
# Policy sum for state 12: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 7, Action: 0, Delta: 0.0
# Policy sum for state 7: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 6, Action: 1, Delta: 0.0
# Policy sum for state 6: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 7, Action: 0, Delta: 0.0
# Policy sum for state 7: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 6, Action: 1, Delta: 0.0
# Policy sum for state 6: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 9/20
# Step: 0, State: 8, Terminated: False, Truncated: False
# delta (4) - State: 8, Action: 0, Delta: 0.0
# Policy sum for state 8: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 7, Action: 1, Delta: 0.0
# Policy sum for state 7: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 8, Action: 0, Delta: 0.0
# Policy sum for state 8: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 7, Action: 3, Delta: 0.0
# Policy sum for state 7: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 7, Action: 3, Delta: 0.0
# Policy sum for state 7: 1.0
# Norm of Q-values: 0.01
# delta (4) - State: 7, Action: 3, Delta: 0.0
# Policy sum for state 7: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 10/20
# Step: 0, State: 19, Terminated: False, Truncated: False
# delta (4) - State: 19, Action: 1, Delta: 0.99
# Policy sum for state 19: 1.0
# Norm of Q-values: 0.0199
#  Actor_critic_q function - looping Episode 11/20
# Step: 0, State: 7, Terminated: False, Truncated: False
# delta (4) - State: 7, Action: 3, Delta: 0.0
# Policy sum for state 7: 1.0
# Norm of Q-values: 0.0199
# delta (4) - State: 7, Action: 1, Delta: 0.0
# Policy sum for state 7: 1.0
# Norm of Q-values: 0.0199
# delta (4) - State: 8, Action: 3, Delta: 0.0
# Policy sum for state 8: 1.0
# Norm of Q-values: 0.0199
# delta (4) - State: 3, Action: 2, Delta: 0.0
# Policy sum for state 3: 1.0
# Norm of Q-values: 0.0199
# delta (4) - State: 8, Action: 1, Delta: 0.0
# Policy sum for state 8: 1.0
# Norm of Q-values: 0.0199
# delta (4) - State: 8, Action: 1, Delta: 0.0
# Policy sum for state 8: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 12/20
# Step: 0, State: 6, Terminated: False, Truncated: False
# delta (4) - State: 6, Action: 1, Delta: 0.0
# Policy sum for state 6: 1.0
# Norm of Q-values: 0.0199
# delta (4) - State: 7, Action: 3, Delta: 0.0
# Policy sum for state 7: 1.0
# Norm of Q-values: 0.0199
# delta (4) - State: 7, Action: 1, Delta: 0.0
# Policy sum for state 7: 1.0
# Norm of Q-values: 0.0199
# delta (4) - State: 8, Action: 2, Delta: 0.0
# Policy sum for state 8: 1.0
# Norm of Q-values: 0.0199
# delta (4) - State: 13, Action: 2, Delta: 0.0
# Policy sum for state 13: 1.0
# Norm of Q-values: 0.0199
# delta (4) - State: 18, Action: 1, Delta: 0.0
# Policy sum for state 18: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 13/20
# Step: 0, State: 19, Terminated: False, Truncated: False
# delta (4) - State: 19, Action: 3, Delta: 1.0
# Policy sum for state 19: 1.0
# Norm of Q-values: 0.022271281956816047
#  Actor_critic_q function - looping Episode 14/20
# Step: 0, State: 13, Terminated: False, Truncated: False
# delta (4) - State: 13, Action: 3, Delta: 0.0
# Policy sum for state 13: 1.0
# Norm of Q-values: 0.022271281956816047
# delta (4) - State: 8, Action: 3, Delta: 0.0
# Policy sum for state 8: 1.0
# Norm of Q-values: 0.022271281956816047
# delta (4) - State: 3, Action: 3, Delta: 0.0
# Policy sum for state 3: 1.0
# Norm of Q-values: 0.022271281956816047
# delta (4) - State: 3, Action: 2, Delta: 0.0
# Policy sum for state 3: 1.0
# Norm of Q-values: 0.022271281956816047
# delta (4) - State: 8, Action: 2, Delta: 0.0
# Policy sum for state 8: 1.0
# Norm of Q-values: 0.022271281956816047
# delta (4) - State: 13, Action: 0, Delta: 0.0
# Policy sum for state 13: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 15/20
# Step: 0, State: 1, Terminated: False, Truncated: False
# delta (4) - State: 1, Action: 0, Delta: 0.0
# Policy sum for state 1: 1.0
# Norm of Q-values: 0.022271281956816047
# delta (4) - State: 0, Action: 2, Delta: 0.0
# Policy sum for state 0: 1.0
# Norm of Q-values: 0.022271281956816047
# delta (4) - State: 4, Action: 0, Delta: 0.0
# Policy sum for state 4: 1.0
# Norm of Q-values: 0.022271281956816047
# delta (4) - State: 4, Action: 1, Delta: 0.0
# Policy sum for state 4: 1.0
# Norm of Q-values: 0.022271281956816047
# delta (4) - State: 5, Action: 2, Delta: 0.0
# Policy sum for state 5: 1.0
# Norm of Q-values: 0.022271281956816047
# delta (4) - State: 10, Action: 2, Delta: 0.0
# Policy sum for state 10: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 16/20
# Step: 0, State: 13, Terminated: False, Truncated: False
# delta (4) - State: 13, Action: 0, Delta: 0.0
# Policy sum for state 13: 1.0
# Norm of Q-values: 0.022271281956816047
# delta (4) - State: 12, Action: 0, Delta: 0.0
# Policy sum for state 12: 1.0
# Norm of Q-values: 0.022271281956816047
# delta (4) - State: 11, Action: 3, Delta: 0.0
# Policy sum for state 11: 1.0
# Norm of Q-values: 0.022271281956816047
# delta (4) - State: 6, Action: 3, Delta: 0.0
# Policy sum for state 6: 1.0
# Norm of Q-values: 0.022271281956816047
# delta (4) - State: 2, Action: 2, Delta: 0.0
# Policy sum for state 2: 1.0
# Norm of Q-values: 0.022271281956816047
# delta (4) - State: 6, Action: 0, Delta: 0.0
# Policy sum for state 6: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 17/20
# Step: 0, State: 9, Terminated: False, Truncated: False
# delta (4) - State: 9, Action: 1, Delta: 0.0
# Policy sum for state 9: 1.0
# Norm of Q-values: 0.022271281956816047
# delta (4) - State: 10, Action: 0, Delta: 0.0
# Policy sum for state 10: 1.0
# Norm of Q-values: 0.022271281956816047
# delta (4) - State: 9, Action: 2, Delta: 0.0
# Policy sum for state 9: 1.0
# Norm of Q-values: 0.022271281956816047
# delta (4) - State: 14, Action: 3, Delta: 0.0
# Policy sum for state 14: 1.0
# Norm of Q-values: 0.022271281956816047
# delta (4) - State: 9, Action: 2, Delta: 0.0
# Policy sum for state 9: 1.0
# Norm of Q-values: 0.022271281956816047
# delta (4) - State: 14, Action: 1, Delta: 0.0
# Policy sum for state 14: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 18/20
# Step: 0, State: 8, Terminated: False, Truncated: False
# delta (4) - State: 8, Action: 2, Delta: 0.0
# Policy sum for state 8: 1.0
# Norm of Q-values: 0.022271281956816047
# delta (4) - State: 13, Action: 3, Delta: 0.0
# Policy sum for state 13: 1.0
# Norm of Q-values: 0.022271281956816047
# delta (4) - State: 8, Action: 3, Delta: 0.0
# Policy sum for state 8: 1.0
# Norm of Q-values: 0.022271281956816047
# delta (4) - State: 3, Action: 1, Delta: 0.0
# Policy sum for state 3: 1.0
# Norm of Q-values: 0.022271281956816047
# delta (4) - State: 3, Action: 3, Delta: 0.0
# Policy sum for state 3: 1.0
# Norm of Q-values: 0.022271281956816047
# delta (4) - State: 3, Action: 0, Delta: 0.0
# Policy sum for state 3: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 19/20
# Step: 0, State: 11, Terminated: False, Truncated: False
# delta (4) - State: 11, Action: 0, Delta: 0.0
# Policy sum for state 11: 1.0
# Norm of Q-values: 0.022271281956816047
# delta (4) - State: 10, Action: 3, Delta: 0.0
# Policy sum for state 10: 1.0
# Norm of Q-values: 0.022271281956816047
# delta (4) - State: 5, Action: 1, Delta: 0.0
# Policy sum for state 5: 1.0
# Norm of Q-values: 0.022271281956816047
# delta (4) - State: 6, Action: 2, Delta: 0.0
# Policy sum for state 6: 1.0
# Norm of Q-values: 0.022271281956816047
# delta (4) - State: 11, Action: 1, Delta: 0.0
# Policy sum for state 11: 1.0
# Norm of Q-values: 0.022271281956816047
# delta (4) - State: 12, Action: 2, Delta: 0.0
# Policy sum for state 12: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#  Actor_critic_q function - looping Episode 20/20
# Step: 0, State: 9, Terminated: False, Truncated: False
# delta (4) - State: 9, Action: 0, Delta: 0.0
# Policy sum for state 9: 1.0
# Norm of Q-values: 0.022271281956816047
# delta (4) - State: 9, Action: 1, Delta: 0.0
# Policy sum for state 9: 1.0
# Norm of Q-values: 0.022271281956816047
# delta (4) - State: 10, Action: 0, Delta: 0.0
# Policy sum for state 10: 1.0
# Norm of Q-values: 0.022271281956816047
# delta (4) - State: 9, Action: 2, Delta: 0.0
# Policy sum for state 9: 1.0
# Norm of Q-values: 0.022271281956816047
# delta (4) - State: 14, Action: 3, Delta: 0.0
# Policy sum for state 14: 1.0
# Norm of Q-values: 0.022271281956816047
# delta (4) - State: 9, Action: 1, Delta: 0.0
# Policy sum for state 9: 1.0
# Stagnation detected after 6 steps. Avg reward: 0.0
#
# Summary Table:
#     Update Rule  Mean Steps  Standard Deviation
# 0        SARSA      5.6115            0.095774
# 1   Q-learning      5.6445            0.156795
# 2   Mean SARSA      5.6270            0.114983
# 3  Fourth Rule      5.6585            0.118122
# nb_episodes: 20
# Temps d'exécution pour 100 runs avec gamma = 0.99 : 0:00:06.933779
