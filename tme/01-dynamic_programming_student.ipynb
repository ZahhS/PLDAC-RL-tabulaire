# %% [markdown]
#  Copyright © Sorbonne University.
#
#  This source code is licensed under the MIT license found in the LICENSE file
#  in the root directory of this source tree.

# %% [markdown]
# # Outlook
#
# In this notebook, we study the **value iteration** and **policy
# iteration** algorithms in a maze environment.

# %% [markdown]
# # Installation

# %%
try:
    from easypip import easyimport, easyinstall, is_notebook
except ModuleNotFoundError:
    # !pip install --user easypip
    # Automatically restart the kernel after installation
    import IPython
    IPython.Application.instance().kernel.do_shutdown(True)

from easypip import easyimport, easyinstall, is_notebook

easyinstall("bbrl>=0.2.2")
# easyinstall("bbrl_gymnasium>=0.3.5")
easyinstall("tensorboard")
easyinstall("moviepy")

import sys
import os
import numpy as np
from pathlib import Path
from typing import List, Tuple

import matplotlib.pyplot as plt
from moviepy.editor import ipython_display as video_display

if not is_notebook():
    print("Not displaying video (hidden since not in a notebook)", file=sys.stderr)
    def video_display(*args, **kwargs):
        pass
    def display(*args, **kwargs):
        print(*args, **kwargs)

testing_mode = os.environ.get("TESTING_MODE", None) == "ON"

import gymnasium as gym

! pip install swig
! pip install box2d-py
! pip install bbrl_utils
easyimport("bbrl_utils").setup(maze_mdp=True)
from bbrl_gymnasium.envs.maze_mdp import MazeMDPEnv
from mazemdp.mdp import Mdp
from mazemdp.toolbox import egreedy, egreedy_loc, sample_categorical, softmax
from mazemdp import random_policy
# Out:
# Requirement already satisfied: swig in c:\users\paulc\appdata\local\programs\python\python313\lib\site-packages (4.3.0)
# Requirement already satisfied: box2d-py in c:\users\paulc\appdata\local\programs\python\python313\lib\site-packages (2.3.5)
# Requirement already satisfied: bbrl_utils in c:\users\paulc\appdata\local\programs\python\python313\lib\site-packages (0.10.3)
# Requirement already satisfied: easypip in c:\users\paulc\appdata\roaming\python\python313\site-packages (from bbrl_utils) (1.3.5)
# Requirement already satisfied: bbrl>=0.3.1 in c:\users\paulc\appdata\local\programs\python\python313\lib\site-packages (from bbrl_utils) (0.3.3)
# Requirement already satisfied: bbrl-gymnasium>=0.3.5 in c:\users\paulc\appdata\local\programs\python\python313\lib\site-packages (from bbrl_utils) (0.3.7)
# Requirement already satisfied: tensorboard in c:\users\paulc\appdata\local\programs\python\python313\lib\site-packages (from bbrl_utils) (2.18.0)
# Requirement already satisfied: pygame in c:\users\paulc\appdata\local\programs\python\python313\lib\site-packages (from bbrl_utils) (2.6.1)
# Requirement already satisfied: torch>=1.9.0 in c:\users\paulc\appdata\local\programs\python\python313\lib\site-packages (from bbrl>=0.3.1->bbrl_utils) (2.6.0)
# Requirement already satisfied: torchvision in c:\users\paulc\appdata\local\programs\python\python313\lib\site-packages (from bbrl>=0.3.1->bbrl_utils) (0.21.0)
# Requirement already satisfied: tqdm in c:\users\paulc\appdata\local\programs\python\python313\lib\site-packages (from bbrl>=0.3.1->bbrl_utils) (4.67.1)
# Requirement already satisfied: hydra-core in c:\users\paulc\appdata\local\programs\python\python313\lib\site-packages (from bbrl>=0.3.1->bbrl_utils) (1.3.2)
# Requirement already satisfied: numpy in c:\users\paulc\appdata\local\programs\python\python313\lib\site-packages (from bbrl>=0.3.1->bbrl_utils) (2.2.2)
# Requirement already satisfied: pandas in c:\users\paulc\appdata\local\programs\python\python313\lib\site-packages (from bbrl>=0.3.1->bbrl_utils) (2.2.3)
# Requirement already satisfied: opencv-python in c:\users\paulc\appdata\local\programs\python\python313\lib\site-packages (from bbrl>=0.3.1->bbrl_utils) (4.11.0.86)
# Requirement already satisfied: omegaconf in c:\users\paulc\appdata\local\programs\python\python313\lib\site-packages (from bbrl>=0.3.1->bbrl_utils) (2.3.0)
# Requirement already satisfied: matplotlib in c:\users\paulc\appdata\local\programs\python\python313\lib\site-packages (from bbrl>=0.3.1->bbrl_utils) (3.10.0)
# Requirement already satisfied: seaborn in c:\users\paulc\appdata\local\programs\python\python313\lib\site-packages (from bbrl>=0.3.1->bbrl_utils) (0.13.2)
# Requirement already satisfied: scipy in c:\users\paulc\appdata\local\programs\python\python313\lib\site-packages (from bbrl>=0.3.1->bbrl_utils) (1.15.1)
# Requirement already satisfied: bootstrapped in c:\users\paulc\appdata\local\programs\python\python313\lib\site-packages (from bbrl>=0.3.1->bbrl_utils) (0.0.2)
# Requirement already satisfied: gymnasium in c:\users\paulc\appdata\local\programs\python\python313\lib\site-packages (from bbrl>=0.3.1->bbrl_utils) (0.29.1)
# Requirement already satisfied: moviepy in c:\users\paulc\appdata\local\programs\python\python313\lib\site-packages (from bbrl>=0.3.1->bbrl_utils) (1.0.3)
# Requirement already satisfied: mazemdp>=1.2.0 in c:\users\paulc\appdata\local\programs\python\python313\lib\site-packages (from bbrl-gymnasium>=0.3.5->bbrl_utils) (1.2.7)
# Requirement already satisfied: packaging in c:\users\paulc\appdata\local\programs\python\python313\lib\site-packages (from easypip->bbrl_utils) (24.2)
# Requirement already satisfied: absl-py>=0.4 in c:\users\paulc\appdata\local\programs\python\python313\lib\site-packages (from tensorboard->bbrl_utils) (2.1.0)
# Requirement already satisfied: grpcio>=1.48.2 in c:\users\paulc\appdata\local\programs\python\python313\lib\site-packages (from tensorboard->bbrl_utils) (1.70.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\paulc\appdata\local\programs\python\python313\lib\site-packages (from tensorboard->bbrl_utils) (3.7)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in c:\users\paulc\appdata\local\programs\python\python313\lib\site-packages (from tensorboard->bbrl_utils) (5.29.3)
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\paulc\appdata\local\programs\python\python313\lib\site-packages (from tensorboard->bbrl_utils) (75.6.0)
# Requirement already satisfied: six>1.9 in c:\users\paulc\appdata\local\programs\python\python313\lib\site-packages (from tensorboard->bbrl_utils) (1.16.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\paulc\appdata\local\programs\python\python313\lib\site-packages (from tensorboard->bbrl_utils) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\paulc\appdata\local\programs\python\python313\lib\site-packages (from tensorboard->bbrl_utils) (3.1.3)
# Requirement already satisfied: cloudpickle>=1.2.0 in c:\users\paulc\appdata\local\programs\python\python313\lib\site-packages (from gymnasium->bbrl>=0.3.1->bbrl_utils) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in c:\users\paulc\appdata\local\programs\python\python313\lib\site-packages (from gymnasium->bbrl>=0.3.1->bbrl_utils) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in c:\users\paulc\appdata\local\programs\python\python313\lib\site-packages (from gymnasium->bbrl>=0.3.1->bbrl_utils) (0.0.4)
# Requirement already satisfied: ipyreact in c:\users\paulc\appdata\local\programs\python\python313\lib\site-packages (from mazemdp>=1.2.0->bbrl-gymnasium>=0.3.5->bbrl_utils) (0.5.0)
# Requirement already satisfied: filelock in c:\users\paulc\appdata\local\programs\python\python313\lib\site-packages (from torch>=1.9.0->bbrl>=0.3.1->bbrl_utils) (3.16.1)
# Requirement already satisfied: networkx in c:\users\paulc\appdata\local\programs\python\python313\lib\site-packages (from torch>=1.9.0->bbrl>=0.3.1->bbrl_utils) (3.4.2)
# Requirement already satisfied: jinja2 in c:\users\paulc\appdata\local\programs\python\python313\lib\site-packages (from torch>=1.9.0->bbrl>=0.3.1->bbrl_utils) (3.1.4)
# Requirement already satisfied: fsspec in c:\users\paulc\appdata\local\programs\python\python313\lib\site-packages (from torch>=1.9.0->bbrl>=0.3.1->bbrl_utils) (2024.10.0)
# Requirement already satisfied: sympy==1.13.1 in c:\users\paulc\appdata\local\programs\python\python313\lib\site-packages (from torch>=1.9.0->bbrl>=0.3.1->bbrl_utils) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\paulc\appdata\local\programs\python\python313\lib\site-packages (from sympy==1.13.1->torch>=1.9.0->bbrl>=0.3.1->bbrl_utils) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\paulc\appdata\local\programs\python\python313\lib\site-packages (from werkzeug>=1.0.1->tensorboard->bbrl_utils) (3.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\paulc\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->bbrl>=0.3.1->bbrl_utils) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\paulc\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->bbrl>=0.3.1->bbrl_utils) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\paulc\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->bbrl>=0.3.1->bbrl_utils) (4.55.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\paulc\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->bbrl>=0.3.1->bbrl_utils) (1.4.7)
# Requirement already satisfied: pillow>=8 in c:\users\paulc\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->bbrl>=0.3.1->bbrl_utils) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\paulc\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->bbrl>=0.3.1->bbrl_utils) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\paulc\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->bbrl>=0.3.1->bbrl_utils) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\paulc\appdata\local\programs\python\python313\lib\site-packages (from pandas->bbrl>=0.3.1->bbrl_utils) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\paulc\appdata\local\programs\python\python313\lib\site-packages (from pandas->bbrl>=0.3.1->bbrl_utils) (2025.1)
# Requirement already satisfied: box2d-py==2.3.5 in c:\users\paulc\appdata\local\programs\python\python313\lib\site-packages (from gymnasium[box2d]->bbrl-gymnasium>=0.3.5->bbrl_utils) (2.3.5)
# Requirement already satisfied: swig==4.* in c:\users\paulc\appdata\local\programs\python\python313\lib\site-packages (from gymnasium[box2d]->bbrl-gymnasium>=0.3.5->bbrl_utils) (4.3.0)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in c:\users\paulc\appdata\local\programs\python\python313\lib\site-packages (from hydra-core->bbrl>=0.3.1->bbrl_utils) (4.9.3)
# Requirement already satisfied: PyYAML>=5.1.0 in c:\users\paulc\appdata\local\programs\python\python313\lib\site-packages (from omegaconf->bbrl>=0.3.1->bbrl_utils) (6.0.2)
# Requirement already satisfied: decorator<5.0,>=4.0.2 in c:\users\paulc\appdata\local\programs\python\python313\lib\site-packages (from moviepy->bbrl>=0.3.1->bbrl_utils) (4.4.2)
# Requirement already satisfied: imageio<3.0,>=2.5 in c:\users\paulc\appdata\local\programs\python\python313\lib\site-packages (from moviepy->bbrl>=0.3.1->bbrl_utils) (2.37.0)
# Requirement already satisfied: imageio_ffmpeg>=0.2.0 in c:\users\paulc\appdata\local\programs\python\python313\lib\site-packages (from moviepy->bbrl>=0.3.1->bbrl_utils) (0.6.0)
# Requirement already satisfied: requests<3.0,>=2.8.1 in c:\users\paulc\appdata\local\programs\python\python313\lib\site-packages (from moviepy->bbrl>=0.3.1->bbrl_utils) (2.32.3)
# Requirement already satisfied: proglog<=1.0.0 in c:\users\paulc\appdata\local\programs\python\python313\lib\site-packages (from moviepy->bbrl>=0.3.1->bbrl_utils) (0.1.10)
# Requirement already satisfied: colorama in c:\users\paulc\appdata\local\programs\python\python313\lib\site-packages (from tqdm->bbrl>=0.3.1->bbrl_utils) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\paulc\appdata\local\programs\python\python313\lib\site-packages (from requests<3.0,>=2.8.1->moviepy->bbrl>=0.3.1->bbrl_utils) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\paulc\appdata\local\programs\python\python313\lib\site-packages (from requests<3.0,>=2.8.1->moviepy->bbrl>=0.3.1->bbrl_utils) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\paulc\appdata\local\programs\python\python313\lib\site-packages (from requests<3.0,>=2.8.1->moviepy->bbrl>=0.3.1->bbrl_utils) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\paulc\appdata\local\programs\python\python313\lib\site-packages (from requests<3.0,>=2.8.1->moviepy->bbrl>=0.3.1->bbrl_utils) (2024.8.30)
# Requirement already satisfied: anywidget>=0.2.0 in c:\users\paulc\appdata\local\programs\python\python313\lib\site-packages (from ipyreact->mazemdp>=1.2.0->bbrl-gymnasium>=0.3.5->bbrl_utils) (0.9.13)
# Requirement already satisfied: ipywidgets>=7.0.0 in c:\users\paulc\appdata\local\programs\python\python313\lib\site-packages (from ipyreact->mazemdp>=1.2.0->bbrl-gymnasium>=0.3.5->bbrl_utils) (8.1.5)
# Requirement already satisfied: psygnal>=0.8.1 in c:\users\paulc\appdata\local\programs\python\python313\lib\site-packages (from anywidget>=0.2.0->ipyreact->mazemdp>=1.2.0->bbrl-gymnasium>=0.3.5->bbrl_utils) (0.11.1)
# Requirement already satisfied: comm>=0.1.3 in c:\users\paulc\appdata\local\programs\python\python313\lib\site-packages (from ipywidgets>=7.0.0->ipyreact->mazemdp>=1.2.0->bbrl-gymnasium>=0.3.5->bbrl_utils) (0.2.2)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\paulc\appdata\local\programs\python\python313\lib\site-packages (from ipywidgets>=7.0.0->ipyreact->mazemdp>=1.2.0->bbrl-gymnasium>=0.3.5->bbrl_utils) (8.30.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\paulc\appdata\local\programs\python\python313\lib\site-packages (from ipywidgets>=7.0.0->ipyreact->mazemdp>=1.2.0->bbrl-gymnasium>=0.3.5->bbrl_utils) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in c:\users\paulc\appdata\local\programs\python\python313\lib\site-packages (from ipywidgets>=7.0.0->ipyreact->mazemdp>=1.2.0->bbrl-gymnasium>=0.3.5->bbrl_utils) (4.0.13)
# Requirement already satisfied: jupyterlab-widgets~=3.0.12 in c:\users\paulc\appdata\local\programs\python\python313\lib\site-packages (from ipywidgets>=7.0.0->ipyreact->mazemdp>=1.2.0->bbrl-gymnasium>=0.3.5->bbrl_utils) (3.0.13)
# Requirement already satisfied: jedi>=0.16 in c:\users\paulc\appdata\local\programs\python\python313\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->ipyreact->mazemdp>=1.2.0->bbrl-gymnasium>=0.3.5->bbrl_utils) (0.19.2)
# Requirement already satisfied: matplotlib-inline in c:\users\paulc\appdata\local\programs\python\python313\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->ipyreact->mazemdp>=1.2.0->bbrl-gymnasium>=0.3.5->bbrl_utils) (0.1.7)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\paulc\appdata\local\programs\python\python313\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->ipyreact->mazemdp>=1.2.0->bbrl-gymnasium>=0.3.5->bbrl_utils) (3.0.48)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\paulc\appdata\local\programs\python\python313\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->ipyreact->mazemdp>=1.2.0->bbrl-gymnasium>=0.3.5->bbrl_utils) (2.18.0)
# Requirement already satisfied: stack_data in c:\users\paulc\appdata\local\programs\python\python313\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->ipyreact->mazemdp>=1.2.0->bbrl-gymnasium>=0.3.5->bbrl_utils) (0.6.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\paulc\appdata\local\programs\python\python313\lib\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets>=7.0.0->ipyreact->mazemdp>=1.2.0->bbrl-gymnasium>=0.3.5->bbrl_utils) (0.8.4)
# Requirement already satisfied: wcwidth in c:\users\paulc\appdata\local\programs\python\python313\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets>=7.0.0->ipyreact->mazemdp>=1.2.0->bbrl-gymnasium>=0.3.5->bbrl_utils) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in c:\users\paulc\appdata\local\programs\python\python313\lib\site-packages (from stack_data->ipython>=6.1.0->ipywidgets>=7.0.0->ipyreact->mazemdp>=1.2.0->bbrl-gymnasium>=0.3.5->bbrl_utils) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\paulc\appdata\local\programs\python\python313\lib\site-packages (from stack_data->ipython>=6.1.0->ipywidgets>=7.0.0->ipyreact->mazemdp>=1.2.0->bbrl-gymnasium>=0.3.5->bbrl_utils) (3.0.0)
# Requirement already satisfied: pure-eval in c:\users\paulc\appdata\local\programs\python\python313\lib\site-packages (from stack_data->ipython>=6.1.0->ipywidgets>=7.0.0->ipyreact->mazemdp>=1.2.0->bbrl-gymnasium>=0.3.5->bbrl_utils) (0.2.3)
# Matplotlib backend: module://matplotlib_inline.backend_inline

# %% [markdown]
# # Agents and MDPs
#
# A reinforcement learning agent interacts with an environment represented as a
# Markov Decision Process (MDP). It is defined by a tuple $(S, A, P, r, \gamma)$
# where $S$ is the state space, $A$ is the action space, $P(state_t, action_t,
# state_{t+1})$ is the transition function, $r(state_t, action_t)$ is the reward
# function and $\gamma \in [0, 1]$ is the discount factor.
#
# In what follows we import code to create an MDP corresponding to a random maze
# (see https://github.com/osigaud/SimpleMazeMDP for documentation).

# %%
env = gym.make(
    "MazeMDP-v0",
    kwargs={"width": 5, "height": 5, "ratio": 0.2},
    render_mode="human",
)
env = env.unwrapped
env.reset()

# in dynamic programming, there is no agent moving in the environment
env.set_no_agent()
env.init_draw("The maze")
# Out:
# <style>table.maze {
#     border-collapse: collapse;
# }
#
# td {
#     text-align: center;
# }
#
# table.maze td.cell {
#     position: relative;
#     border: 1px solid black;
# }
#
# table.maze td.cell div.agent {
#     position: absolute;
#     left: 25%;
#     top: 25%;;
#     width: 50%;
#     height: 50%;
#     border-radius: 100%;
#     background:rgba(69, 100, 186, 0.5);
# }
#
#
# td.wall {
#     background: black;
# }
#
# td.terminal {
#     background: rgb(246, 170, 246);
# }
#
# table.maze table td {
#     width: .5rem;
#     height: .5rem;
# }
#
#
#
# table.maze table td.arrow {
#     color: transparent;
#     font-weight: bold;
# }
#
# table.maze table td.value {
#     position: relative;
#     width: 2rem;
#     height: 2rem;
# }
#
# </style>
# VBox(children=(MazeWidget(cells=array([[-1,  4,  8, 13, 17],
#        [ 0, -1,  9, 14, 18],
#        [ 1,  5, 10, …

# %% [markdown]
# Dynamic programming
#
# The goal of an RL agent is to find the optimal behaviour, defined by a policy
# $\pi$ that assigns an action (or distribution over actions) to each state so
# as to maximize the agent's total expected reward. In order to estimate how
# good a state is, either a state value function $V(x)$ or a state-action value
# function $Q(x,u)$ is used.
#
# Dynamic programming algorithms are used for planning, they require a full
# knowledge of the MDP from the agent (in contrast to "true" RL where the agent
# does not know the transition and reward functions). They find the optimal
# policy by computing a value function $V$ or an action-value function $Q$ over
# the state space or state-action space of the given MDP. **Value iteration**
# and **policy iteration** are two standard dynamic programming algorithms. You
# should study both of them using both $V$ and $Q$, as these algorithms contain
# the basic building blocks for most RL algorithms.
#
# # Value Iteration
#
# ## Value Iteration with the V function
#
# When using the $V$ function, **value iteration** aims at finding the optimal
# values $V^*$ based on the Bellman Optimality Equation: $$V^*(s) = \max_a
# \big[r(s,a) + \gamma \sum_{y \in S} P(s,a,y)V^*(y) \big],$$ where:
#
# *   $r(s, a)$ is the reward obtained from taking action $a$ in state $s$,
# *   $P(s, a, y)$ is the probability of reaching state $y$ when taking action
#     $a$ in state $s$,
# *   $\gamma \in [0,1]$ is a discount factor defining the relative importance
#     of long term rewards over short term ones (the closer to 0, the more the
#     agent focuses on immediate rewards).
#
# In practice, we start with an initial value function $V^0$ (for instance, the
# values of all states are 0), and then we iterate for all states $s$
# $$V^{i+1}(s) = \max_a \big[ r(s,a) + \gamma \sum_{y \in S} P(s,a,y)V^i(y)
# \big],$$
#
# until the values converge, that is $\forall s, V^{i+1}(s) \approx V^i(s)$. It
# is shown that at convergence, $\forall s, V^i(s)= V^*(s)$.
#
# To visualize the policy obtained from **value iteration**, we need to first
# define the `get_policy_from_V()` function

# %%
def get_policy_from_v(mdp: MazeMDPEnv, v: np.ndarray) -> np.ndarray:
    """Outputs a policy given the state values"""

    # Sets initial state values are set to 0
    policy = np.zeros(mdp.nb_states)  

    # Loop over MDP states
    for x in range(mdp.nb_states):
        if x in mdp.terminal_states:
            # Takes the reward associated with the terminal state
            policy[x] = np.argmax(mdp.r[x, :])
        else:
            # Compute the value V(x) for state x
            v_temp = []
            
            # Loop over actions
            for u in range(mdp.action_space.n):
                # Process sum of the values of the neighbouring states
                summ = 0
                for y in range(mdp.nb_states):
                    summ = summ + mdp.P[x, u, y] * v[y]
                v_temp.append(mdp.r[x, u] + mdp.gamma * summ)
            policy[x] = np.argmax(v_temp)
    return policy

# %% [markdown]
# The `value_iteration_v(mdp)` function below provides the code of **value
# iteration** using the $V$ function. It is given as an example from which you
# can derive other instances of dynamic programming algorithms. Look at it more
# closely, this will help for later questions:
#
# * you can ignore the `mdp.new_render()` and `mdp.render(...)` functions which
#   are here to provide the visualization of the iterations.
# * find in the code the loop over states, the main loop that performs these
#   updates until the values don't change significantly anymore, the main update
#   equation. Found them? OK, you can continue...

# %%
def value_iteration_v(
    mdp: MazeMDPEnv, render: bool = True
) -> Tuple[np.ndarray, List[float]]:
    # Value Iteration using the state value v
    v = np.zeros(mdp.nb_states)  # initial state values are set to 0
    v_list = []
    stop = False

    mdp.init_draw("Value iteration V")

    mdp.draw_v(v)

    while not stop:
        v_old = v.copy()
        mdp.draw_v(v)

        for x in range(mdp.nb_states):  # for each state x
            # Compute the value of the state x for each action u of the MDP action space
            if x in mdp.terminal_states:
                v[x] = np.max(mdp.r[x, :])
            else:
                v_temp = []
                for u in range(mdp.action_space.n):
                    # Process sum of the values of the neighbouring states
                    summ = 0
                    for y in range(mdp.nb_states):
                        summ = summ + mdp.P[x, u, y] * v_old[y]
                    v_temp.append(mdp.r[x, u] + mdp.gamma * summ)

                # Select the highest state value among those computed
                v[x] = np.max(v_temp)

        # Test if convergence has been reached
        if (np.linalg.norm(v - v_old)) < 0.01:
            stop = True
        v_list.append(np.linalg.norm(v))

    policy = get_policy_from_v(mdp, v)
    mdp.draw_v_pi(v, policy)
    return v, v_list

# %% [markdown]
# Let us run it on the previously defined MDP

# %%
v, v_list = value_iteration_v(env, render=True)
# Out:
# VBox(children=(MazeWidget(cells=array([[-1,  4,  8, 13, 17],
#        [ 0, -1,  9, 14, 18],
#        [ 1,  5, 10, …

# %% [markdown]
# ### Value iteration with the $Q$ function ###
#
# The state-action value function $Q^{\pi}(s,a)$ defines the value of being in
# state $s$, taking action $a$ then following policy $\pi$. The Bellman
# Optimality Equation for $Q^*$ is $$ Q^*(s,a) =  r(s,a) + \gamma \sum_{y}
# P(s,a,y) \max_{a'}Q^*(y,a'). $$
#
# **Question:** By taking inspiration from the `value_iteration_v(mdp)` function
# above, fill the blank (given with '\#Q[x,u]=...') in the code of
# `value_iteration_q(mdp)`.

# %%
# ------------------ Value Iteration with the Q function ---------------------#
# Given a MDP, this algorithm computes the optimal action value function Q
# It then derives the optimal policy based on this function


def value_iteration_q(
    mdp: MazeMDPEnv, render: bool = True
) -> Tuple[np.ndarray, List[float]]:
    q = np.zeros(
        (mdp.nb_states, mdp.action_space.n)
    )  # initial action values are set to 0
    q_list = []
    stop = False

    mdp.init_draw("Value iteration Q")

    mdp.draw_v(q)

    while not stop:
        qold = q.copy()

        mdp.draw_v(q)
        for x in range(mdp.nb_states):
            for u in range(mdp.action_space.n):
                if x in mdp.terminal_states:
                    q[x, u] = mdp.r[x, u]
                else:
                    summ = 0
                    for y in range(mdp.nb_states):
                        summ += mdp.P[x, u, y] * np.max(qold[y, :])

                    # Compléter d'après la formule ci-dessus

                    q[x, u] = mdp.r[x,u]+ mdp.gamma * summ
                    


        if (np.linalg.norm(q - qold)) <= 0.01:
            stop = True
        q_list.append(np.linalg.norm(q))

    mdp.draw_v(q)

    return q, q_list

# %% [markdown]
# Once you are done, run it.

# %%
q, q_list = value_iteration_q(env, render=True)
# Out:
# VBox(children=(MazeWidget(cells=array([[-1,  4,  8, 13, 17],
#        [ 0, -1,  9, 14, 18],
#        [ 1,  5, 10, …

# %% [markdown]
# ## Policy Iteration ##
#
# The **policy iteration** algorithm is more complicated than **value
# iteration**. Given a MDP and a policy $\pi$, **policy iteration** iterates the
# following steps:
#
# *   Evaluate policy $\pi$: compute $V$ or $Q$ based on the policy $\pi$;
# *   Improve policy $\pi$: compute a better policy based on $V$ or $Q$.
#
# This process is repeated until convergence, i.e. when the policy cannot be
# improved anymore.
#
# ### Policy iteration with the $V$ function ###
#
# When using $V$, $V^{\pi}(s)$ is the expected return when starting from state
# $s$ and following policy $\pi$. It is processed based on the Bellman
# Optimality Equation for deterministic policies:
#
# $$V^\pi(s) = r(s, \pi(s)) + \gamma \sum_{y \in S}P(s, \pi(s), y)V^\pi(y),$$
#
# where:
#
# *   $\pi$ is a deterministic policy, meaning that in a state $s$, the agent
#     always selects the same action,
# *   $V^\pi(y)$ is the value of the state $y$ under policy $\pi$.
#
# Thus, given a policy $\pi$, one must first compute its value function
# $V^\pi(s)$ for all states $s$ iterating the Bellman Optimality Equation until
# convergence, that is using **value iteration**. Then, one must determine if
# policy $\pi$ can be improved based on $V$. For that, in each state $s$, one
# can compute the Q-value $Q(s,a)$ of applying action $a$ and then following
# policy $\pi$ based on the just computed $V^\pi$, and replace the action
# $\pi(s)$ with $\arg\max_a Q(s,a)$.
#
# In order to facilitate the coding of **policy iteration** algorithms, we first
# define a set of useful functions.
#
# The `improve_policy_from_v(mdp, v, policy)` function is very similar to the
# `get_policy_from_v(v)` function which was given above. The main difference is
# that it takes a policy as argument and improves this policy when possible,
# thus is more in the spirit of the `policy improvement` step of **policy
# iteration**. But both functions can be used interchangeably.
#
# The functions `evaluate_one_step_v(mdp, v, policy)`, where `mdp` is a given
# MDP, `v` is some value function in this MDP and `policy` is some policy and
# the function `evaluate_v(mdp, policy)` are also given. These functions are
# used to build the value function $V^\pi$ corresponding to policy $\pi$.

# %%
def improve_policy_from_v(
    mdp: MazeMDPEnv, v: np.ndarray, policy: np.ndarray
) -> np.ndarray:
    # Improves a policy given the state values
    for x in range(mdp.nb_states):  # for each state x
        # Compute the value of the state x for each action u of the MDP action space
        if x in mdp.terminal_states:
            policy[x] = np.argmax(mdp.r[x, :])
        else:
            v_temp = np.zeros(mdp.action_space.n)
            for u in range(mdp.action_space.n):
                # Process sum of the values of the neighbouring states
                summ = 0
                for y in range(mdp.nb_states):
                    summ = summ + mdp.P[x, u, y] * v[y]
                v_temp[u] = mdp.r[x, u] + mdp.gamma * summ

            for u in range(mdp.action_space.n):
                if v_temp[u] > v_temp[policy[x]]:
                    policy[x] = u
    return policy

# %%
def evaluate_one_step_v(
    mdp: MazeMDPEnv, v: np.ndarray, policy: np.ndarray
) -> np.ndarray:
    # Outputs the state value function after one step of policy evaluation
    # Corresponds to one application of the Bellman Operator
    v_new = np.zeros(mdp.nb_states)  # initial state values are set to 0
    for x in range(mdp.nb_states):  # for each state x
        # Compute the value of the state x for each action u of the MDP action space
        if x in mdp.terminal_states:
            v_new[x] = mdp.r[x, policy[x]]
        else:
            # Process sum of the values of the neighbouring states
            summ = 0
            for y in range(mdp.nb_states):
                summ = summ + mdp.P[x, policy[x], y] * v[y]
            v_new[x] = mdp.r[x, policy[x]] + mdp.gamma * summ
    return v_new

# %%
def evaluate_v(mdp: MazeMDPEnv, policy: np.ndarray) -> np.ndarray:
    # Outputs the state value function of a policy
    v = np.zeros(mdp.nb_states)  # initial state values are set to 0
    stop = False
    while not stop:
        vold = v.copy()
        v = evaluate_one_step_v(mdp, vold, policy)

        # Test if convergence has been reached
        if (np.linalg.norm(v - vold)) < 0.01:
            stop = True
    return v

# %% [markdown]
# To perform **policy iteration** we also need an initial random policy.

# %%
from mazemdp import random_policy

# %% [markdown]
# **Question:** By using the above functions, fill the code of the `policy_iteration_v(mdp)` function below.

# %%
# ---------------- Policy Iteration with the V function -----------------#
# Given an MDP, this algorithm simultaneously computes
# the optimal state value function V and the optimal policy


def policy_iteration_v(
    mdp: MazeMDPEnv, render: bool = True
) -> Tuple[np.ndarray, List[float]]:
    # policy iteration over the v function
    v = np.zeros(mdp.nb_states)  # initial state values are set to 0
    v_list = []
    policy = random_policy(mdp)

    stop = False

    mdp.init_draw("Policy Iteration (V)")

    while not stop:
        vold = v.copy()

        mdp.draw_v(v, title="Policy iteration Q")

        # Step 1 : Policy Evaluation
        # To be completed...

        v = evaluate_v(mdp, policy)


        # Step 2 : Policy Improvement
        # To be completed...

        policy =  improve_policy_from_v(mdp, v, policy)


        # Check convergence
        if (np.linalg.norm(v - vold)) < 0.01:
            stop = True
        v_list.append(np.linalg.norm(v))

    mdp.draw_v_pi(v, get_policy_from_v(mdp, v))

    return v, v_list

# %% [markdown]
# And finally run it.

# %%
v, v_list = policy_iteration_v(env, render=True)
# Out:
# VBox(children=(MazeWidget(cells=array([[-1,  4,  8, 13, 17],
#        [ 0, -1,  9, 14, 18],
#        [ 1,  5, 10, …

# %% [markdown]
# ### Policy iteration with the $Q$ function ###
#
# The **policy iteration** algorithm with the $Q$ function is the same as with
# the $V$ function, but the policy improvement step is more straightforward.
#
# When using $Q$, the Bellman Optimality Equation with deterministic policy
# $\pi$ for $Q$ becomes: $$Q^{\pi}(s,a) = r(s,a) + \gamma \sum_{y \in
# S}P(s,a,y)Q^{\pi}(y,\pi(y)).$$
#
# The policy can then be updated as follows: $$\pi^{(t+1)}(s) =
# \arg\max_aQ^{\pi^{(t)}}(s,a).$$
#
# First, we need to determine a policy from the $Q$ function.
#
# **Question:**  fill the `get_policy_from_q(q)` function, where $q$ is the
# state-action value function.

# %%
def get_policy_from_q(q: np.ndarray) -> np.ndarray:
    # Outputs a policy given the action values

    return np.argmax(q, axis=1)

# %% [markdown]
# **Question:** By drawing inspiration on the functions give with the $v$
# function, fill the code of the `evaluate_one_step_q(mdp, q, policy)` function
# below, where $q$ is some action value function, and the `evaluate_q(mdp,
# policy)` function.

# %%
def evaluate_one_step_q(
    mdp: MazeMDPEnv, q: np.ndarray, policy: np.ndarray
) -> np.ndarray:
    # Outputs the state value function after one step of policy evaluation
    qnew = np.zeros(
        (mdp.nb_states, mdp.action_space.n)
    )  # initial action values are set to 0
    for x in range(mdp.nb_states):  # for each state x
        # Compute the value of the state x for each action u of the MDP action space
        for u in range(mdp.action_space.n):
            if x in mdp.terminal_states:
                qnew[x, u] = mdp.r[x, u]
            else:
                # Process sum of the values of the neighbouring states
                summ = 0
                for y in range(mdp.nb_states):
                    # To be completed...
                    summ += mdp.P[x,u, y] * q[y,policy[y]]

                # To be completed...
                qnew[x, u] = mdp.r[x, u] + mdp.gamma * summ

    return qnew

# %%
def evaluate_q(mdp: MazeMDPEnv, policy: np.ndarray) -> np.ndarray:
    # Outputs the state value function of a policy
    q = np.zeros(
        (mdp.nb_states, mdp.action_space.n)
    )  # initial action values are set to 0
    stop = False
    
    while not stop:
        qold = q.copy()
        q = evaluate_one_step_q(mdp, qold, policy)
        
        # Test if convergence has been reached
        if (np.linalg.norm(q - qold)) < 0.01:
            stop = True
    return q

# %% [markdown]
# **Question:** By using the above functions, fill the code of the `policy_iteration_q(mdp)` function below.

# %%
# ---------------- Policy Iteration with the Q function -----------------#
# Given a MDP, this algorithm simultaneously computes
# the optimal action value function Q and the optimal policy


def policy_iteration_q(
    mdp: MazeMDPEnv, render: bool = True
) -> Tuple[np.ndarray, List[float]]:
    """policy iteration over the q function."""
    q = np.zeros(
        (mdp.nb_states, mdp.action_space.n)
    )  # initial action values are set to 0
    q_list = []
    policy = random_policy(mdp)

    stop = False

    mdp.init_draw("Policy iteration Q")
    while not stop:
        qold = q.copy()
        mdp.draw_v(q)

        # Step 1 : Policy evaluation

        q = evaluate_q(mdp, policy)
        # Step 2 : Policy improvement

        policy = get_policy_from_q(q)

        # Check convergence
        if (np.linalg.norm(q - qold)) <= 0.01:
            stop = True
        q_list.append(np.linalg.norm(q))

    mdp.draw_v_pi(q, get_policy_from_q(q))
    return q, q_list

# %% [markdown]
# Finally, run it.

# %%
q, q_list = policy_iteration_q(env, render=True)
# Out:
# VBox(children=(MazeWidget(cells=array([[-1,  4,  8, 13, 17],
#        [ 0, -1,  9, 14, 18],
#        [ 1,  5, 10, …

# %% [markdown]
# ### Experimental comparisons
#
# We now compare the efficiency of the various dynamic programming methods using either the $V$ or the  $Q$ functions.
#
# In all your dymanic programming functions, add code to count the number of iterations and the number of elementary $V$ or $Q$ updates. Use the provided `mazemdp.Chrono` class to measure the time taken. You may generate various mazes of various sizes to figure out the influence of the maze topology.
#
# Build a table where you compare the various dymanic programming functions in terms of iterations, elementary operations and time taken.
#
# You can run the `plot_convergence_vi_pi(...)` function provided below to visualize the convergence of the various algorithms.

# %%
# ---- plot learning curves of Q-Learning and Sarsa using epsilon-greedy and softmax -----#


def plot_convergence_vi_pi(m, render):
    v, v_list1 = value_iteration_v(m, render)
    q, q_list1 = value_iteration_q(m, render)
    v, v_list2 = policy_iteration_v(m, render)
    q, q_list2 = policy_iteration_q(m, render)

    plt.plot(range(len(v_list1)), v_list1, label="value_iteration_v")
    plt.plot(range(len(q_list1)), q_list1, label="value_iteration_q")
    plt.plot(range(len(v_list2)), v_list2, label="policy_iteration_v")
    plt.plot(range(len(q_list2)), q_list2, label="policy_iteration_q")

    plt.xlabel("Number of episodes")
    plt.ylabel("Norm of V or Q value")
    plt.legend(loc="upper right")
    # plt.savefig("comparison_DP.png")
    plt.title("Comparison of convergence rates")
    plt.show()

# %% [markdown]
# **Question:** Run the code below and visualize the results of the different algorithms

# %%
plot_convergence_vi_pi(env, False)
# Out:
# VBox(children=(MazeWidget(cells=array([[-1,  4,  8, 13, 17],
#        [ 0, -1,  9, 14, 18],
#        [ 1,  5, 10, …
